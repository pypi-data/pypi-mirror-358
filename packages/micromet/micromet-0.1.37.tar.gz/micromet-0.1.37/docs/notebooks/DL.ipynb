# %% [markdown]
# This notebook was used to compile all of the available data from the Utah Flux Network stations.  It should only need to be used once, as other notebooks are used to comile the newer data.

# %% [markdown]
# # Import Relevant Libraries

# %% [markdown]
# ## Standard Libraries

# %%
import pandas as pd
import numpy as np
import os
import geopandas as gpd
import sys
import pathlib
import glob
import matplotlib.pyplot as plt
from urllib.parse import quote
from sqlalchemy import create_engine
import configparser
import re

import statsmodels.api as sm
#import pingouin as pg
import plotly.express as px
import plotly.express as px

# %% [markdown]
# ## Import Libraries

# %%
import matplotlib
import pandas
import pathlib
import sys

sys.path.append("../../src/")
import micromet

# %matplotlib inline

import logging
logger = logging.getLogger(__name__)
logger.setLevel(logging.DEBUG)
ch = logging.StreamHandler()
ch.setFormatter(
    logging.Formatter(
        fmt="%(levelname)s [%(asctime)s] %(name)s – %(message)s",
        datefmt="%Y-%m-%d %H:%M:%S",
    )
)
logger.addHandler(ch)

# %% [markdown]
# # Run Compilation

# %% [markdown]
# ## List Sites for Examination

# %%
site_folders = {#'US-UTD':'Dugout_Ranch',
                #'US-UTB':'BSF',
                #'US-UTJ':'Bluff',
                #'US-UTW':'Wellington',
                #'US-UTE':'Escalante',
                #'US-UTM':'Matheson',
                'US-UTP':'Phrag',
                #'US-CdM':'Cedar_mesa',
                #'US-UTV':'Desert_View_Myton',
                #'US-UTN':'Juab',
                #'US-UTG':'Green_River'
                }

# %% [markdown]
# ## Compile Eddy Data

# %% [markdown]
# Search folders, reformat table, and save csv files

# %%
comp_edd_df = {}

am = micromet.AmerifluxDataProcessor(logger=logger)

for key, value in site_folders.items():

    print(key)
    raw_fold = pathlib.Path('G:/Shared drives/UGS_Flux/Data_Downloads/')
    pths = micromet.fix_all_in_parent(raw_fold)
    raw_data = am.raw_file_compile(raw_fold, value, search_str = "*Flux_AmeriFluxFormat*.dat")
    if raw_data is not None:
        am_data = micromet.Reformatter(drop_soil=False,
                                       logger=logger,
                                       )
        #raw_data = raw_data.drop([0], axis=0)
        am_df = am_data.prepare(raw_data)
        comp_edd_df[key] = am_df

        am_df.to_csv(f"../../out_data/station_data/{key}_HH_{am_df['TIMESTAMP_START'].values[0]:}_{am_df['TIMESTAMP_END'].values[-1]:}.csv")
# Out:
# US-UTP
# [INFO]  Patched  Phrag\e20250320\8442_Flux_AmeriFluxFormat_38.dat   (34 rows)
# INFO [2025-06-16 17:09:41] __main__ – Compiling data from G:\Shared drives\UGS_Flux\Data_Downloads\Phrag
# INFO [2025-06-16 17:09:41] __main__ – Processing file: G:\Shared drives\UGS_Flux\Data_Downloads\Phrag\Great Salt Lake Phragmites_Flux_AmeriFluxFormat_(3).dat
# DEBUG [2025-06-16 17:09:41] __main__ – 9999 -> 9999
# DEBUG [2025-06-16 17:09:41] __main__ – TOA5 header detected: ['TOA5', 'Phrag', '', '', '', '', '', 'Flux_AmeriFluxFormat']
# DEBUG [2025-06-16 17:09:41] __main__ – Skip rows for set to [0, 1, 2, 3]
# DEBUG [2025-06-16 17:09:41] __main__ – Reading G:\Shared drives\UGS_Flux\Data_Downloads\Phrag\Great Salt Lake Phragmites_Flux_AmeriFluxFormat_(3).dat
# INFO [2025-06-16 17:09:41] __main__ – Processing file: G:\Shared drives\UGS_Flux\Data_Downloads\Phrag\Great Salt Lake Phragmites_Flux_AmeriFluxFormat_(2).dat
# DEBUG [2025-06-16 17:09:41] __main__ – 9999 -> 9999
# DEBUG [2025-06-16 17:09:41] __main__ – TOA5 header detected: ['TOA5', 'Phrag', '', '', '', '', '', 'Flux_AmeriFluxFormat']
# DEBUG [2025-06-16 17:09:41] __main__ – Skip rows for set to [0, 1, 2, 3]
# DEBUG [2025-06-16 17:09:41] __main__ – Reading G:\Shared drives\UGS_Flux\Data_Downloads\Phrag\Great Salt Lake Phragmites_Flux_AmeriFluxFormat_(2).dat
# INFO [2025-06-16 17:09:41] __main__ – Processing file: G:\Shared drives\UGS_Flux\Data_Downloads\Phrag\Great Salt Lake Phragmites_Flux_AmeriFluxFormat (5).dat
# DEBUG [2025-06-16 17:09:41] __main__ – 9999 -> 9999
# DEBUG [2025-06-16 17:09:41] __main__ – TOA5 header detected: ['TOA5', 'Phrag', '', '', '', '', '', 'Flux_AmeriFluxFormat']
# DEBUG [2025-06-16 17:09:41] __main__ – Skip rows for set to [0, 1, 2, 3]
# DEBUG [2025-06-16 17:09:41] __main__ – Reading G:\Shared drives\UGS_Flux\Data_Downloads\Phrag\Great Salt Lake Phragmites_Flux_AmeriFluxFormat (5).dat
# INFO [2025-06-16 17:09:41] __main__ – Processing file: G:\Shared drives\UGS_Flux\Data_Downloads\Phrag\8441_Flux_AmeriFluxFormat_1.dat
# DEBUG [2025-06-16 17:09:41] __main__ – 1 -> 8441
# DEBUG [2025-06-16 17:09:41] __main__ – Header row detected: ['TIMESTAMP_START', 'TIMESTAMP_END', 'CO2', 'CO2_SIGMA', 'H2O', 'H2O_SIGMA', 'FC', 'FC_SSITC_TEST', 'LE', 'LE_SSITC_TEST', 'ET', 'ET_SSITC_TEST', 'H', 'H_SSITC_TEST', 'FETCH_MAX', 'FETCH_90', 'FETCH_55', 'FETCH_40', 'WD', 'WS', 'WS_MAX', 'USTAR', 'ZL', 'TAU', 'TAU_SSITC_TEST', 'MO_LENGTH', 'U', 'U_SIGMA', 'V', 'V_SIGMA', 'W', 'W_SIGMA', 'PA', 'TA_1_1_1', 'RH_1_1_1', 'T_DP_1_1_1', 'TA_1_1_2', 'RH_1_1_2', 'T_DP_1_1_2', 'VPD', 'T_SONIC', 'T_SONIC_SIGMA', 'PBLH', 'ALB', 'NETRAD', 'SW_IN', 'SW_OUT', 'LW_IN', 'LW_OUT']
# DEBUG [2025-06-16 17:09:41] __main__ – Skip rows for set to 0
# DEBUG [2025-06-16 17:09:41] __main__ – Reading G:\Shared drives\UGS_Flux\Data_Downloads\Phrag\8441_Flux_AmeriFluxFormat_1.dat
# INFO [2025-06-16 17:09:41] __main__ – Processing file: G:\Shared drives\UGS_Flux\Data_Downloads\Phrag\8441_Flux_AmeriFluxFormat_0.dat
# DEBUG [2025-06-16 17:09:41] __main__ – 0 -> 8441
# DEBUG [2025-06-16 17:09:41] __main__ – Header row detected: ['TIMESTAMP_START', 'TIMESTAMP_END', 'CO2', 'CO2_SIGMA', 'H2O', 'H2O_SIGMA', 'FC', 'FC_SSITC_TEST', 'LE', 'LE_SSITC_TEST', 'ET', 'ET_SSITC_TEST', 'H', 'H_SSITC_TEST', 'FETCH_MAX', 'FETCH_90', 'FETCH_55', 'FETCH_40', 'WD', 'WS', 'WS_MAX', 'USTAR', 'ZL', 'TAU', 'TAU_SSITC_TEST', 'MO_LENGTH', 'U', 'U_SIGMA', 'V', 'V_SIGMA', 'W', 'W_SIGMA', 'PA', 'TA_1_1_1', 'RH_1_1_1', 'T_DP_1_1_1', 'TA_1_1_2', 'RH_1_1_2', 'T_DP_1_1_2', 'VPD', 'T_SONIC', 'T_SONIC_SIGMA', 'PBLH', 'ALB', 'NETRAD', 'SW_IN', 'SW_OUT', 'LW_IN', 'LW_OUT']
# DEBUG [2025-06-16 17:09:41] __main__ – Skip rows for set to 0
# DEBUG [2025-06-16 17:09:41] __main__ – Reading G:\Shared drives\UGS_Flux\Data_Downloads\Phrag\8441_Flux_AmeriFluxFormat_0.dat
# INFO [2025-06-16 17:09:41] __main__ – Processing file: G:\Shared drives\UGS_Flux\Data_Downloads\Phrag\8441_Flux_AmeriFluxFormat_2.dat
# DEBUG [2025-06-16 17:09:41] __main__ – 2 -> 8441
# DEBUG [2025-06-16 17:09:41] __main__ – Header row detected: ['TIMESTAMP_START', 'TIMESTAMP_END', 'CO2', 'CO2_SIGMA', 'H2O', 'H2O_SIGMA', 'FC', 'FC_SSITC_TEST', 'LE', 'LE_SSITC_TEST', 'ET', 'ET_SSITC_TEST', 'H', 'H_SSITC_TEST', 'FETCH_MAX', 'FETCH_90', 'FETCH_55', 'FETCH_40', 'WD', 'WS', 'WS_MAX', 'USTAR', 'ZL', 'TAU', 'TAU_SSITC_TEST', 'MO_LENGTH', 'U', 'U_SIGMA', 'V', 'V_SIGMA', 'W', 'W_SIGMA', 'PA', 'TA_1_1_1', 'RH_1_1_1', 'T_DP_1_1_1', 'TA_1_1_2', 'RH_1_1_2', 'T_DP_1_1_2', 'VPD', 'T_SONIC', 'T_SONIC_SIGMA', 'PBLH', 'ALB', 'NETRAD', 'SW_IN', 'SW_OUT', 'LW_IN', 'LW_OUT']
# DEBUG [2025-06-16 17:09:41] __main__ – Skip rows for set to 0
# DEBUG [2025-06-16 17:09:41] __main__ – Reading G:\Shared drives\UGS_Flux\Data_Downloads\Phrag\8441_Flux_AmeriFluxFormat_2.dat
# ✔ All possible files have been checked.
# INFO [2025-06-16 17:09:41] __main__ – Processing file: G:\Shared drives\UGS_Flux\Data_Downloads\Phrag\8441_Flux_AmeriFluxFormat_3.dat
# DEBUG [2025-06-16 17:09:41] __main__ – 3 -> 8441
# DEBUG [2025-06-16 17:09:41] __main__ – Header row detected: ['TIMESTAMP_START', 'TIMESTAMP_END', 'CO2', 'CO2_SIGMA', 'H2O', 'H2O_SIGMA', 'FC', 'FC_SSITC_TEST', 'LE', 'LE_SSITC_TEST', 'ET', 'ET_SSITC_TEST', 'H', 'H_SSITC_TEST', 'FETCH_MAX', 'FETCH_90', 'FETCH_55', 'FETCH_40', 'WD', 'WS', 'WS_MAX', 'USTAR', 'ZL', 'TAU', 'TAU_SSITC_TEST', 'MO_LENGTH', 'U', 'U_SIGMA', 'V', 'V_SIGMA', 'W', 'W_SIGMA', 'PA', 'TA_1_1_1', 'RH_1_1_1', 'T_DP_1_1_1', 'TA_1_1_2', 'RH_1_1_2', 'T_DP_1_1_2', 'VPD', 'T_SONIC', 'T_SONIC_SIGMA', 'PBLH', 'ALB', 'NETRAD', 'SW_IN', 'SW_OUT', 'LW_IN', 'LW_OUT']
# DEBUG [2025-06-16 17:09:41] __main__ – Skip rows for set to 0
# DEBUG [2025-06-16 17:09:41] __main__ – Reading G:\Shared drives\UGS_Flux\Data_Downloads\Phrag\8441_Flux_AmeriFluxFormat_3.dat
# INFO [2025-06-16 17:09:41] __main__ – Processing file: G:\Shared drives\UGS_Flux\Data_Downloads\Phrag\New folder\8442_Flux_AmeriFluxFormat_0.dat
# DEBUG [2025-06-16 17:09:41] __main__ – 0 -> 8442
# DEBUG [2025-06-16 17:09:41] __main__ – Header row detected: ['TIMESTAMP_START', 'TIMESTAMP_END', 'CO2', 'CO2_SIGMA', 'H2O', 'H2O_SIGMA', 'FC', 'FC_SSITC_TEST', 'LE', 'LE_SSITC_TEST', 'ET', 'ET_SSITC_TEST', 'H', 'H_SSITC_TEST', 'G', 'SG', 'FETCH_MAX', 'FETCH_90', 'FETCH_55', 'FETCH_40', 'WD', 'WS', 'WS_MAX', 'USTAR', 'ZL', 'TAU', 'TAU_SSITC_TEST', 'MO_LENGTH', 'U', 'U_SIGMA', 'V', 'V_SIGMA', 'W', 'W_SIGMA', 'PA', 'TA_1_1_1', 'RH_1_1_1', 'T_DP_1_1_1', 'TA_1_1_2', 'RH_1_1_2', 'T_DP_1_1_2', 'TA_1_1_3', 'RH_1_1_3', 'T_DP_1_1_3', 'VPD', 'T_SONIC', 'T_SONIC_SIGMA', 'PBLH', 'TS_1_1_1', 'SWC_1_1_1', 'ALB', 'NETRAD', 'SW_IN', 'SW_OUT', 'LW_IN', 'LW_OUT', 'P']
# DEBUG [2025-06-16 17:09:41] __main__ – Skip rows for set to 0
# DEBUG [2025-06-16 17:09:41] __main__ – Reading G:\Shared drives\UGS_Flux\Data_Downloads\Phrag\New folder\8442_Flux_AmeriFluxFormat_0.dat
# INFO [2025-06-16 17:09:41] __main__ – Processing file: G:\Shared drives\UGS_Flux\Data_Downloads\Phrag\New folder\8442_Flux_AmeriFluxFormat_1.dat
# DEBUG [2025-06-16 17:09:41] __main__ – 1 -> 8442
# DEBUG [2025-06-16 17:09:41] __main__ – Header row detected: ['TIMESTAMP_START', 'TIMESTAMP_END', 'CO2', 'CO2_SIGMA', 'H2O', 'H2O_SIGMA', 'FC', 'FC_SSITC_TEST', 'LE', 'LE_SSITC_TEST', 'ET', 'ET_SSITC_TEST', 'H', 'H_SSITC_TEST', 'G', 'SG', 'FETCH_MAX', 'FETCH_90', 'FETCH_55', 'FETCH_40', 'WD', 'WS', 'WS_MAX', 'USTAR', 'ZL', 'TAU', 'TAU_SSITC_TEST', 'MO_LENGTH', 'U', 'U_SIGMA', 'V', 'V_SIGMA', 'W', 'W_SIGMA', 'PA', 'TA_1_1_1', 'RH_1_1_1', 'T_DP_1_1_1', 'TA_1_1_2', 'RH_1_1_2', 'T_DP_1_1_2', 'TA_1_1_3', 'RH_1_1_3', 'T_DP_1_1_3', 'VPD', 'T_SONIC', 'T_SONIC_SIGMA', 'PBLH', 'TS_1_1_1', 'SWC_1_1_1', 'ALB', 'NETRAD', 'SW_IN', 'SW_OUT', 'LW_IN', 'LW_OUT', 'P']
# DEBUG [2025-06-16 17:09:41] __main__ – Skip rows for set to 0
# DEBUG [2025-06-16 17:09:41] __main__ – Reading G:\Shared drives\UGS_Flux\Data_Downloads\Phrag\New folder\8442_Flux_AmeriFluxFormat_1.dat
# INFO [2025-06-16 17:09:41] __main__ – Processing file: G:\Shared drives\UGS_Flux\Data_Downloads\Phrag\New folder\8442_Flux_AmeriFluxFormat_2.dat
# DEBUG [2025-06-16 17:09:41] __main__ – 2 -> 8442
# DEBUG [2025-06-16 17:09:41] __main__ – Header row detected: ['TIMESTAMP_START', 'TIMESTAMP_END', 'CO2', 'CO2_SIGMA', 'H2O', 'H2O_SIGMA', 'FC', 'FC_SSITC_TEST', 'LE', 'LE_SSITC_TEST', 'ET', 'ET_SSITC_TEST', 'H', 'H_SSITC_TEST', 'G', 'SG', 'FETCH_MAX', 'FETCH_90', 'FETCH_55', 'FETCH_40', 'WD', 'WS', 'WS_MAX', 'USTAR', 'ZL', 'TAU', 'TAU_SSITC_TEST', 'MO_LENGTH', 'U', 'U_SIGMA', 'V', 'V_SIGMA', 'W', 'W_SIGMA', 'PA', 'TA_1_1_1', 'RH_1_1_1', 'T_DP_1_1_1', 'TA_1_1_2', 'RH_1_1_2', 'T_DP_1_1_2', 'TA_1_1_3', 'RH_1_1_3', 'T_DP_1_1_3', 'VPD', 'T_SONIC', 'T_SONIC_SIGMA', 'PBLH', 'TS_1_1_1', 'SWC_1_1_1', 'ALB', 'NETRAD', 'SW_IN', 'SW_OUT', 'LW_IN', 'LW_OUT', 'P']
# DEBUG [2025-06-16 17:09:41] __main__ – Skip rows for set to 0
# DEBUG [2025-06-16 17:09:41] __main__ – Reading G:\Shared drives\UGS_Flux\Data_Downloads\Phrag\New folder\8442_Flux_AmeriFluxFormat_2.dat
# INFO [2025-06-16 17:09:41] __main__ – Processing file: G:\Shared drives\UGS_Flux\Data_Downloads\Phrag\New folder\8442_Flux_AmeriFluxFormat_3.dat
# DEBUG [2025-06-16 17:09:41] __main__ – 3 -> 8442
# DEBUG [2025-06-16 17:09:41] __main__ – Header row detected: ['TIMESTAMP_START', 'TIMESTAMP_END', 'CO2', 'CO2_SIGMA', 'H2O', 'H2O_SIGMA', 'FC', 'FC_SSITC_TEST', 'LE', 'LE_SSITC_TEST', 'ET', 'ET_SSITC_TEST', 'H', 'H_SSITC_TEST', 'G', 'SG', 'FETCH_MAX', 'FETCH_90', 'FETCH_55', 'FETCH_40', 'WD', 'WS', 'WS_MAX', 'USTAR', 'ZL', 'TAU', 'TAU_SSITC_TEST', 'MO_LENGTH', 'U', 'U_SIGMA', 'V', 'V_SIGMA', 'W', 'W_SIGMA', 'PA', 'TA_1_1_1', 'RH_1_1_1', 'T_DP_1_1_1', 'TA_1_1_2', 'RH_1_1_2', 'T_DP_1_1_2', 'TA_1_1_3', 'RH_1_1_3', 'T_DP_1_1_3', 'VPD', 'T_SONIC', 'T_SONIC_SIGMA', 'PBLH', 'TS_1_1_1', 'SWC_1_1_1', 'ALB', 'NETRAD', 'SW_IN', 'SW_OUT', 'LW_IN', 'LW_OUT', 'P']
# DEBUG [2025-06-16 17:09:41] __main__ – Skip rows for set to 0
# DEBUG [2025-06-16 17:09:41] __main__ – Reading G:\Shared drives\UGS_Flux\Data_Downloads\Phrag\New folder\8442_Flux_AmeriFluxFormat_3.dat
# INFO [2025-06-16 17:09:41] __main__ – Processing file: G:\Shared drives\UGS_Flux\Data_Downloads\Phrag\New folder\8442_Flux_AmeriFluxFormat_5.dat
# DEBUG [2025-06-16 17:09:41] __main__ – 5 -> 8442
# DEBUG [2025-06-16 17:09:41] __main__ – Header row detected: ['TIMESTAMP_START', 'TIMESTAMP_END', 'CO2', 'CO2_SIGMA', 'H2O', 'H2O_SIGMA', 'FC', 'FC_SSITC_TEST', 'LE', 'LE_SSITC_TEST', 'ET', 'ET_SSITC_TEST', 'H', 'H_SSITC_TEST', 'G', 'SG', 'FETCH_MAX', 'FETCH_90', 'FETCH_55', 'FETCH_40', 'WD', 'WS', 'WS_MAX', 'USTAR', 'ZL', 'TAU', 'TAU_SSITC_TEST', 'MO_LENGTH', 'U', 'U_SIGMA', 'V', 'V_SIGMA', 'W', 'W_SIGMA', 'PA', 'TA_1_1_1', 'RH_1_1_1', 'T_DP_1_1_1', 'TA_1_1_2', 'RH_1_1_2', 'T_DP_1_1_2', 'TA_1_1_3', 'RH_1_1_3', 'T_DP_1_1_3', 'VPD', 'T_SONIC', 'T_SONIC_SIGMA', 'PBLH', 'TS_1_1_1', 'SWC_1_1_1', 'ALB', 'NETRAD', 'SW_IN', 'SW_OUT', 'LW_IN', 'LW_OUT', 'P']
# DEBUG [2025-06-16 17:09:41] __main__ – Skip rows for set to 0
# DEBUG [2025-06-16 17:09:41] __main__ – Reading G:\Shared drives\UGS_Flux\Data_Downloads\Phrag\New folder\8442_Flux_AmeriFluxFormat_5.dat
# INFO [2025-06-16 17:09:41] __main__ – Processing file: G:\Shared drives\UGS_Flux\Data_Downloads\Phrag\New folder\8442_Flux_AmeriFluxFormat_6.dat
# DEBUG [2025-06-16 17:09:41] __main__ – 6 -> 8442
# DEBUG [2025-06-16 17:09:41] __main__ – Header row detected: ['TIMESTAMP_START', 'TIMESTAMP_END', 'CO2', 'CO2_SIGMA', 'H2O', 'H2O_SIGMA', 'FC', 'FC_SSITC_TEST', 'LE', 'LE_SSITC_TEST', 'ET', 'ET_SSITC_TEST', 'H', 'H_SSITC_TEST', 'G', 'SG', 'FETCH_MAX', 'FETCH_90', 'FETCH_55', 'FETCH_40', 'WD', 'WS', 'WS_MAX', 'USTAR', 'ZL', 'TAU', 'TAU_SSITC_TEST', 'MO_LENGTH', 'U', 'U_SIGMA', 'V', 'V_SIGMA', 'W', 'W_SIGMA', 'PA', 'TA_1_1_1', 'RH_1_1_1', 'T_DP_1_1_1', 'TA_1_1_2', 'RH_1_1_2', 'T_DP_1_1_2', 'TA_1_1_3', 'RH_1_1_3', 'T_DP_1_1_3', 'VPD', 'T_SONIC', 'T_SONIC_SIGMA', 'PBLH', 'TS_1_1_1', 'SWC_1_1_1', 'ALB', 'NETRAD', 'SW_IN', 'SW_OUT', 'LW_IN', 'LW_OUT', 'P']
# DEBUG [2025-06-16 17:09:41] __main__ – Skip rows for set to 0
# DEBUG [2025-06-16 17:09:41] __main__ – Reading G:\Shared drives\UGS_Flux\Data_Downloads\Phrag\New folder\8442_Flux_AmeriFluxFormat_6.dat
# INFO [2025-06-16 17:09:41] __main__ – Processing file: G:\Shared drives\UGS_Flux\Data_Downloads\Phrag\New folder\8442_Flux_AmeriFluxFormat_4.dat
# DEBUG [2025-06-16 17:09:41] __main__ – 4 -> 8442
# DEBUG [2025-06-16 17:09:41] __main__ – Header row detected: ['TIMESTAMP_START', 'TIMESTAMP_END', 'CO2', 'CO2_SIGMA', 'H2O', 'H2O_SIGMA', 'FC', 'FC_SSITC_TEST', 'LE', 'LE_SSITC_TEST', 'ET', 'ET_SSITC_TEST', 'H', 'H_SSITC_TEST', 'G', 'SG', 'FETCH_MAX', 'FETCH_90', 'FETCH_55', 'FETCH_40', 'WD', 'WS', 'WS_MAX', 'USTAR', 'ZL', 'TAU', 'TAU_SSITC_TEST', 'MO_LENGTH', 'U', 'U_SIGMA', 'V', 'V_SIGMA', 'W', 'W_SIGMA', 'PA', 'TA_1_1_1', 'RH_1_1_1', 'T_DP_1_1_1', 'TA_1_1_2', 'RH_1_1_2', 'T_DP_1_1_2', 'TA_1_1_3', 'RH_1_1_3', 'T_DP_1_1_3', 'VPD', 'T_SONIC', 'T_SONIC_SIGMA', 'PBLH', 'TS_1_1_1', 'SWC_1_1_1', 'ALB', 'NETRAD', 'SW_IN', 'SW_OUT', 'LW_IN', 'LW_OUT', 'P']
# DEBUG [2025-06-16 17:09:41] __main__ – Skip rows for set to 0
# DEBUG [2025-06-16 17:09:41] __main__ – Reading G:\Shared drives\UGS_Flux\Data_Downloads\Phrag\New folder\8442_Flux_AmeriFluxFormat_4.dat
# INFO [2025-06-16 17:09:41] __main__ – Processing file: G:\Shared drives\UGS_Flux\Data_Downloads\Phrag\New folder\8442_Flux_AmeriFluxFormat_7.dat
# DEBUG [2025-06-16 17:09:41] __main__ – 7 -> 8442
# DEBUG [2025-06-16 17:09:41] __main__ – Header row detected: ['TIMESTAMP_START', 'TIMESTAMP_END', 'CO2', 'CO2_SIGMA', 'H2O', 'H2O_SIGMA', 'FC', 'FC_SSITC_TEST', 'LE', 'LE_SSITC_TEST', 'ET', 'ET_SSITC_TEST', 'H', 'H_SSITC_TEST', 'G', 'SG', 'FETCH_MAX', 'FETCH_90', 'FETCH_55', 'FETCH_40', 'WD', 'WS', 'WS_MAX', 'USTAR', 'ZL', 'TAU', 'TAU_SSITC_TEST', 'MO_LENGTH', 'U', 'U_SIGMA', 'V', 'V_SIGMA', 'W', 'W_SIGMA', 'PA', 'TA_1_1_1', 'RH_1_1_1', 'T_DP_1_1_1', 'TA_1_1_2', 'RH_1_1_2', 'T_DP_1_1_2', 'TA_1_1_3', 'RH_1_1_3', 'T_DP_1_1_3', 'VPD', 'T_SONIC', 'T_SONIC_SIGMA', 'PBLH', 'TS_1_1_1', 'SWC_1_1_1', 'ALB', 'NETRAD', 'SW_IN', 'SW_OUT', 'LW_IN', 'LW_OUT', 'P']
# DEBUG [2025-06-16 17:09:41] __main__ – Skip rows for set to 0
# DEBUG [2025-06-16 17:09:41] __main__ – Reading G:\Shared drives\UGS_Flux\Data_Downloads\Phrag\New folder\8442_Flux_AmeriFluxFormat_7.dat
# INFO [2025-06-16 17:09:41] __main__ – Processing file: G:\Shared drives\UGS_Flux\Data_Downloads\Phrag\e20250210\8442_Flux_AmeriFluxFormat_45.dat
# DEBUG [2025-06-16 17:09:41] __main__ – 45 -> 8442
# DEBUG [2025-06-16 17:09:41] __main__ – Header row detected: ['TIMESTAMP_START', 'TIMESTAMP_END', 'CO2', 'CO2_SIGMA', 'H2O', 'H2O_SIGMA', 'CH4', 'FC', 'FC_SSITC_TEST', 'FCH4', 'FCH4_SSITC_TEST', 'LE', 'LE_SSITC_TEST', 'ET', 'ET_SSITC_TEST', 'H', 'H_SSITC_TEST', 'G', 'SG', 'FETCH_MAX', 'FETCH_90', 'FETCH_55', 'FETCH_40', 'WD', 'WS', 'WS_MAX', 'USTAR', 'ZL', 'TAU', 'TAU_SSITC_TEST', 'MO_LENGTH', 'U', 'U_SIGMA', 'V', 'V_SIGMA', 'W', 'W_SIGMA', 'PA', 'TA_1_1_1', 'RH_1_1_1', 'T_DP_1_1_1', 'TA_1_1_2', 'RH_1_1_2', 'T_DP_1_1_2', 'TA_1_1_3', 'RH_1_1_3', 'T_DP_1_1_3', 'VPD', 'T_SONIC', 'T_SONIC_SIGMA', 'PBLH', 'TS_1_1_1', 'TS_1_1_2', 'SWC_1_1_1', 'SWC_1_1_2', 'ALB', 'NETRAD', 'SW_IN', 'SW_OUT', 'LW_IN', 'LW_OUT', 'P']
# DEBUG [2025-06-16 17:09:41] __main__ – Skip rows for set to 0
# DEBUG [2025-06-16 17:09:41] __main__ – Reading G:\Shared drives\UGS_Flux\Data_Downloads\Phrag\e20250210\8442_Flux_AmeriFluxFormat_45.dat
# INFO [2025-06-16 17:09:41] __main__ – Processing file: G:\Shared drives\UGS_Flux\Data_Downloads\Phrag\e20250210\8442_Flux_AmeriFluxFormat_44.dat
# DEBUG [2025-06-16 17:09:41] __main__ – 44 -> 8442
# DEBUG [2025-06-16 17:09:41] __main__ – Header row detected: ['TIMESTAMP_START', 'TIMESTAMP_END', 'CO2', 'CO2_SIGMA', 'H2O', 'H2O_SIGMA', 'CH4', 'FC', 'FC_SSITC_TEST', 'FCH4', 'FCH4_SSITC_TEST', 'LE', 'LE_SSITC_TEST', 'ET', 'ET_SSITC_TEST', 'H', 'H_SSITC_TEST', 'G', 'SG', 'FETCH_MAX', 'FETCH_90', 'FETCH_55', 'FETCH_40', 'WD', 'WS', 'WS_MAX', 'USTAR', 'ZL', 'TAU', 'TAU_SSITC_TEST', 'MO_LENGTH', 'U', 'U_SIGMA', 'V', 'V_SIGMA', 'W', 'W_SIGMA', 'PA', 'TA_1_1_1', 'RH_1_1_1', 'T_DP_1_1_1', 'TA_1_1_2', 'RH_1_1_2', 'T_DP_1_1_2', 'TA_1_1_3', 'RH_1_1_3', 'T_DP_1_1_3', 'VPD', 'T_SONIC', 'T_SONIC_SIGMA', 'PBLH', 'TS_1_1_1', 'TS_1_1_2', 'SWC_1_1_1', 'SWC_1_1_2', 'ALB', 'NETRAD', 'SW_IN', 'SW_OUT', 'LW_IN', 'LW_OUT', 'P']
# DEBUG [2025-06-16 17:09:41] __main__ – Skip rows for set to 0
# DEBUG [2025-06-16 17:09:41] __main__ – Reading G:\Shared drives\UGS_Flux\Data_Downloads\Phrag\e20250210\8442_Flux_AmeriFluxFormat_44.dat
# INFO [2025-06-16 17:09:41] __main__ – Processing file: G:\Shared drives\UGS_Flux\Data_Downloads\Phrag\e20250210\8442_Flux_AmeriFluxFormat_42.dat
# DEBUG [2025-06-16 17:09:41] __main__ – 42 -> 8442
# DEBUG [2025-06-16 17:09:41] __main__ – Header row detected: ['TIMESTAMP_START', 'TIMESTAMP_END', 'CO2', 'CO2_SIGMA', 'H2O', 'H2O_SIGMA', 'CH4', 'FC', 'FC_SSITC_TEST', 'FCH4', 'FCH4_SSITC_TEST', 'LE', 'LE_SSITC_TEST', 'ET', 'ET_SSITC_TEST', 'H', 'H_SSITC_TEST', 'G', 'SG', 'FETCH_MAX', 'FETCH_90', 'FETCH_55', 'FETCH_40', 'WD', 'WS', 'WS_MAX', 'USTAR', 'ZL', 'TAU', 'TAU_SSITC_TEST', 'MO_LENGTH', 'U', 'U_SIGMA', 'V', 'V_SIGMA', 'W', 'W_SIGMA', 'PA', 'TA_1_1_1', 'RH_1_1_1', 'T_DP_1_1_1', 'TA_1_1_2', 'RH_1_1_2', 'T_DP_1_1_2', 'TA_1_1_3', 'RH_1_1_3', 'T_DP_1_1_3', 'VPD', 'T_SONIC', 'T_SONIC_SIGMA', 'PBLH', 'TS_1_1_1', 'TS_1_1_2', 'SWC_1_1_1', 'SWC_1_1_2', 'ALB', 'NETRAD', 'SW_IN', 'SW_OUT', 'LW_IN', 'LW_OUT', 'P']
# DEBUG [2025-06-16 17:09:41] __main__ – Skip rows for set to 0
# DEBUG [2025-06-16 17:09:41] __main__ – Reading G:\Shared drives\UGS_Flux\Data_Downloads\Phrag\e20250210\8442_Flux_AmeriFluxFormat_42.dat
# INFO [2025-06-16 17:09:41] __main__ – Processing file: G:\Shared drives\UGS_Flux\Data_Downloads\Phrag\e20250210\8442_Flux_AmeriFluxFormat_40.dat
# DEBUG [2025-06-16 17:09:41] __main__ – 40 -> 8442
# DEBUG [2025-06-16 17:09:41] __main__ – Header row detected: ['TIMESTAMP_START', 'TIMESTAMP_END', 'CO2', 'CO2_SIGMA', 'H2O', 'H2O_SIGMA', 'CH4', 'FC', 'FC_SSITC_TEST', 'FCH4', 'FCH4_SSITC_TEST', 'LE', 'LE_SSITC_TEST', 'ET', 'ET_SSITC_TEST', 'H', 'H_SSITC_TEST', 'G', 'SG', 'FETCH_MAX', 'FETCH_90', 'FETCH_55', 'FETCH_40', 'WD', 'WS', 'WS_MAX', 'USTAR', 'ZL', 'TAU', 'TAU_SSITC_TEST', 'MO_LENGTH', 'U', 'U_SIGMA', 'V', 'V_SIGMA', 'W', 'W_SIGMA', 'PA', 'TA_1_1_1', 'RH_1_1_1', 'T_DP_1_1_1', 'TA_1_1_2', 'RH_1_1_2', 'T_DP_1_1_2', 'TA_1_1_3', 'RH_1_1_3', 'T_DP_1_1_3', 'VPD', 'T_SONIC', 'T_SONIC_SIGMA', 'PBLH', 'TS_1_1_1', 'TS_1_1_2', 'SWC_1_1_1', 'SWC_1_1_2', 'ALB', 'NETRAD', 'SW_IN', 'SW_OUT', 'LW_IN', 'LW_OUT', 'P']
# DEBUG [2025-06-16 17:09:41] __main__ – Skip rows for set to 0
# DEBUG [2025-06-16 17:09:41] __main__ – Reading G:\Shared drives\UGS_Flux\Data_Downloads\Phrag\e20250210\8442_Flux_AmeriFluxFormat_40.dat
# INFO [2025-06-16 17:09:41] __main__ – Processing file: G:\Shared drives\UGS_Flux\Data_Downloads\Phrag\e20250210\8442_Flux_AmeriFluxFormat_43.dat
# DEBUG [2025-06-16 17:09:41] __main__ – 43 -> 8442
# DEBUG [2025-06-16 17:09:41] __main__ – Header row detected: ['TIMESTAMP_START', 'TIMESTAMP_END', 'CO2', 'CO2_SIGMA', 'H2O', 'H2O_SIGMA', 'CH4', 'FC', 'FC_SSITC_TEST', 'FCH4', 'FCH4_SSITC_TEST', 'LE', 'LE_SSITC_TEST', 'ET', 'ET_SSITC_TEST', 'H', 'H_SSITC_TEST', 'G', 'SG', 'FETCH_MAX', 'FETCH_90', 'FETCH_55', 'FETCH_40', 'WD', 'WS', 'WS_MAX', 'USTAR', 'ZL', 'TAU', 'TAU_SSITC_TEST', 'MO_LENGTH', 'U', 'U_SIGMA', 'V', 'V_SIGMA', 'W', 'W_SIGMA', 'PA', 'TA_1_1_1', 'RH_1_1_1', 'T_DP_1_1_1', 'TA_1_1_2', 'RH_1_1_2', 'T_DP_1_1_2', 'TA_1_1_3', 'RH_1_1_3', 'T_DP_1_1_3', 'VPD', 'T_SONIC', 'T_SONIC_SIGMA', 'PBLH', 'TS_1_1_1', 'TS_1_1_2', 'SWC_1_1_1', 'SWC_1_1_2', 'ALB', 'NETRAD', 'SW_IN', 'SW_OUT', 'LW_IN', 'LW_OUT', 'P']
# DEBUG [2025-06-16 17:09:41] __main__ – Skip rows for set to 0
# DEBUG [2025-06-16 17:09:41] __main__ – Reading G:\Shared drives\UGS_Flux\Data_Downloads\Phrag\e20250210\8442_Flux_AmeriFluxFormat_43.dat
# INFO [2025-06-16 17:09:41] __main__ – Processing file: G:\Shared drives\UGS_Flux\Data_Downloads\Phrag\e20250210\8442_Flux_AmeriFluxFormat_41.dat
# DEBUG [2025-06-16 17:09:41] __main__ – 41 -> 8442
# DEBUG [2025-06-16 17:09:41] __main__ – Header row detected: ['TIMESTAMP_START', 'TIMESTAMP_END', 'CO2', 'CO2_SIGMA', 'H2O', 'H2O_SIGMA', 'CH4', 'FC', 'FC_SSITC_TEST', 'FCH4', 'FCH4_SSITC_TEST', 'LE', 'LE_SSITC_TEST', 'ET', 'ET_SSITC_TEST', 'H', 'H_SSITC_TEST', 'G', 'SG', 'FETCH_MAX', 'FETCH_90', 'FETCH_55', 'FETCH_40', 'WD', 'WS', 'WS_MAX', 'USTAR', 'ZL', 'TAU', 'TAU_SSITC_TEST', 'MO_LENGTH', 'U', 'U_SIGMA', 'V', 'V_SIGMA', 'W', 'W_SIGMA', 'PA', 'TA_1_1_1', 'RH_1_1_1', 'T_DP_1_1_1', 'TA_1_1_2', 'RH_1_1_2', 'T_DP_1_1_2', 'TA_1_1_3', 'RH_1_1_3', 'T_DP_1_1_3', 'VPD', 'T_SONIC', 'T_SONIC_SIGMA', 'PBLH', 'TS_1_1_1', 'TS_1_1_2', 'SWC_1_1_1', 'SWC_1_1_2', 'ALB', 'NETRAD', 'SW_IN', 'SW_OUT', 'LW_IN', 'LW_OUT', 'P']
# DEBUG [2025-06-16 17:09:41] __main__ – Skip rows for set to 0
# DEBUG [2025-06-16 17:09:41] __main__ – Reading G:\Shared drives\UGS_Flux\Data_Downloads\Phrag\e20250210\8442_Flux_AmeriFluxFormat_41.dat
# INFO [2025-06-16 17:09:41] __main__ – Processing file: G:\Shared drives\UGS_Flux\Data_Downloads\Phrag\e20250210\8442_Flux_AmeriFluxFormat_39.dat
# DEBUG [2025-06-16 17:09:41] __main__ – 39 -> 8442
# DEBUG [2025-06-16 17:09:41] __main__ – Header row detected: ['TIMESTAMP_START', 'TIMESTAMP_END', 'CO2', 'CO2_SIGMA', 'H2O', 'H2O_SIGMA', 'CH4', 'FC', 'FC_SSITC_TEST', 'FCH4', 'FCH4_SSITC_TEST', 'LE', 'LE_SSITC_TEST', 'ET', 'ET_SSITC_TEST', 'H', 'H_SSITC_TEST', 'G', 'SG', 'FETCH_MAX', 'FETCH_90', 'FETCH_55', 'FETCH_40', 'WD', 'WS', 'WS_MAX', 'USTAR', 'ZL', 'TAU', 'TAU_SSITC_TEST', 'MO_LENGTH', 'U', 'U_SIGMA', 'V', 'V_SIGMA', 'W', 'W_SIGMA', 'PA', 'TA_1_1_1', 'RH_1_1_1', 'T_DP_1_1_1', 'TA_1_1_2', 'RH_1_1_2', 'T_DP_1_1_2', 'TA_1_1_3', 'RH_1_1_3', 'T_DP_1_1_3', 'VPD', 'T_SONIC', 'T_SONIC_SIGMA', 'PBLH', 'TS_1_1_1', 'TS_1_1_2', 'SWC_1_1_1', 'SWC_1_1_2', 'ALB', 'NETRAD', 'SW_IN', 'SW_OUT', 'LW_IN', 'LW_OUT', 'P']
# DEBUG [2025-06-16 17:09:41] __main__ – Skip rows for set to 0
# DEBUG [2025-06-16 17:09:41] __main__ – Reading G:\Shared drives\UGS_Flux\Data_Downloads\Phrag\e20250210\8442_Flux_AmeriFluxFormat_39.dat
# INFO [2025-06-16 17:09:42] __main__ – Processing file: G:\Shared drives\UGS_Flux\Data_Downloads\Phrag\e20250210\8442_Flux_AmeriFluxFormat_38.dat
# DEBUG [2025-06-16 17:09:42] __main__ – 38 -> 8442
# DEBUG [2025-06-16 17:09:42] __main__ – Header row detected: ['TIMESTAMP_START', 'TIMESTAMP_END', 'CO2', 'CO2_SIGMA', 'H2O', 'H2O_SIGMA', 'CH4', 'FC', 'FC_SSITC_TEST', 'FCH4', 'FCH4_SSITC_TEST', 'LE', 'LE_SSITC_TEST', 'ET', 'ET_SSITC_TEST', 'H', 'H_SSITC_TEST', 'G', 'SG', 'FETCH_MAX', 'FETCH_90', 'FETCH_55', 'FETCH_40', 'WD', 'WS', 'WS_MAX', 'USTAR', 'ZL', 'TAU', 'TAU_SSITC_TEST', 'MO_LENGTH', 'U', 'U_SIGMA', 'V', 'V_SIGMA', 'W', 'W_SIGMA', 'PA', 'TA_1_1_1', 'RH_1_1_1', 'T_DP_1_1_1', 'TA_1_1_2', 'RH_1_1_2', 'T_DP_1_1_2', 'TA_1_1_3', 'RH_1_1_3', 'T_DP_1_1_3', 'VPD', 'T_SONIC', 'T_SONIC_SIGMA', 'PBLH', 'TS_1_1_1', 'TS_1_1_2', 'SWC_1_1_1', 'SWC_1_1_2', 'ALB', 'NETRAD', 'SW_IN', 'SW_OUT', 'LW_IN', 'LW_OUT', 'P']
# DEBUG [2025-06-16 17:09:42] __main__ – Skip rows for set to 0
# DEBUG [2025-06-16 17:09:42] __main__ – Reading G:\Shared drives\UGS_Flux\Data_Downloads\Phrag\e20250210\8442_Flux_AmeriFluxFormat_38.dat
# INFO [2025-06-16 17:09:42] __main__ – Processing file: G:\Shared drives\UGS_Flux\Data_Downloads\Phrag\m20250210\8441_Flux_AmeriFluxFormat_0.dat
# DEBUG [2025-06-16 17:09:42] __main__ – 0 -> 8441
# DEBUG [2025-06-16 17:09:42] __main__ – Header row detected: ['TIMESTAMP_START', 'TIMESTAMP_END', 'CO2', 'CO2_SIGMA', 'H2O', 'H2O_SIGMA', 'FC', 'FC_SSITC_TEST', 'LE', 'LE_SSITC_TEST', 'ET', 'ET_SSITC_TEST', 'H', 'H_SSITC_TEST', 'FETCH_MAX', 'FETCH_90', 'FETCH_55', 'FETCH_40', 'WD', 'WS', 'WS_MAX', 'USTAR', 'ZL', 'TAU', 'TAU_SSITC_TEST', 'MO_LENGTH', 'U', 'U_SIGMA', 'V', 'V_SIGMA', 'W', 'W_SIGMA', 'PA', 'TA_1_1_1', 'RH_1_1_1', 'T_DP_1_1_1', 'TA_1_1_2', 'RH_1_1_2', 'T_DP_1_1_2', 'VPD', 'T_SONIC', 'T_SONIC_SIGMA', 'PBLH', 'ALB', 'NETRAD', 'SW_IN', 'SW_OUT', 'LW_IN', 'LW_OUT']
# DEBUG [2025-06-16 17:09:42] __main__ – Skip rows for set to 0
# DEBUG [2025-06-16 17:09:42] __main__ – Reading G:\Shared drives\UGS_Flux\Data_Downloads\Phrag\m20250210\8441_Flux_AmeriFluxFormat_0.dat
# INFO [2025-06-16 17:09:42] __main__ – Processing file: G:\Shared drives\UGS_Flux\Data_Downloads\Phrag\m20250210\8441_Flux_AmeriFluxFormat_1.dat
# DEBUG [2025-06-16 17:09:42] __main__ – 1 -> 8441
# DEBUG [2025-06-16 17:09:42] __main__ – Header row detected: ['TIMESTAMP_START', 'TIMESTAMP_END', 'CO2', 'CO2_SIGMA', 'H2O', 'H2O_SIGMA', 'FC', 'FC_SSITC_TEST', 'LE', 'LE_SSITC_TEST', 'ET', 'ET_SSITC_TEST', 'H', 'H_SSITC_TEST', 'FETCH_MAX', 'FETCH_90', 'FETCH_55', 'FETCH_40', 'WD', 'WS', 'WS_MAX', 'USTAR', 'ZL', 'TAU', 'TAU_SSITC_TEST', 'MO_LENGTH', 'U', 'U_SIGMA', 'V', 'V_SIGMA', 'W', 'W_SIGMA', 'PA', 'TA_1_1_1', 'RH_1_1_1', 'T_DP_1_1_1', 'TA_1_1_2', 'RH_1_1_2', 'T_DP_1_1_2', 'VPD', 'T_SONIC', 'T_SONIC_SIGMA', 'PBLH', 'ALB', 'NETRAD', 'SW_IN', 'SW_OUT', 'LW_IN', 'LW_OUT']
# DEBUG [2025-06-16 17:09:42] __main__ – Skip rows for set to 0
# DEBUG [2025-06-16 17:09:42] __main__ – Reading G:\Shared drives\UGS_Flux\Data_Downloads\Phrag\m20250210\8441_Flux_AmeriFluxFormat_1.dat
# INFO [2025-06-16 17:09:43] __main__ – Processing file: G:\Shared drives\UGS_Flux\Data_Downloads\Phrag\m20250210\8441_Flux_AmeriFluxFormat_2.dat
# DEBUG [2025-06-16 17:09:43] __main__ – 2 -> 8441
# DEBUG [2025-06-16 17:09:43] __main__ – Header row detected: ['TIMESTAMP_START', 'TIMESTAMP_END', 'CO2', 'CO2_SIGMA', 'H2O', 'H2O_SIGMA', 'FC', 'FC_SSITC_TEST', 'LE', 'LE_SSITC_TEST', 'ET', 'ET_SSITC_TEST', 'H', 'H_SSITC_TEST', 'FETCH_MAX', 'FETCH_90', 'FETCH_55', 'FETCH_40', 'WD', 'WS', 'WS_MAX', 'USTAR', 'ZL', 'TAU', 'TAU_SSITC_TEST', 'MO_LENGTH', 'U', 'U_SIGMA', 'V', 'V_SIGMA', 'W', 'W_SIGMA', 'PA', 'TA_1_1_1', 'RH_1_1_1', 'T_DP_1_1_1', 'TA_1_1_2', 'RH_1_1_2', 'T_DP_1_1_2', 'VPD', 'T_SONIC', 'T_SONIC_SIGMA', 'PBLH', 'ALB', 'NETRAD', 'SW_IN', 'SW_OUT', 'LW_IN', 'LW_OUT']
# DEBUG [2025-06-16 17:09:43] __main__ – Skip rows for set to 0
# DEBUG [2025-06-16 17:09:43] __main__ – Reading G:\Shared drives\UGS_Flux\Data_Downloads\Phrag\m20250210\8441_Flux_AmeriFluxFormat_2.dat
# INFO [2025-06-16 17:09:43] __main__ – Processing file: G:\Shared drives\UGS_Flux\Data_Downloads\Phrag\m20250210\8441_Flux_AmeriFluxFormat_3.dat
# DEBUG [2025-06-16 17:09:43] __main__ – 3 -> 8441
# DEBUG [2025-06-16 17:09:43] __main__ – Header row detected: ['TIMESTAMP_START', 'TIMESTAMP_END', 'CO2', 'CO2_SIGMA', 'H2O', 'H2O_SIGMA', 'FC', 'FC_SSITC_TEST', 'LE', 'LE_SSITC_TEST', 'ET', 'ET_SSITC_TEST', 'H', 'H_SSITC_TEST', 'FETCH_MAX', 'FETCH_90', 'FETCH_55', 'FETCH_40', 'WD', 'WS', 'WS_MAX', 'USTAR', 'ZL', 'TAU', 'TAU_SSITC_TEST', 'MO_LENGTH', 'U', 'U_SIGMA', 'V', 'V_SIGMA', 'W', 'W_SIGMA', 'PA', 'TA_1_1_1', 'RH_1_1_1', 'T_DP_1_1_1', 'TA_1_1_2', 'RH_1_1_2', 'T_DP_1_1_2', 'VPD', 'T_SONIC', 'T_SONIC_SIGMA', 'PBLH', 'ALB', 'NETRAD', 'SW_IN', 'SW_OUT', 'LW_IN', 'LW_OUT']
# DEBUG [2025-06-16 17:09:43] __main__ – Skip rows for set to 0
# DEBUG [2025-06-16 17:09:43] __main__ – Reading G:\Shared drives\UGS_Flux\Data_Downloads\Phrag\m20250210\8441_Flux_AmeriFluxFormat_3.dat
# INFO [2025-06-16 17:09:43] __main__ – Processing file: G:\Shared drives\UGS_Flux\Data_Downloads\Phrag\e20250320\8442_Flux_AmeriFluxFormat_47.dat
# DEBUG [2025-06-16 17:09:43] __main__ – 47 -> 8442
# DEBUG [2025-06-16 17:09:43] __main__ – Header row detected: ['TIMESTAMP_START', 'TIMESTAMP_END', 'CO2', 'CO2_SIGMA', 'H2O', 'H2O_SIGMA', 'CH4', 'FC', 'FC_SSITC_TEST', 'FCH4', 'FCH4_SSITC_TEST', 'LE', 'LE_SSITC_TEST', 'ET', 'ET_SSITC_TEST', 'H', 'H_SSITC_TEST', 'G', 'SG', 'FETCH_MAX', 'FETCH_90', 'FETCH_55', 'FETCH_40', 'WD', 'WS', 'WS_MAX', 'USTAR', 'ZL', 'TAU', 'TAU_SSITC_TEST', 'MO_LENGTH', 'U', 'U_SIGMA', 'V', 'V_SIGMA', 'W', 'W_SIGMA', 'PA', 'TA_1_1_1', 'RH_1_1_1', 'T_DP_1_1_1', 'TA_1_1_2', 'RH_1_1_2', 'T_DP_1_1_2', 'TA_1_1_3', 'RH_1_1_3', 'T_DP_1_1_3', 'VPD', 'T_SONIC', 'T_SONIC_SIGMA', 'PBLH', 'TS_1_1_1', 'TS_1_1_2', 'SWC_1_1_1', 'SWC_1_1_2', 'ALB', 'NETRAD', 'SW_IN', 'SW_OUT', 'LW_IN', 'LW_OUT', 'P', 'Battery_Voltage', 'CO2_sig_strgth_Min', 'H2O_sig_strgth_Min']
# DEBUG [2025-06-16 17:09:43] __main__ – Skip rows for set to 0
# DEBUG [2025-06-16 17:09:43] __main__ – Reading G:\Shared drives\UGS_Flux\Data_Downloads\Phrag\e20250320\8442_Flux_AmeriFluxFormat_47.dat
# INFO [2025-06-16 17:09:45] __main__ – Processing file: G:\Shared drives\UGS_Flux\Data_Downloads\Phrag\e20250320\8442_Flux_AmeriFluxFormat_43.dat
# DEBUG [2025-06-16 17:09:45] __main__ – 43 -> 8442
# DEBUG [2025-06-16 17:09:45] __main__ – Header row detected: ['TIMESTAMP_START', 'TIMESTAMP_END', 'CO2', 'CO2_SIGMA', 'H2O', 'H2O_SIGMA', 'CH4', 'FC', 'FC_SSITC_TEST', 'FCH4', 'FCH4_SSITC_TEST', 'LE', 'LE_SSITC_TEST', 'ET', 'ET_SSITC_TEST', 'H', 'H_SSITC_TEST', 'G', 'SG', 'FETCH_MAX', 'FETCH_90', 'FETCH_55', 'FETCH_40', 'WD', 'WS', 'WS_MAX', 'USTAR', 'ZL', 'TAU', 'TAU_SSITC_TEST', 'MO_LENGTH', 'U', 'U_SIGMA', 'V', 'V_SIGMA', 'W', 'W_SIGMA', 'PA', 'TA_1_1_1', 'RH_1_1_1', 'T_DP_1_1_1', 'TA_1_1_2', 'RH_1_1_2', 'T_DP_1_1_2', 'TA_1_1_3', 'RH_1_1_3', 'T_DP_1_1_3', 'VPD', 'T_SONIC', 'T_SONIC_SIGMA', 'PBLH', 'TS_1_1_1', 'TS_1_1_2', 'SWC_1_1_1', 'SWC_1_1_2', 'ALB', 'NETRAD', 'SW_IN', 'SW_OUT', 'LW_IN', 'LW_OUT', 'P']
# DEBUG [2025-06-16 17:09:45] __main__ – Skip rows for set to 0
# DEBUG [2025-06-16 17:09:45] __main__ – Reading G:\Shared drives\UGS_Flux\Data_Downloads\Phrag\e20250320\8442_Flux_AmeriFluxFormat_43.dat
# INFO [2025-06-16 17:09:45] __main__ – Processing file: G:\Shared drives\UGS_Flux\Data_Downloads\Phrag\e20250320\8442_Flux_AmeriFluxFormat_44.dat
# DEBUG [2025-06-16 17:09:45] __main__ – 44 -> 8442
# DEBUG [2025-06-16 17:09:45] __main__ – Header row detected: ['TIMESTAMP_START', 'TIMESTAMP_END', 'CO2', 'CO2_SIGMA', 'H2O', 'H2O_SIGMA', 'CH4', 'FC', 'FC_SSITC_TEST', 'FCH4', 'FCH4_SSITC_TEST', 'LE', 'LE_SSITC_TEST', 'ET', 'ET_SSITC_TEST', 'H', 'H_SSITC_TEST', 'G', 'SG', 'FETCH_MAX', 'FETCH_90', 'FETCH_55', 'FETCH_40', 'WD', 'WS', 'WS_MAX', 'USTAR', 'ZL', 'TAU', 'TAU_SSITC_TEST', 'MO_LENGTH', 'U', 'U_SIGMA', 'V', 'V_SIGMA', 'W', 'W_SIGMA', 'PA', 'TA_1_1_1', 'RH_1_1_1', 'T_DP_1_1_1', 'TA_1_1_2', 'RH_1_1_2', 'T_DP_1_1_2', 'TA_1_1_3', 'RH_1_1_3', 'T_DP_1_1_3', 'VPD', 'T_SONIC', 'T_SONIC_SIGMA', 'PBLH', 'TS_1_1_1', 'TS_1_1_2', 'SWC_1_1_1', 'SWC_1_1_2', 'ALB', 'NETRAD', 'SW_IN', 'SW_OUT', 'LW_IN', 'LW_OUT', 'P']
# DEBUG [2025-06-16 17:09:45] __main__ – Skip rows for set to 0
# DEBUG [2025-06-16 17:09:45] __main__ – Reading G:\Shared drives\UGS_Flux\Data_Downloads\Phrag\e20250320\8442_Flux_AmeriFluxFormat_44.dat
# INFO [2025-06-16 17:09:45] __main__ – Processing file: G:\Shared drives\UGS_Flux\Data_Downloads\Phrag\e20250320\8442_Flux_AmeriFluxFormat_46.dat
# DEBUG [2025-06-16 17:09:45] __main__ – 46 -> 8442
# DEBUG [2025-06-16 17:09:46] __main__ – Header row detected: ['TIMESTAMP_START', 'TIMESTAMP_END', 'CO2', 'CO2_SIGMA', 'H2O', 'H2O_SIGMA', 'CH4', 'FC', 'FC_SSITC_TEST', 'FCH4', 'FCH4_SSITC_TEST', 'LE', 'LE_SSITC_TEST', 'ET', 'ET_SSITC_TEST', 'H', 'H_SSITC_TEST', 'G', 'SG', 'FETCH_MAX', 'FETCH_90', 'FETCH_55', 'FETCH_40', 'WD', 'WS', 'WS_MAX', 'USTAR', 'ZL', 'TAU', 'TAU_SSITC_TEST', 'MO_LENGTH', 'U', 'U_SIGMA', 'V', 'V_SIGMA', 'W', 'W_SIGMA', 'PA', 'TA_1_1_1', 'RH_1_1_1', 'T_DP_1_1_1', 'TA_1_1_2', 'RH_1_1_2', 'T_DP_1_1_2', 'TA_1_1_3', 'RH_1_1_3', 'T_DP_1_1_3', 'VPD', 'T_SONIC', 'T_SONIC_SIGMA', 'PBLH', 'TS_1_1_1', 'TS_1_1_2', 'SWC_1_1_1', 'SWC_1_1_2', 'ALB', 'NETRAD', 'SW_IN', 'SW_OUT', 'LW_IN', 'LW_OUT', 'P', 'Battery_Voltage', 'CO2_sig_strgth_Min', 'H2O_sig_strgth_Min']
# DEBUG [2025-06-16 17:09:46] __main__ – Skip rows for set to 0
# DEBUG [2025-06-16 17:09:46] __main__ – Reading G:\Shared drives\UGS_Flux\Data_Downloads\Phrag\e20250320\8442_Flux_AmeriFluxFormat_46.dat
# INFO [2025-06-16 17:09:46] __main__ – Processing file: G:\Shared drives\UGS_Flux\Data_Downloads\Phrag\e20250320\8442_Flux_AmeriFluxFormat_45.dat
# DEBUG [2025-06-16 17:09:46] __main__ – 45 -> 8442
# DEBUG [2025-06-16 17:09:46] __main__ – Header row detected: ['TIMESTAMP_START', 'TIMESTAMP_END', 'CO2', 'CO2_SIGMA', 'H2O', 'H2O_SIGMA', 'CH4', 'FC', 'FC_SSITC_TEST', 'FCH4', 'FCH4_SSITC_TEST', 'LE', 'LE_SSITC_TEST', 'ET', 'ET_SSITC_TEST', 'H', 'H_SSITC_TEST', 'G', 'SG', 'FETCH_MAX', 'FETCH_90', 'FETCH_55', 'FETCH_40', 'WD', 'WS', 'WS_MAX', 'USTAR', 'ZL', 'TAU', 'TAU_SSITC_TEST', 'MO_LENGTH', 'U', 'U_SIGMA', 'V', 'V_SIGMA', 'W', 'W_SIGMA', 'PA', 'TA_1_1_1', 'RH_1_1_1', 'T_DP_1_1_1', 'TA_1_1_2', 'RH_1_1_2', 'T_DP_1_1_2', 'TA_1_1_3', 'RH_1_1_3', 'T_DP_1_1_3', 'VPD', 'T_SONIC', 'T_SONIC_SIGMA', 'PBLH', 'TS_1_1_1', 'TS_1_1_2', 'SWC_1_1_1', 'SWC_1_1_2', 'ALB', 'NETRAD', 'SW_IN', 'SW_OUT', 'LW_IN', 'LW_OUT', 'P']
# DEBUG [2025-06-16 17:09:46] __main__ – Skip rows for set to 0
# DEBUG [2025-06-16 17:09:46] __main__ – Reading G:\Shared drives\UGS_Flux\Data_Downloads\Phrag\e20250320\8442_Flux_AmeriFluxFormat_45.dat
# INFO [2025-06-16 17:09:47] __main__ – Processing file: G:\Shared drives\UGS_Flux\Data_Downloads\Phrag\e20250320\8442_Flux_AmeriFluxFormat_40.dat
# DEBUG [2025-06-16 17:09:47] __main__ – 40 -> 8442
# DEBUG [2025-06-16 17:09:47] __main__ – Header row detected: ['TIMESTAMP_START', 'TIMESTAMP_END', 'CO2', 'CO2_SIGMA', 'H2O', 'H2O_SIGMA', 'CH4', 'FC', 'FC_SSITC_TEST', 'FCH4', 'FCH4_SSITC_TEST', 'LE', 'LE_SSITC_TEST', 'ET', 'ET_SSITC_TEST', 'H', 'H_SSITC_TEST', 'G', 'SG', 'FETCH_MAX', 'FETCH_90', 'FETCH_55', 'FETCH_40', 'WD', 'WS', 'WS_MAX', 'USTAR', 'ZL', 'TAU', 'TAU_SSITC_TEST', 'MO_LENGTH', 'U', 'U_SIGMA', 'V', 'V_SIGMA', 'W', 'W_SIGMA', 'PA', 'TA_1_1_1', 'RH_1_1_1', 'T_DP_1_1_1', 'TA_1_1_2', 'RH_1_1_2', 'T_DP_1_1_2', 'TA_1_1_3', 'RH_1_1_3', 'T_DP_1_1_3', 'VPD', 'T_SONIC', 'T_SONIC_SIGMA', 'PBLH', 'TS_1_1_1', 'TS_1_1_2', 'SWC_1_1_1', 'SWC_1_1_2', 'ALB', 'NETRAD', 'SW_IN', 'SW_OUT', 'LW_IN', 'LW_OUT', 'P']
# DEBUG [2025-06-16 17:09:47] __main__ – Skip rows for set to 0
# DEBUG [2025-06-16 17:09:47] __main__ – Reading G:\Shared drives\UGS_Flux\Data_Downloads\Phrag\e20250320\8442_Flux_AmeriFluxFormat_40.dat
# INFO [2025-06-16 17:09:47] __main__ – Processing file: G:\Shared drives\UGS_Flux\Data_Downloads\Phrag\e20250320\8442_Flux_AmeriFluxFormat_42.dat
# DEBUG [2025-06-16 17:09:47] __main__ – 42 -> 8442
# DEBUG [2025-06-16 17:09:47] __main__ – Header row detected: ['TIMESTAMP_START', 'TIMESTAMP_END', 'CO2', 'CO2_SIGMA', 'H2O', 'H2O_SIGMA', 'CH4', 'FC', 'FC_SSITC_TEST', 'FCH4', 'FCH4_SSITC_TEST', 'LE', 'LE_SSITC_TEST', 'ET', 'ET_SSITC_TEST', 'H', 'H_SSITC_TEST', 'G', 'SG', 'FETCH_MAX', 'FETCH_90', 'FETCH_55', 'FETCH_40', 'WD', 'WS', 'WS_MAX', 'USTAR', 'ZL', 'TAU', 'TAU_SSITC_TEST', 'MO_LENGTH', 'U', 'U_SIGMA', 'V', 'V_SIGMA', 'W', 'W_SIGMA', 'PA', 'TA_1_1_1', 'RH_1_1_1', 'T_DP_1_1_1', 'TA_1_1_2', 'RH_1_1_2', 'T_DP_1_1_2', 'TA_1_1_3', 'RH_1_1_3', 'T_DP_1_1_3', 'VPD', 'T_SONIC', 'T_SONIC_SIGMA', 'PBLH', 'TS_1_1_1', 'TS_1_1_2', 'SWC_1_1_1', 'SWC_1_1_2', 'ALB', 'NETRAD', 'SW_IN', 'SW_OUT', 'LW_IN', 'LW_OUT', 'P']
# DEBUG [2025-06-16 17:09:47] __main__ – Skip rows for set to 0
# DEBUG [2025-06-16 17:09:47] __main__ – Reading G:\Shared drives\UGS_Flux\Data_Downloads\Phrag\e20250320\8442_Flux_AmeriFluxFormat_42.dat
# INFO [2025-06-16 17:09:47] __main__ – Processing file: G:\Shared drives\UGS_Flux\Data_Downloads\Phrag\e20250320\8442_Flux_AmeriFluxFormat_41.dat
# DEBUG [2025-06-16 17:09:47] __main__ – 41 -> 8442
# DEBUG [2025-06-16 17:09:47] __main__ – Header row detected: ['TIMESTAMP_START', 'TIMESTAMP_END', 'CO2', 'CO2_SIGMA', 'H2O', 'H2O_SIGMA', 'CH4', 'FC', 'FC_SSITC_TEST', 'FCH4', 'FCH4_SSITC_TEST', 'LE', 'LE_SSITC_TEST', 'ET', 'ET_SSITC_TEST', 'H', 'H_SSITC_TEST', 'G', 'SG', 'FETCH_MAX', 'FETCH_90', 'FETCH_55', 'FETCH_40', 'WD', 'WS', 'WS_MAX', 'USTAR', 'ZL', 'TAU', 'TAU_SSITC_TEST', 'MO_LENGTH', 'U', 'U_SIGMA', 'V', 'V_SIGMA', 'W', 'W_SIGMA', 'PA', 'TA_1_1_1', 'RH_1_1_1', 'T_DP_1_1_1', 'TA_1_1_2', 'RH_1_1_2', 'T_DP_1_1_2', 'TA_1_1_3', 'RH_1_1_3', 'T_DP_1_1_3', 'VPD', 'T_SONIC', 'T_SONIC_SIGMA', 'PBLH', 'TS_1_1_1', 'TS_1_1_2', 'SWC_1_1_1', 'SWC_1_1_2', 'ALB', 'NETRAD', 'SW_IN', 'SW_OUT', 'LW_IN', 'LW_OUT', 'P']
# DEBUG [2025-06-16 17:09:47] __main__ – Skip rows for set to 0
# DEBUG [2025-06-16 17:09:47] __main__ – Reading G:\Shared drives\UGS_Flux\Data_Downloads\Phrag\e20250320\8442_Flux_AmeriFluxFormat_41.dat
# INFO [2025-06-16 17:09:47] __main__ – Processing file: G:\Shared drives\UGS_Flux\Data_Downloads\Phrag\e20250320\8442_Flux_AmeriFluxFormat_38.dat
# DEBUG [2025-06-16 17:09:47] __main__ – 38 -> 8442
# DEBUG [2025-06-16 17:09:47] __main__ – Header row detected: ['TIMESTAMP_START', 'TIMESTAMP_END', 'CO2', 'CO2_SIGMA', 'H2O', 'H2O_SIGMA', 'CH4', 'FC', 'FC_SSITC_TEST', 'FCH4', 'FCH4_SSITC_TEST', 'LE', 'LE_SSITC_TEST', 'ET', 'ET_SSITC_TEST', 'H', 'H_SSITC_TEST', 'G', 'SG', 'FETCH_MAX', 'FETCH_90', 'FETCH_55', 'FETCH_40', 'WD', 'WS', 'WS_MAX', 'USTAR', 'ZL', 'TAU', 'TAU_SSITC_TEST', 'MO_LENGTH', 'U', 'U_SIGMA', 'V', 'V_SIGMA', 'W', 'W_SIGMA', 'PA', 'TA_1_1_1', 'RH_1_1_1', 'T_DP_1_1_1', 'TA_1_1_2', 'RH_1_1_2', 'T_DP_1_1_2', 'TA_1_1_3', 'RH_1_1_3', 'T_DP_1_1_3', 'VPD', 'T_SONIC', 'T_SONIC_SIGMA', 'PBLH', 'TS_1_1_1', 'TS_1_1_2', 'SWC_1_1_1', 'SWC_1_1_2', 'ALB', 'NETRAD', 'SW_IN', 'SW_OUT', 'LW_IN', 'LW_OUT', 'P']
# DEBUG [2025-06-16 17:09:47] __main__ – Skip rows for set to 0
# DEBUG [2025-06-16 17:09:47] __main__ – Reading G:\Shared drives\UGS_Flux\Data_Downloads\Phrag\e20250320\8442_Flux_AmeriFluxFormat_38.dat
# INFO [2025-06-16 17:09:47] __main__ – Processing file: G:\Shared drives\UGS_Flux\Data_Downloads\Phrag\e20250320\8442_Flux_AmeriFluxFormat_39.dat
# DEBUG [2025-06-16 17:09:47] __main__ – 39 -> 8442
# DEBUG [2025-06-16 17:09:47] __main__ – Header row detected: ['TIMESTAMP_START', 'TIMESTAMP_END', 'CO2', 'CO2_SIGMA', 'H2O', 'H2O_SIGMA', 'CH4', 'FC', 'FC_SSITC_TEST', 'FCH4', 'FCH4_SSITC_TEST', 'LE', 'LE_SSITC_TEST', 'ET', 'ET_SSITC_TEST', 'H', 'H_SSITC_TEST', 'G', 'SG', 'FETCH_MAX', 'FETCH_90', 'FETCH_55', 'FETCH_40', 'WD', 'WS', 'WS_MAX', 'USTAR', 'ZL', 'TAU', 'TAU_SSITC_TEST', 'MO_LENGTH', 'U', 'U_SIGMA', 'V', 'V_SIGMA', 'W', 'W_SIGMA', 'PA', 'TA_1_1_1', 'RH_1_1_1', 'T_DP_1_1_1', 'TA_1_1_2', 'RH_1_1_2', 'T_DP_1_1_2', 'TA_1_1_3', 'RH_1_1_3', 'T_DP_1_1_3', 'VPD', 'T_SONIC', 'T_SONIC_SIGMA', 'PBLH', 'TS_1_1_1', 'TS_1_1_2', 'SWC_1_1_1', 'SWC_1_1_2', 'ALB', 'NETRAD', 'SW_IN', 'SW_OUT', 'LW_IN', 'LW_OUT', 'P']
# DEBUG [2025-06-16 17:09:47] __main__ – Skip rows for set to 0
# DEBUG [2025-06-16 17:09:47] __main__ – Reading G:\Shared drives\UGS_Flux\Data_Downloads\Phrag\e20250320\8442_Flux_AmeriFluxFormat_39.dat
# INFO [2025-06-16 17:09:47] __main__ – Processing file: G:\Shared drives\UGS_Flux\Data_Downloads\Phrag\m20250320\8441_Flux_AmeriFluxFormat_3.dat
# DEBUG [2025-06-16 17:09:47] __main__ – 3 -> 8441
# DEBUG [2025-06-16 17:09:47] __main__ – Header row detected: ['TIMESTAMP_START', 'TIMESTAMP_END', 'CO2', 'CO2_SIGMA', 'H2O', 'H2O_SIGMA', 'FC', 'FC_SSITC_TEST', 'LE', 'LE_SSITC_TEST', 'ET', 'ET_SSITC_TEST', 'H', 'H_SSITC_TEST', 'FETCH_MAX', 'FETCH_90', 'FETCH_55', 'FETCH_40', 'WD', 'WS', 'WS_MAX', 'USTAR', 'ZL', 'TAU', 'TAU_SSITC_TEST', 'MO_LENGTH', 'U', 'U_SIGMA', 'V', 'V_SIGMA', 'W', 'W_SIGMA', 'PA', 'TA_1_1_1', 'RH_1_1_1', 'T_DP_1_1_1', 'TA_1_1_2', 'RH_1_1_2', 'T_DP_1_1_2', 'VPD', 'T_SONIC', 'T_SONIC_SIGMA', 'PBLH', 'ALB', 'NETRAD', 'SW_IN', 'SW_OUT', 'LW_IN', 'LW_OUT']
# DEBUG [2025-06-16 17:09:47] __main__ – Skip rows for set to 0
# DEBUG [2025-06-16 17:09:47] __main__ – Reading G:\Shared drives\UGS_Flux\Data_Downloads\Phrag\m20250320\8441_Flux_AmeriFluxFormat_3.dat
# INFO [2025-06-16 17:09:47] __main__ – Processing file: G:\Shared drives\UGS_Flux\Data_Downloads\Phrag\m20250320\8441_Flux_AmeriFluxFormat_1.dat
# DEBUG [2025-06-16 17:09:47] __main__ – 1 -> 8441
# DEBUG [2025-06-16 17:09:47] __main__ – Header row detected: ['TIMESTAMP_START', 'TIMESTAMP_END', 'CO2', 'CO2_SIGMA', 'H2O', 'H2O_SIGMA', 'FC', 'FC_SSITC_TEST', 'LE', 'LE_SSITC_TEST', 'ET', 'ET_SSITC_TEST', 'H', 'H_SSITC_TEST', 'FETCH_MAX', 'FETCH_90', 'FETCH_55', 'FETCH_40', 'WD', 'WS', 'WS_MAX', 'USTAR', 'ZL', 'TAU', 'TAU_SSITC_TEST', 'MO_LENGTH', 'U', 'U_SIGMA', 'V', 'V_SIGMA', 'W', 'W_SIGMA', 'PA', 'TA_1_1_1', 'RH_1_1_1', 'T_DP_1_1_1', 'TA_1_1_2', 'RH_1_1_2', 'T_DP_1_1_2', 'VPD', 'T_SONIC', 'T_SONIC_SIGMA', 'PBLH', 'ALB', 'NETRAD', 'SW_IN', 'SW_OUT', 'LW_IN', 'LW_OUT']
# DEBUG [2025-06-16 17:09:47] __main__ – Skip rows for set to 0
# DEBUG [2025-06-16 17:09:47] __main__ – Reading G:\Shared drives\UGS_Flux\Data_Downloads\Phrag\m20250320\8441_Flux_AmeriFluxFormat_1.dat
# INFO [2025-06-16 17:09:47] __main__ – Processing file: G:\Shared drives\UGS_Flux\Data_Downloads\Phrag\m20250320\8441_Flux_AmeriFluxFormat_2.dat
# DEBUG [2025-06-16 17:09:47] __main__ – 2 -> 8441
# DEBUG [2025-06-16 17:09:47] __main__ – Header row detected: ['TIMESTAMP_START', 'TIMESTAMP_END', 'CO2', 'CO2_SIGMA', 'H2O', 'H2O_SIGMA', 'FC', 'FC_SSITC_TEST', 'LE', 'LE_SSITC_TEST', 'ET', 'ET_SSITC_TEST', 'H', 'H_SSITC_TEST', 'FETCH_MAX', 'FETCH_90', 'FETCH_55', 'FETCH_40', 'WD', 'WS', 'WS_MAX', 'USTAR', 'ZL', 'TAU', 'TAU_SSITC_TEST', 'MO_LENGTH', 'U', 'U_SIGMA', 'V', 'V_SIGMA', 'W', 'W_SIGMA', 'PA', 'TA_1_1_1', 'RH_1_1_1', 'T_DP_1_1_1', 'TA_1_1_2', 'RH_1_1_2', 'T_DP_1_1_2', 'VPD', 'T_SONIC', 'T_SONIC_SIGMA', 'PBLH', 'ALB', 'NETRAD', 'SW_IN', 'SW_OUT', 'LW_IN', 'LW_OUT']
# DEBUG [2025-06-16 17:09:47] __main__ – Skip rows for set to 0
# DEBUG [2025-06-16 17:09:47] __main__ – Reading G:\Shared drives\UGS_Flux\Data_Downloads\Phrag\m20250320\8441_Flux_AmeriFluxFormat_2.dat
# INFO [2025-06-16 17:09:47] __main__ – Processing file: G:\Shared drives\UGS_Flux\Data_Downloads\Phrag\m20250320\8441_Flux_AmeriFluxFormat_0.dat
# DEBUG [2025-06-16 17:09:47] __main__ – 0 -> 8441
# DEBUG [2025-06-16 17:09:47] __main__ – Header row detected: ['TIMESTAMP_START', 'TIMESTAMP_END', 'CO2', 'CO2_SIGMA', 'H2O', 'H2O_SIGMA', 'FC', 'FC_SSITC_TEST', 'LE', 'LE_SSITC_TEST', 'ET', 'ET_SSITC_TEST', 'H', 'H_SSITC_TEST', 'FETCH_MAX', 'FETCH_90', 'FETCH_55', 'FETCH_40', 'WD', 'WS', 'WS_MAX', 'USTAR', 'ZL', 'TAU', 'TAU_SSITC_TEST', 'MO_LENGTH', 'U', 'U_SIGMA', 'V', 'V_SIGMA', 'W', 'W_SIGMA', 'PA', 'TA_1_1_1', 'RH_1_1_1', 'T_DP_1_1_1', 'TA_1_1_2', 'RH_1_1_2', 'T_DP_1_1_2', 'VPD', 'T_SONIC', 'T_SONIC_SIGMA', 'PBLH', 'ALB', 'NETRAD', 'SW_IN', 'SW_OUT', 'LW_IN', 'LW_OUT']
# DEBUG [2025-06-16 17:09:47] __main__ – Skip rows for set to 0
# DEBUG [2025-06-16 17:09:47] __main__ – Reading G:\Shared drives\UGS_Flux\Data_Downloads\Phrag\m20250320\8441_Flux_AmeriFluxFormat_0.dat
# INFO [2025-06-16 17:09:47] __main__ – Processing file: G:\Shared drives\UGS_Flux\Data_Downloads\Phrag\m20250526\Great Salt Lake Phragmites_Flux_AmeriFluxFormat (2).dat
# DEBUG [2025-06-16 17:09:47] __main__ – 9999 -> 9999
# DEBUG [2025-06-16 17:09:47] __main__ – TOA5 header detected: ['TOA5', 'Phrag', '', '', '', '', '', 'Flux_AmeriFluxFormat']
# DEBUG [2025-06-16 17:09:47] __main__ – Skip rows for set to [0, 1, 2, 3]
# DEBUG [2025-06-16 17:09:47] __main__ – Reading G:\Shared drives\UGS_Flux\Data_Downloads\Phrag\m20250526\Great Salt Lake Phragmites_Flux_AmeriFluxFormat (2).dat
# INFO [2025-06-16 17:09:48] __main__ – Starting reformat (33557 rows)
# DEBUG [2025-06-16 17:09:48] __main__ – TS col TIMESTAMP_START
# DEBUG [2025-06-16 17:09:48] __main__ – TIMESTAMP_START col 202407022100
# DEBUG [2025-06-16 17:09:48] __main__ – Len of unfixed timestamps 33557
# DEBUG [2025-06-16 17:09:48] __main__ – Len of fixed timestamps 33519
# DEBUG [2025-06-16 17:09:48] __main__ – Renaming columns from Index(['RECORD', 'TIMESTAMP_START', 'TIMESTAMP_END', 'CO2', 'CO2_SIGMA', 'H2O',
#        'H2O_SIGMA', 'FC', 'FC_SSITC_TEST', 'LE', 'LE_SSITC_TEST', 'ET',
#        'ET_SSITC_TEST', 'H', 'H_SSITC_TEST', 'G', 'SG', 'FETCH_MAX',
#        'FETCH_90', 'FETCH_55', 'FETCH_40', 'WD', 'WS', 'WS_MAX', 'USTAR', 'ZL',
#        'TAU', 'TAU_SSITC_TEST', 'MO_LENGTH', 'U', 'U_SIGMA', 'V', 'V_SIGMA',
#        'W', 'W_SIGMA', 'PA', 'TA_1_1_1', 'RH_1_1_1', 'T_DP_1_1_1', 'TA_1_1_2',
#        'RH_1_1_2', 'T_DP_1_1_2', 'TA_1_1_3', 'RH_1_1_3', 'T_DP_1_1_3', 'VPD',
#        'T_SONIC', 'T_SONIC_SIGMA', 'PBLH', 'TS_1_1_1', 'SWC_1_1_1', 'ALB',
#        'NETRAD', 'SW_IN', 'SW_OUT', 'LW_IN', 'LW_OUT', 'P', 'file_no',
#        'datalogger_no', 'CH4', 'FCH4', 'FCH4_SSITC_TEST', 'TS_1_1_2',
#        'SWC_1_1_2', 'Battery_Voltage', 'CO2_sig_strgth_Min',
#        'H2O_sig_strgth_Min', 'CH4_sig_strgth_Min', 'datetime_start'],
#       dtype='object') to {}
# DEBUG [2025-06-16 17:09:48] __main__ – Len of normalized prefix cols 33519
# DEBUG [2025-06-16 17:09:48] __main__ – Len of renamed cols 33519
# DEBUG [2025-06-16 17:09:48] __main__ – Setting number types:    RECORD TIMESTAMP_START TIMESTAMP_END       CO2 CO2_SIGMA       H2O  \
# 0  1020.0    202407022100  202407022130  436.3569  5.451923  7.800076
# 1  1021.0    202407022130  202407022200  459.2611  7.305037  7.790117
# 2  1022.0    202407022200  202407022230  475.3193  10.51883  7.545727
#
#   H2O_SIGMA        FC FC_SSITC_TEST        LE  ...  CH4 FCH4 FCH4_SSITC_TEST  \
# 0  0.792657  2.791917           7.0  7.348644  ...  NaN  NaN             NaN
# 1  0.737987 -0.441283           9.0  3.274243  ...  NaN  NaN             NaN
# 2  0.994946  1.162799           9.0 -0.360413  ...  NaN  NaN             NaN
#
#   TS_1_1_2 SWC_1_1_2 Battery_Voltage CO2_sig_strgth_Min H2O_sig_strgth_Min  \
# 0      NaN       NaN             NaN                NaN                NaN
# 1      NaN       NaN             NaN                NaN                NaN
# 2      NaN       NaN             NaN                NaN                NaN
#
#   CH4_sig_strgth_Min      datetime_start
# 0                NaN 2024-07-02 21:00:00
# 1                NaN 2024-07-02 21:30:00
# 2                NaN 2024-07-02 22:00:00
#
# [3 rows x 70 columns]
# DEBUG [2025-06-16 17:09:48] __main__ – Setting number types RECORD
# DEBUG [2025-06-16 17:09:48] __main__ – Setting number types TIMESTAMP_START
# DEBUG [2025-06-16 17:09:48] __main__ – Setting number types TIMESTAMP_END
# DEBUG [2025-06-16 17:09:48] __main__ – Setting number types CO2
# DEBUG [2025-06-16 17:09:48] __main__ – Setting number types CO2_SIGMA
# DEBUG [2025-06-16 17:09:48] __main__ – Setting number types H2O
# DEBUG [2025-06-16 17:09:48] __main__ – Setting number types H2O_SIGMA
# DEBUG [2025-06-16 17:09:48] __main__ – Setting number types FC
# DEBUG [2025-06-16 17:09:48] __main__ – Setting number types FC_SSITC_TEST
# DEBUG [2025-06-16 17:09:48] __main__ – Setting number types LE
# DEBUG [2025-06-16 17:09:48] __main__ – Setting number types LE_SSITC_TEST
# DEBUG [2025-06-16 17:09:48] __main__ – Setting number types ET
# DEBUG [2025-06-16 17:09:48] __main__ – Setting number types ET_SSITC_TEST
# DEBUG [2025-06-16 17:09:48] __main__ – Setting number types H
# DEBUG [2025-06-16 17:09:48] __main__ – Setting number types H_SSITC_TEST
# DEBUG [2025-06-16 17:09:48] __main__ – Setting number types G
# DEBUG [2025-06-16 17:09:48] __main__ – Setting number types SG
# DEBUG [2025-06-16 17:09:48] __main__ – Setting number types FETCH_MAX
# DEBUG [2025-06-16 17:09:48] __main__ – Setting number types FETCH_90
# DEBUG [2025-06-16 17:09:48] __main__ – Setting number types FETCH_55
# DEBUG [2025-06-16 17:09:48] __main__ – Setting number types FETCH_40
# DEBUG [2025-06-16 17:09:48] __main__ – Setting number types WD
# DEBUG [2025-06-16 17:09:48] __main__ – Setting number types WS
# DEBUG [2025-06-16 17:09:48] __main__ – Setting number types WS_MAX
# DEBUG [2025-06-16 17:09:48] __main__ – Setting number types USTAR
# DEBUG [2025-06-16 17:09:48] __main__ – Setting number types ZL
# DEBUG [2025-06-16 17:09:48] __main__ – Setting number types TAU
# DEBUG [2025-06-16 17:09:48] __main__ – Setting number types TAU_SSITC_TEST
# DEBUG [2025-06-16 17:09:48] __main__ – Setting number types MO_LENGTH
# DEBUG [2025-06-16 17:09:48] __main__ – Setting number types U
# DEBUG [2025-06-16 17:09:48] __main__ – Setting number types U_SIGMA
# DEBUG [2025-06-16 17:09:48] __main__ – Setting number types V
# DEBUG [2025-06-16 17:09:48] __main__ – Setting number types V_SIGMA
# DEBUG [2025-06-16 17:09:48] __main__ – Setting number types W
# DEBUG [2025-06-16 17:09:48] __main__ – Setting number types W_SIGMA
# DEBUG [2025-06-16 17:09:48] __main__ – Setting number types PA
# DEBUG [2025-06-16 17:09:48] __main__ – Setting number types TA_1_1_1
# DEBUG [2025-06-16 17:09:48] __main__ – Setting number types RH_1_1_1
# DEBUG [2025-06-16 17:09:48] __main__ – Setting number types T_DP_1_1_1
# DEBUG [2025-06-16 17:09:48] __main__ – Setting number types TA_1_1_2
# DEBUG [2025-06-16 17:09:48] __main__ – Setting number types RH_1_1_2
# DEBUG [2025-06-16 17:09:49] __main__ – Setting number types T_DP_1_1_2
# DEBUG [2025-06-16 17:09:49] __main__ – Setting number types TA_1_1_3
# DEBUG [2025-06-16 17:09:49] __main__ – Setting number types RH_1_1_3
# DEBUG [2025-06-16 17:09:49] __main__ – Setting number types T_DP_1_1_3
# DEBUG [2025-06-16 17:09:49] __main__ – Setting number types VPD
# DEBUG [2025-06-16 17:09:49] __main__ – Setting number types T_SONIC
# DEBUG [2025-06-16 17:09:49] __main__ – Setting number types T_SONIC_SIGMA
# DEBUG [2025-06-16 17:09:49] __main__ – Setting number types PBLH
# DEBUG [2025-06-16 17:09:49] __main__ – Setting number types TS_1_1_1
# DEBUG [2025-06-16 17:09:49] __main__ – Setting number types SWC_1_1_1
# DEBUG [2025-06-16 17:09:49] __main__ – Setting number types ALB
# DEBUG [2025-06-16 17:09:49] __main__ – Setting number types NETRAD
# DEBUG [2025-06-16 17:09:49] __main__ – Setting number types SW_IN
# DEBUG [2025-06-16 17:09:49] __main__ – Setting number types SW_OUT
# DEBUG [2025-06-16 17:09:49] __main__ – Setting number types LW_IN
# DEBUG [2025-06-16 17:09:49] __main__ – Setting number types LW_OUT
# DEBUG [2025-06-16 17:09:49] __main__ – Setting number types P
# DEBUG [2025-06-16 17:09:49] __main__ – Setting number types file_no
# DEBUG [2025-06-16 17:09:49] __main__ – Setting number types datalogger_no
# DEBUG [2025-06-16 17:09:49] __main__ – Setting number types CH4
# DEBUG [2025-06-16 17:09:49] __main__ – Setting number types FCH4
# DEBUG [2025-06-16 17:09:49] __main__ – Setting number types FCH4_SSITC_TEST
# DEBUG [2025-06-16 17:09:49] __main__ – Setting number types TS_1_1_2
# DEBUG [2025-06-16 17:09:49] __main__ – Setting number types SWC_1_1_2
# DEBUG [2025-06-16 17:09:49] __main__ – Setting number types Battery_Voltage
# DEBUG [2025-06-16 17:09:49] __main__ – Setting number types CO2_sig_strgth_Min
# DEBUG [2025-06-16 17:09:49] __main__ – Setting number types H2O_sig_strgth_Min
# DEBUG [2025-06-16 17:09:49] __main__ – Setting number types CH4_sig_strgth_Min
# DEBUG [2025-06-16 17:09:49] __main__ – Setting number types datetime_start
# DEBUG [2025-06-16 17:09:49] __main__ – Set number types: 33519
# DEBUG [2025-06-16 17:09:50] __main__ – Len of resampled timestamps 40851
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 16
#      12 am_data = micromet.Reformatter(drop_soil=False,
#      13                                logger=logger,
#      14                                )
#      15 #raw_data = raw_data.drop([0], axis=0)
# ---> 16 am_df = am_data.prepare(raw_data)
#      17 comp_edd_df[key] = am_df
#      19 am_df.to_csv(f"../../out_data/station_data/{key}_HH_{am_df['TIMESTAMP_START'].values[0]:}_{am_df['TIMESTAMP_END'].values[-1]:}.csv")
#
# File c:\Users\paulinkenbrandt\Documents\GitHub\MicroMet\docs\notebooks\../../src\micromet\converter.py:300, in Reformatter.prepare(self, df, data_type)
#     291 def prepare(self, df: pd.DataFrame, data_type: str = "eddy") -> pd.DataFrame:
#     292     self.logger.info("Starting reformat (%s rows)", len(df))
#     294     df = (
#     295         df.pipe(self._fix_timestamps)
#     296         .pipe(self.rename_columns, data_type=data_type)
#     297         .pipe(self.set_number_types)
#     298         .pipe(self.resample_timestamps)
#     299         .pipe(self.timestamp_reset)
# --> 300         .pipe(self.clean_columns)
#     301         .pipe(self.apply_fixes)
#     302     )
#     303     if self.drop_soil:
#     304         df = self._drop_extra_soil_columns(df)
#
# File c:\Users\paulinkenbrandt\.conda\envs\py313\Lib\site-packages\pandas\core\generic.py:6231, in NDFrame.pipe(self, func, *args, **kwargs)
#    6229 if using_copy_on_write():
#    6230     return common.pipe(self.copy(deep=None), func, *args, **kwargs)
# -> 6231 return common.pipe(self, func, *args, **kwargs)
#
# File c:\Users\paulinkenbrandt\.conda\envs\py313\Lib\site-packages\pandas\core\common.py:502, in pipe(obj, func, *args, **kwargs)
#     500     return func(*args, **kwargs)
#     501 else:
# --> 502     return func(obj, *args, **kwargs)
#
# File c:\Users\paulinkenbrandt\Documents\GitHub\MicroMet\docs\notebooks\../../src\micromet\converter.py:561, in Reformatter.clean_columns(self, df, replace_w)
#     559 df = df.copy()
#     560 if self.varlimits is not None:
# --> 561     for col in set(df.columns) & set(self.varlimits.index):
#     562         if df.dtypes[col] == "float64":
#     563             self.logger.debug(f"Examining column {col} limits")
#
# AttributeError: 'dict' object has no attribute 'index'

# %%
raw_data

# %% [markdown]
# Compile files from each station into a a single dataframe.

# %%
cdf = pd.concat(comp_edd_df, axis=0)
cdf.index.set_names(['stationid','datetime_start'],inplace=True)
#cdf.rename(columns={'level_0':'stationid'},inplace=True)
#cdf.to_parquet('../station_data/all_data.parquet')
for col in cdf.columns:
    cdf.rename(columns={col:col.lower()},inplace=True)

# %% [markdown]
# Save to Parquet

# %%
cdf.to_parquet('../../station_data/all_eddy_data.parquet')

# %%
comp_met_df = {}
root_dir = "C:/Users/paulinkenbrandt/Documents/GitHub/MicroMet/src/micromet/data/"
config_path = root_dir + "reformatter_vars.yml"
var_limits_csv = root_dir + "extreme_values.csv"
am = micromet.AmerifluxDataProcessor(config_path, logger)


for key, value in site_folders.items():

    print(key)
    raw_fold = pathlib.Path('G:/Shared drives/UGS_Flux/Data_Downloads/')
    raw_data = am.raw_file_compile(raw_fold, value, search_str = "*Statistics_AmeriFlux*.dat")
    if raw_data is not None:
        am_data = micromet.Reformatter(
                                       config_path=config_path,
                                       var_limits_csv= var_limits_csv,
                                       drop_soil=False,
                                       logger=logger,
                                       )
        am_df = am_data.prepare(raw_data, data_type="met")
        #am_df = am_data.et_data
        comp_met_df[key] = am_df

        #am_df.to_csv(f"../../station_data/{key}_HH_{am_df['TIMESTAMP_START'].values[0]:}_{am_df['TIMESTAMP_END'].values[-1]:}.csv")

# %%
raw_data

# %%
mapping = {
    "T_100cm_N_Avg": "TS_3_9_1",
    "BulkEC_5cm_N_Avg": "EC_3_1_1",
    "BulkEC_10cm_N_Avg": "EC_3_2_1",
    "BulkEC_20cm_N_Avg": "EC_3_3_1",
    "BulkEC_30cm_N_Avg": "EC_3_4_1",
    "BulkEC_40cm_N_Avg": "EC_3_5_1",
    "BulkEC_50cm_N_Avg": "EC_3_6_1",
    "BulkEC_60cm_N_Avg": "EC_3_7_1",
    "BulkEC_75cm_N_Avg": "EC_3_8_1",
    "BulkEC_100cm_N_Avg": "EC_3_9_1",
    "VWC_5cm_S_Avg": "SWC_4_1_1",
    "VWC_10cm_S_Avg": "SWC_4_2_1",
    "VWC_20cm_S_Avg": "SWC_4_3_1",
    "VWC_30cm_S_Avg": "SWC_4_4_1",
    "VWC_40cm_S_Avg": "SWC_4_5_1",
    "VWC_50cm_S_Avg": "SWC_4_6_1",
    "VWC_60cm_S_Avg": "SWC_4_7_1",
    "VWC_75cm_S_Avg": "SWC_4_8_1",
    "VWC_100cm_S_Avg": "SWC_4_9_1",
    "Ka_5cm_S_Avg": "K_4_1_1",
    "Ka_10cm_S_Avg": "K_4_2_1",
    "Ka_20cm_S_Avg": "K_4_3_1",
    "Ka_30cm_S_Avg": "K_4_4_1",
    "Ka_40cm_S_Avg": "K_4_5_1",
    "Ka_50cm_S_Avg": "K_4_6_1",
    "Ka_60cm_S_Avg": "K_4_7_1",
    "Ka_75cm_S_Avg": "K_4_8_1",
    "Ka_100cm_S_Avg": "K_4_9_1",
    "T_5cm_S_Avg": "TS_4_1_1",
    "T_10cm_S_Avg": "TS_4_2_1",
    "T_20cm_S_Avg": "TS_4_3_1",
    "T_30cm_S_Avg": "TS_4_4_1",
    "T_40cm_S_Avg": "TS_4_5_1",
    "T_50cm_S_Avg": "TS_4_6_1",
    "T_60cm_S_Avg": "TS_4_7_1",
    "T_75cm_S_Avg": "TS_4_8_1",
    "T_100cm_S_Avg": "TS_4_9_1",
    "BulkEC_5cm_S_Avg": "EC_4_1_1",
    "BulkEC_10cm_S_Avg": "EC_4_2_1",
    "BulkEC_20cm_S_Avg": "EC_4_3_1",
    "BulkEC_30cm_S_Avg": "EC_4_4_1",
    "BulkEC_40cm_S_Avg": "EC_4_5_1",
    "BulkEC_50cm_S_Avg": "EC_4_6_1",
    "BulkEC_60cm_S_Avg": "EC_4_7_1",
    "BulkEC_75cm_S_Avg": "EC_4_8_1",
    "BulkEC_100cm_S_Avg": "EC_4_9_1",
    "VWC_5cm_Avg": "SWC_3_1_1",
    "VWC_10cm_Avg": "SWC_3_2_1",
    "VWC_20cm_Avg": "SWC_3_3_1",
    "VWC_30cm_Avg": "SWC_3_4_1",
    "VWC_40cm_Avg": "SWC_3_5_1",
    "VWC_50cm_Avg": "SWC_3_6_1",
    "VWC_60cm_Avg": "SWC_3_7_1",
    "VWC_75cm_Avg": "SWC_3_8_1",
    "VWC_100cm_Avg": "SWC_3_9_1",
    "Ka_5cm_Avg": "K_3_1_1",
    "Ka_10cm_Avg": "K_3_2_1",
    "Ka_20cm_Avg": "K_3_3_1",
    "Ka_30cm_Avg": "K_3_4_1",
    "Ka_40cm_Avg": "K_3_5_1",
    "Ka_50cm_Avg": "K_3_6_1",
    "Ka_60cm_Avg": "K_3_7_1",
    "Ka_75cm_Avg": "K_3_8_1",
    "Ka_100cm_Avg": "K_3_9_1",
    "T_5cm_Avg": "TS_3_1_1",
    "T_10cm_Avg": "TS_3_2_1",
    "T_20cm_Avg": "TS_3_3_1",
    "T_30cm_Avg": "TS_3_4_1",
    "T_40cm_Avg": "TS_3_5_1",
    "T_50cm_Avg": "TS_3_6_1",
    "T_60cm_Avg": "TS_3_7_1",
    "T_75cm_Avg": "TS_3_8_1",
    "T_100cm_Avg": "TS_3_9_1",
    "BulkEC_5cm_Avg": "EC_3_1_1",
    "BulkEC_10cm_Avg": "EC_3_2_1",
    "BulkEC_20cm_Avg": "EC_3_3_1",
    "BulkEC_30cm_Avg": "EC_3_4_1",
    "BulkEC_40cm_Avg": "EC_3_5_1",
    "BulkEC_50cm_Avg": "EC_3_6_1",
    "BulkEC_60cm_Avg": "EC_3_7_1",
    "BulkEC_75cm_Avg": "EC_3_8_1",
    "BulkEC_100cm_Avg": "EC_3_9_1",
    "BulkEC_3_1_1": "EC_3_1_1",
    "BulkEC_3_2_1": "EC_3_2_1",
    "BulkEC_3_3_1": "EC_3_3_1",
    "BulkEC_3_4_1": "EC_3_4_1",
    "BulkEC_3_5_1": "EC_3_5_1",
    "BulkEC_3_6_1": "EC_3_6_1",
    "BulkEC_3_7_1": "EC_3_7_1",
    "BulkEC_3_8_1": "EC_3_8_1",
    "BulkEC_3_9_1": "EC_3_9_1",
    "KA_3_1_1": "K_3_1_1",
    "KA_3_2_1": "K_3_2_1",
    "KA_3_3_1": "K_3_3_1",
    "KA_3_4_1": "K_3_4_1",
    "KA_3_5_1": "K_3_5_1",
    "KA_3_6_1": "K_3_6_1",
    "KA_3_7_1": "K_3_7_1",
    "KA_3_8_1": "K_3_8_1",
    "KA_3_9_1": "K_3_9_1",
    "VWC_2_1_1": "SWC_3_1_1",
    "VWC_2_2_1": "SWC_3_2_1",
    "VWC_2_3_1": "SWC_3_3_1",
    "VWC_2_4_1": "SWC_3_4_1",
    "VWC_2_5_1": "SWC_3_5_1",
    "VWC_2_6_1": "SWC_3_6_1",
    "VWC_2_7_1": "SWC_3_7_1",
    "VWC_2_8_1": "SWC_3_8_1",
    "VWC_2_9_1": "SWC_3_9_1",
    "VWC_3_1_1": "SWC_4_1_1",
    "VWC_3_2_1": "SWC_4_2_1",
    "VWC_3_3_1": "SWC_4_3_1",
    "VWC_3_4_1": "SWC_4_4_1",
    "VWC_3_5_1": "SWC_4_5_1",
    "VWC_3_6_1": "SWC_4_6_1",
    "VWC_3_7_1": "SWC_4_7_1",
    "VWC_3_8_1": "SWC_4_8_1",
    "VWC_3_9_1": "SWC_4_9_1",
    "T__1_8_1": "TS_3_8_1",
    "KA_4_1_1": "K_4_1_1",
    "KA_4_2_1": "K_4_2_1",
    "KA_4_3_1": "K_4_3_1",
    "KA_4_4_1": "K_4_4_1",
    "KA_4_5_1": "K_4_5_1",
    "KA_4_6_1": "K_4_6_1",
    "KA_4_7_1": "K_4_7_1",
    "KA_4_8_1": "K_4_8_1",
    "KA_4_9_1": "K_4_9_1",
    "BulkEC_4_1_1": "EC_4_1_1",
    "BulkEC_4_2_1": "EC_4_2_1",
    "BulkEC_4_3_1": "EC_4_3_1",
    "BulkEC_4_4_1": "EC_4_4_1",
    "BulkEC_4_5_1": "EC_4_5_1",
    "BulkEC_4_6_1": "EC_4_6_1",
    "BulkEC_4_7_1": "EC_4_7_1",
    "BulkEC_4_8_1": "EC_4_8_1",
    "BulkEC_4_9_1": "EC_4_9_1",
    "KA_2_1_1": "K_4_1_1",
    "KA_2_2_1": "K_4_2_1",
    "KA_2_3_1": "K_4_3_1",
    "KA_2_4_1": "K_4_4_1",
    "KA_2_5_1": "K_4_5_1",
    "KA_2_6_1": "K_4_6_1",
    "KA_2_7_1": "K_4_7_1",
    "KA_2_8_1": "K_4_8_1",
    "KA_2_9_1": "K_4_9_1",
    "BulkEC_2_1_1": "EC_4_1_1",
    "BulkEC_2_2_1": "EC_4_2_1",
    "BulkEC_2_3_1": "EC_4_3_1",
    "BulkEC_2_4_1": "EC_4_4_1",
    "BulkEC_2_5_1": "EC_4_5_1",
    "BulkEC_2_6_1": "EC_4_6_1",
    "BulkEC_2_7_1": "EC_4_7_1",
    "BulkEC_2_8_1": "EC_4_8_1",
    "BulkEC_2_9_1": "EC_4_9_1",
    "T_2_1_1": "TS_4_1_1",
    "T_2_2_1": "TS_4_2_1",
    "T_2_3_1": "TS_4_3_1",
    "T_2_4_1": "TS_4_4_1",
    "T_2_5_1": "TS_4_5_1",
    "T_2_6_1": "TS_4_6_1",
    "T_2_7_1": "TS_4_7_1",
    "T_2_8_1": "TS_4_8_1",
    "T_2_9_1": "TS_4_9_1",
}

# %%
ddf.columns = ddf.columns.str.lower()

for old_col, new_col in mapping.items():
    if str(old_col).lower() in ddf.columns.str.lower():
        if str(new_col).lower() in ddf.columns.str.lower():
            ddf[new_col.lower()] = ddf[[old_col.lower(), new_col.lower()]].max(axis=1)
            ddf = ddf.drop(old_col.lower(), axis=1)
        else:
            ddf = ddf.rename(columns={old_col.lower(): new_col.lower()})

# %%
soildfs

for old_col, new_col in mapping.items():
    if str(old_col).lower() in soildfs.columns.str.lower():
        if str(new_col).lower() in soildfs.columns.str.lower():
            soildfs[new_col.lower()] = soildfs[[old_col.lower(), new_col.lower()]].max(axis=1)
            soildfs = soildfs.drop(old_col.lower(), axis=1)
        else:
            soildfs = soildfs.rename(columns={old_col.lower(): new_col.lower()})
    elif str(old_col).lower()+"_eddy" in soildfs.columns.str.lower():
        print(f"Found {old_col} eddy column")
        if str(new_col).lower()+"_eddy" in soildfs.columns.str.lower():
            soildfs[new_col.lower()] = soildfs[[old_col.lower()+"_eddy", new_col.lower()+"_eddy"]].max(axis=1)
            soildfs = soildfs.drop(old_col.lower()+"_eddy", axis=1)
        else:
            soildfs = soildfs.rename(columns={old_col.lower()+"_eddy": new_col.lower()})
    elif str(new_col).lower()+"_eddy" in soildfs.columns.str.lower():
        if str(new_col).lower() in soildfs.columns.str.lower():
            soildfs[new_col.lower()] = soildfs[[new_col.lower()+"_eddy", new_col.lower()+"_eddy"]].max(axis=1)
            soildfs = soildfs.drop(new_col.lower()+"_eddy", axis=1)
            print(f"Found {new_col} eddy column")
        else:
            print(f"Found {new_col} eddy column")
            soildfs = soildfs.rename(columns={new_col.lower()+"_eddy": new_col.lower()})

# %%
for old_col, new_col in mapping.items():
    if str(old_col).lower()+"_eddy" in soildfs.columns.str.lower().str.strip():
        print(f"Found {old_col} eddy column")

# %%
"swc_4_1_1"

# %%
soildfs.iloc[0:1,:].to_clipboard()

# %%
ddf = ddf.replace(np.nan, 0)

# %%
ddf.to_parquet('../../station_data/all_met_data.parquet')

# %%
ddf = pd.concat(comp_met_df, axis=0)
ddf.index.set_names(['stationid','datetime_start'],inplace=True)
#cdf.rename(columns={'level_0':'stationid'},inplace=True)
#cdf.to_parquet('../station_data/all_data.parquet')
for col in ddf.columns:
    ddf.rename(columns={col:col.lower()},inplace=True)

# %%
ddf[~ddf['vwc_2_7_1'].isna()]

# %%
ddf.iloc[0:1,:].to_clipboard()

# %%
import re

soilcols = [col.lower() for col in am_data.MATH_SOILS_V2]
pattern = re.compile(r"2_1_1|1_2_1|1_1_2")
# Print matching columns
matching_cols = [col for col in soilcols if pattern.search(col)]
# Remove them from the original list
soilcols = [col for col in soilcols if not pattern.search(col)]

        
soildfs = pd.merge(ddf,cdf[soilcols],how='left',on=['stationid','datetime_start'],suffixes=(None,'_eddy'))
soildfs

for col in cdf.columns:
    if col in soilcols:
        cdf.drop(columns=col,inplace=True)  # drop the soil columns from the main dataframe

cdf.to_parquet('../../station_data/all_eddy_data.parquet')

soildfs.to_parquet('../../station_data/all_soil_data.parquet')

ddf.to_parquet('../../station_data/all_met_data.parquet')

# %%
cdf = pd.read_parquet('../../station_data/all_eddy_data.parquet')

# %%
cdf.columns

# %%
soildfs = pd.read_parquet('../../station_data/all_soil_data.parquet')
utd_soilt = soildfs.loc['US-UTD'][['ts_3_1_1','ts_3_2_1','ts_3_3_1']].replace(-9999,np.nan)
utd_soilt = utd_soilt[utd_soilt.index >= '2024-07-01']#.resample('30T').mean()
utd_soilt['ts_3_1_1'].plot()
utd_soilt['ts_3_2_1'].shift(-1).plot()
utd_soilt['ts_3_3_1'].shift(-5).plot()
plt.axvline('2024-07-04 15:00',color='r')
#plt.xlim('2024-07-01','2024-07-08')
#plt.ylim(10,35)
plt.grid(True, which='minor')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose
from scipy.signal import correlate

# Function to decompose the seasonal component
def extract_seasonal(ts, period):
    decomposition = seasonal_decompose(ts, model='additive', period=period)
    return decomposition.seasonal

# Function to calculate lag between two seasonal series using cross-correlation
def calculate_lag(seasonal1, seasonal2):
    n = len(seasonal1)
    correlation = correlate(seasonal1 - np.mean(seasonal1), seasonal2 - np.mean(seasonal2), mode='full')
    lags = np.arange(-n + 1, n)
    lag = lags[np.argmax(correlation)]
    return lag, correlation, lags

ts1 = utd_soilt['ts_3_2_1']
ts2 = utd_soilt['ts_3_3_1']
#utd_soilt['ts_3_3_1'].shift(-5).plot()


# Extract seasonal components
seasonal1 = extract_seasonal(ts1, period=48)
seasonal2 = extract_seasonal(ts2, period=48)

# Calculate lag
lag, correlation, lags = calculate_lag(seasonal1.dropna(), seasonal2.dropna())

# Output
print(f"Calculated lag: {lag/2} hours")

# Plot seasonal components and correlation
fig, ax = plt.subplots(3, 1, figsize=(10, 8))

seasonal1.plot(ax=ax[0], label='Seasonal Component 1')
seasonal2.plot(ax=ax[0], label='Seasonal Component 2')
ax[0].legend()
ax[0].set_title('Seasonal Components')
ax[0].set_xlim(pd.to_datetime('2024-07-01'),pd.to_datetime('2024-07-08'))
ax[0].grid(True)

ax[1].plot(lags, correlation)
ax[1].set_title('Cross-Correlation')
ax[1].set_xlabel('Lag (hours)')
ax[1].set_ylabel('Correlation')
ax[1].set_xlim(-10, 10)
ax[1].grid(True)

ax[2].plot(seasonal1.index, seasonal1, label='Series 1')
ax[2].plot(seasonal2.index + pd.Timedelta(hours=lag/2), seasonal2, label='Series 2 (Shifted)')
ax[2].legend()
ax[2].set_title(f'Series alignment (Lag: {lag/2} hours)')
ax[2].set_xlim(pd.to_datetime('2024-07-01'),pd.to_datetime('2024-07-08'))
ax[2].grid(True)
plt.tight_layout()
plt.show()

# %%
cdf = pd.read_parquet('../../station_data/all_eddy_data.parquet')
ddf = pd.read_parquet('../../station_data/all_met_data.parquet')

for col in cdf.columns:
    if col in ddf.columns:
        print(col)

# %%
ddf.head(10).to_clipboard()

# %%
series = ddf.loc['US-UTD','t_si111_body'].replace(-9999,np.nan)
series.plot()
series.diff().plot()
new_series = series[series.diff()<2].diff().cumsum()
new_series.plot()

# %%
config = configparser.ConfigParser()

config.read('../../secrets/config.ini')

from sqlalchemy import create_engine
import urllib.parse
host = config['DEFAULT']['ip']
pw = config['DEFAULT']['pw']
user = config['DEFAULT']['login']

encoded_password = urllib.parse.quote_plus(pw)

def postconn_et(encoded_password, host='localhost',user='postgres',port='5432',db='groundwater', schema = 'groundwater'):
    connection_text = "postgresql+psycopg2://{:}:{:}@{:}:{:}/{:}?gssencmode=disable".format(user,encoded_password,host,port,db)
    return create_engine(connection_text, connect_args={'options': '-csearch_path={}'.format(schema)})


engine = postconn_et(encoded_password, host=host, user=user)

# %%
cdf.to_sql(name = 'amfluxeddy',
           schema='groundwater',
           con=engine,
           if_exists='replace',
           chunksize=2000)

# %%
for col in soildfs.columns:
    print(f"amfluxmet.{col},")

# %%
soildfs.to_sql(name = 'amfluxmet',
           schema='groundwater',
           con=engine,
           if_exists='replace',
           chunksize=2000)
