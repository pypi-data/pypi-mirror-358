# %%
import syft_code_queue as q
# Out:
# 2025-06-29 22:08:48.768 | INFO     | syft_code_queue.data_scientist_api:__init__:54 - Initialized Data Scientist API for andrew@openmined.org
# 2025-06-29 22:08:48.769 | INFO     | syft_code_queue.data_owner_api:__init__:55 - Initialized Data Owner API for andrew@openmined.org
# 2025-06-29 22:08:48.769 | INFO     | syft_code_queue:__init__:79 - Initialized syft-code-queue API for andrew@openmined.org

# %%
q.pending_for_me
# Out:
# JobCollection(1 jobs - pending: 1)

# %%
q.pending_for_me[0].approve("Approved via Jupyter interface")
# Out:
# 2025-06-29 22:08:54.932 | INFO     | syft_code_queue.data_owner_api:approve_job:319 - Approved job: Customer Insights Analysis
# True
