# %% [markdown]
# # Demo

# %% [markdown]
# ## Setup

# %%
import sys
from pathlib import Path

# Try finding project root by searching for marker (like pyproject.toml)
def find_project_root(start: Path, marker: str = "pyproject.toml") -> Path:
    for parent in [start] + list(start.parents):
        if (parent / marker).exists():
            return parent
    raise RuntimeError("Project root not found")

root_dir = find_project_root(Path.cwd())
sys.path.append(str(root_dir / "src"))

# %%
from charfinder.core.core_main import (
    find_chars,
    find_chars_raw,
    find_chars_with_info,
)
from charfinder.constants import FuzzyAlgorithm, HybridAggFunc

# %% [markdown]
# #### Simple Exact Match (Default)

# %%
query = "arrow"
results = list(find_chars(query))

print("\n".join(results))
# Out:
# [INFO] Rebuilding Unicode name cache. This may take a few seconds...
# [WARNING] Validation failed: Cache file path does not exist: C:\Users\HamedVAHEB\Documents\Projects\Python\charfinder\data\UnicodeData.txt
# [INFO] Downloaded and cached "UnicodeData.txt" from https://www.unicode.org/Public/UCD/latest/ucd/UnicodeData.txt
# [INFO] Loaded "UnicodeData.txt" from local file: C:\Users\HamedVAHEB\Documents\Projects\Python\charfinder\data\UnicodeData.txt
# [INFO] Cache written to: "C:\Users\HamedVAHEB\Documents\Projects\Python\charfinder\data\cache\unicode_name_cache.json"
# [INFO] Found 560 match(es) for query: 'arrow'
# CODE       CHAR NAME
# --------------------
# U+02FF     ˿   MODIFIER LETTER LOW LEFT ARROW  (\u02ff)
# U+034D     ͍   COMBINING LEFT RIGHT ARROW BELOW  (\u034d)
# U+034E     ͎   COMBINING UPWARDS ARROW BELOW  (\u034e)
# U+0362     ͢   COMBINING DOUBLE RIGHTWARDS ARROW BELOW  (\u0362)
# U+1AB3     ᪳   COMBINING DOWNWARDS ARROW  (\u1ab3)
# U+20D4     ⃔   COMBINING ANTICLOCKWISE ARROW ABOVE  (\u20d4)
# U+20D5     ⃕   COMBINING CLOCKWISE ARROW ABOVE  (\u20d5)
# U+20D6     ⃖   COMBINING LEFT ARROW ABOVE  (\u20d6)
# U+20D7     ⃗   COMBINING RIGHT ARROW ABOVE  (\u20d7)
# U+20E1     ⃡   COMBINING LEFT RIGHT ARROW ABOVE  (\u20e1)
# U+20EA     ⃪   COMBINING LEFTWARDS ARROW OVERLAY  (\u20ea)
# U+20EE     ⃮   COMBINING LEFT ARROW BELOW  (\u20ee)
# U+20EF     ⃯   COMBINING RIGHT ARROW BELOW  (\u20ef)
# U+2190     ←   LEFTWARDS ARROW  (\u2190)
# U+2191     ↑   UPWARDS ARROW  (\u2191)
# U+2192     →   RIGHTWARDS ARROW  (\u2192)
# U+2193     ↓   DOWNWARDS ARROW  (\u2193)
# U+2194     ↔   LEFT RIGHT ARROW  (\u2194)
# U+2195     ↕   UP DOWN ARROW  (\u2195)
# U+2196     ↖   NORTH WEST ARROW  (\u2196)
# U+2197     ↗   NORTH EAST ARROW  (\u2197)
# U+2198     ↘   SOUTH EAST ARROW  (\u2198)
# U+2199     ↙   SOUTH WEST ARROW  (\u2199)
# U+219A     ↚   LEFTWARDS ARROW WITH STROKE  (\u219a)
# U+219B     ↛   RIGHTWARDS ARROW WITH STROKE  (\u219b)
# U+219C     ↜   LEFTWARDS WAVE ARROW  (\u219c)
# U+219D     ↝   RIGHTWARDS WAVE ARROW  (\u219d)
# U+219E     ↞   LEFTWARDS TWO HEADED ARROW  (\u219e)
# U+219F     ↟   UPWARDS TWO HEADED ARROW  (\u219f)
# U+21A0     ↠   RIGHTWARDS TWO HEADED ARROW  (\u21a0)
# U+21A1     ↡   DOWNWARDS TWO HEADED ARROW  (\u21a1)
# U+21A2     ↢   LEFTWARDS ARROW WITH TAIL  (\u21a2)
# U+21A3     ↣   RIGHTWARDS ARROW WITH TAIL  (\u21a3)
# U+21A4     ↤   LEFTWARDS ARROW FROM BAR  (\u21a4)
# U+21A5     ↥   UPWARDS ARROW FROM BAR  (\u21a5)
# U+21A6     ↦   RIGHTWARDS ARROW FROM BAR  (\u21a6)
# U+21A7     ↧   DOWNWARDS ARROW FROM BAR  (\u21a7)
# U+21A8     ↨   UP DOWN ARROW WITH BASE  (\u21a8)
# U+21A9     ↩   LEFTWARDS ARROW WITH HOOK  (\u21a9)
# U+21AA     ↪   RIGHTWARDS ARROW WITH HOOK  (\u21aa)
# U+21AB     ↫   LEFTWARDS ARROW WITH LOOP  (\u21ab)
# U+21AC     ↬   RIGHTWARDS ARROW WITH LOOP  (\u21ac)
# U+21AD     ↭   LEFT RIGHT WAVE ARROW  (\u21ad)
# U+21AE     ↮   LEFT RIGHT ARROW WITH STROKE  (\u21ae)
# U+21AF     ↯   DOWNWARDS ZIGZAG ARROW  (\u21af)
# U+21B0     ↰   UPWARDS ARROW WITH TIP LEFTWARDS  (\u21b0)
# U+21B1     ↱   UPWARDS ARROW WITH TIP RIGHTWARDS  (\u21b1)
# U+21B2     ↲   DOWNWARDS ARROW WITH TIP LEFTWARDS  (\u21b2)
# U+21B3     ↳   DOWNWARDS ARROW WITH TIP RIGHTWARDS  (\u21b3)
# U+21B4     ↴   RIGHTWARDS ARROW WITH CORNER DOWNWARDS  (\u21b4)
# U+21B5     ↵   DOWNWARDS ARROW WITH CORNER LEFTWARDS  (\u21b5)
# U+21B6     ↶   ANTICLOCKWISE TOP SEMICIRCLE ARROW  (\u21b6)
# U+21B7     ↷   CLOCKWISE TOP SEMICIRCLE ARROW  (\u21b7)
# U+21B8     ↸   NORTH WEST ARROW TO LONG BAR  (\u21b8)
# U+21B9     ↹   LEFTWARDS ARROW TO BAR OVER RIGHTWARDS ARROW TO BAR  (\u21b9)
# U+21BA     ↺   ANTICLOCKWISE OPEN CIRCLE ARROW  (\u21ba)
# U+21BB     ↻   CLOCKWISE OPEN CIRCLE ARROW  (\u21bb)
# U+21C4     ⇄   RIGHTWARDS ARROW OVER LEFTWARDS ARROW  (\u21c4)
# U+21C5     ⇅   UPWARDS ARROW LEFTWARDS OF DOWNWARDS ARROW  (\u21c5)
# U+21C6     ⇆   LEFTWARDS ARROW OVER RIGHTWARDS ARROW  (\u21c6)
# U+21CD     ⇍   LEFTWARDS DOUBLE ARROW WITH STROKE  (\u21cd)
# U+21CE     ⇎   LEFT RIGHT DOUBLE ARROW WITH STROKE  (\u21ce)
# U+21CF     ⇏   RIGHTWARDS DOUBLE ARROW WITH STROKE  (\u21cf)
# U+21D0     ⇐   LEFTWARDS DOUBLE ARROW  (\u21d0)
# U+21D1     ⇑   UPWARDS DOUBLE ARROW  (\u21d1)
# U+21D2     ⇒   RIGHTWARDS DOUBLE ARROW  (\u21d2)
# U+21D3     ⇓   DOWNWARDS DOUBLE ARROW  (\u21d3)
# U+21D4     ⇔   LEFT RIGHT DOUBLE ARROW  (\u21d4)
# U+21D5     ⇕   UP DOWN DOUBLE ARROW  (\u21d5)
# U+21D6     ⇖   NORTH WEST DOUBLE ARROW  (\u21d6)
# U+21D7     ⇗   NORTH EAST DOUBLE ARROW  (\u21d7)
# U+21D8     ⇘   SOUTH EAST DOUBLE ARROW  (\u21d8)
# U+21D9     ⇙   SOUTH WEST DOUBLE ARROW  (\u21d9)
# U+21DA     ⇚   LEFTWARDS TRIPLE ARROW  (\u21da)
# U+21DB     ⇛   RIGHTWARDS TRIPLE ARROW  (\u21db)
# U+21DC     ⇜   LEFTWARDS SQUIGGLE ARROW  (\u21dc)
# U+21DD     ⇝   RIGHTWARDS SQUIGGLE ARROW  (\u21dd)
# U+21DE     ⇞   UPWARDS ARROW WITH DOUBLE STROKE  (\u21de)
# U+21DF     ⇟   DOWNWARDS ARROW WITH DOUBLE STROKE  (\u21df)
# U+21E0     ⇠   LEFTWARDS DASHED ARROW  (\u21e0)
# U+21E1     ⇡   UPWARDS DASHED ARROW  (\u21e1)
# U+21E2     ⇢   RIGHTWARDS DASHED ARROW  (\u21e2)
# U+21E3     ⇣   DOWNWARDS DASHED ARROW  (\u21e3)
# U+21E4     ⇤   LEFTWARDS ARROW TO BAR  (\u21e4)
# U+21E5     ⇥   RIGHTWARDS ARROW TO BAR  (\u21e5)
# U+21E6     ⇦   LEFTWARDS WHITE ARROW  (\u21e6)
# U+21E7     ⇧   UPWARDS WHITE ARROW  (\u21e7)
# U+21E8     ⇨   RIGHTWARDS WHITE ARROW  (\u21e8)
# U+21E9     ⇩   DOWNWARDS WHITE ARROW  (\u21e9)
# U+21EA     ⇪   UPWARDS WHITE ARROW FROM BAR  (\u21ea)
# U+21EB     ⇫   UPWARDS WHITE ARROW ON PEDESTAL  (\u21eb)
# U+21EC     ⇬   UPWARDS WHITE ARROW ON PEDESTAL WITH HORIZONTAL BAR  (\u21ec)
# U+21ED     ⇭   UPWARDS WHITE ARROW ON PEDESTAL WITH VERTICAL BAR  (\u21ed)
# U+21EE     ⇮   UPWARDS WHITE DOUBLE ARROW  (\u21ee)
# U+21EF     ⇯   UPWARDS WHITE DOUBLE ARROW ON PEDESTAL  (\u21ef)
# U+21F0     ⇰   RIGHTWARDS WHITE ARROW FROM WALL  (\u21f0)
# U+21F1     ⇱   NORTH WEST ARROW TO CORNER  (\u21f1)
# U+21F2     ⇲   SOUTH EAST ARROW TO CORNER  (\u21f2)
# U+21F3     ⇳   UP DOWN WHITE ARROW  (\u21f3)
# U+21F4     ⇴   RIGHT ARROW WITH SMALL CIRCLE  (\u21f4)
# U+21F5     ⇵   DOWNWARDS ARROW LEFTWARDS OF UPWARDS ARROW  (\u21f5)
# U+21F7     ⇷   LEFTWARDS ARROW WITH VERTICAL STROKE  (\u21f7)
# U+21F8     ⇸   RIGHTWARDS ARROW WITH VERTICAL STROKE  (\u21f8)
# U+21F9     ⇹   LEFT RIGHT ARROW WITH VERTICAL STROKE  (\u21f9)
# U+21FA     ⇺   LEFTWARDS ARROW WITH DOUBLE VERTICAL STROKE  (\u21fa)
# U+21FB     ⇻   RIGHTWARDS ARROW WITH DOUBLE VERTICAL STROKE  (\u21fb)
# U+21FC     ⇼   LEFT RIGHT ARROW WITH DOUBLE VERTICAL STROKE  (\u21fc)
# U+21FD     ⇽   LEFTWARDS OPEN-HEADED ARROW  (\u21fd)
# U+21FE     ⇾   RIGHTWARDS OPEN-HEADED ARROW  (\u21fe)
# U+21FF     ⇿   LEFT RIGHT OPEN-HEADED ARROW  (\u21ff)
# U+2301     ⌁   ELECTRIC ARROW  (\u2301)
# U+2347     ⍇   APL FUNCTIONAL SYMBOL QUAD LEFTWARDS ARROW  (\u2347)
# U+2348     ⍈   APL FUNCTIONAL SYMBOL QUAD RIGHTWARDS ARROW  (\u2348)
# U+2350     ⍐   APL FUNCTIONAL SYMBOL QUAD UPWARDS ARROW  (\u2350)
# U+2357     ⍗   APL FUNCTIONAL SYMBOL QUAD DOWNWARDS ARROW  (\u2357)
# U+237C     ⍼   RIGHT ANGLE WITH DOWNWARDS ZIGZAG ARROW  (\u237c)
# U+238B     ⎋   BROKEN CIRCLE WITH NORTHWEST ARROW  (\u238b)
# U+2794     ➔   HEAVY WIDE-HEADED RIGHTWARDS ARROW  (\u2794)
# U+2798     ➘   HEAVY SOUTH EAST ARROW  (\u2798)
# U+2799     ➙   HEAVY RIGHTWARDS ARROW  (\u2799)
# U+279A     ➚   HEAVY NORTH EAST ARROW  (\u279a)
# U+279B     ➛   DRAFTING POINT RIGHTWARDS ARROW  (\u279b)
# U+279C     ➜   HEAVY ROUND-TIPPED RIGHTWARDS ARROW  (\u279c)
# U+279D     ➝   TRIANGLE-HEADED RIGHTWARDS ARROW  (\u279d)
# U+279E     ➞   HEAVY TRIANGLE-HEADED RIGHTWARDS ARROW  (\u279e)
# U+279F     ➟   DASHED TRIANGLE-HEADED RIGHTWARDS ARROW  (\u279f)
# U+27A0     ➠   HEAVY DASHED TRIANGLE-HEADED RIGHTWARDS ARROW  (\u27a0)
# U+27A1     ➡   BLACK RIGHTWARDS ARROW  (\u27a1)
# U+27A5     ➥   HEAVY BLACK CURVED DOWNWARDS AND RIGHTWARDS ARROW  (\u27a5)
# U+27A6     ➦   HEAVY BLACK CURVED UPWARDS AND RIGHTWARDS ARROW  (\u27a6)
# U+27A7     ➧   SQUAT BLACK RIGHTWARDS ARROW  (\u27a7)
# U+27A8     ➨   HEAVY CONCAVE-POINTED BLACK RIGHTWARDS ARROW  (\u27a8)
# U+27A9     ➩   RIGHT-SHADED WHITE RIGHTWARDS ARROW  (\u27a9)
# U+27AA     ➪   LEFT-SHADED WHITE RIGHTWARDS ARROW  (\u27aa)
# U+27AB     ➫   BACK-TILTED SHADOWED WHITE RIGHTWARDS ARROW  (\u27ab)
# U+27AC     ➬   FRONT-TILTED SHADOWED WHITE RIGHTWARDS ARROW  (\u27ac)
# U+27AD     ➭   HEAVY LOWER RIGHT-SHADOWED WHITE RIGHTWARDS ARROW  (\u27ad)
# U+27AE     ➮   HEAVY UPPER RIGHT-SHADOWED WHITE RIGHTWARDS ARROW  (\u27ae)
# U+27AF     ➯   NOTCHED LOWER RIGHT-SHADOWED WHITE RIGHTWARDS ARROW  (\u27af)
# U+27B1     ➱   NOTCHED UPPER RIGHT-SHADOWED WHITE RIGHTWARDS ARROW  (\u27b1)
# U+27B2     ➲   CIRCLED HEAVY WHITE RIGHTWARDS ARROW  (\u27b2)
# U+27B3     ➳   WHITE-FEATHERED RIGHTWARDS ARROW  (\u27b3)
# U+27B4     ➴   BLACK-FEATHERED SOUTH EAST ARROW  (\u27b4)
# U+27B5     ➵   BLACK-FEATHERED RIGHTWARDS ARROW  (\u27b5)
# U+27B6     ➶   BLACK-FEATHERED NORTH EAST ARROW  (\u27b6)
# U+27B7     ➷   HEAVY BLACK-FEATHERED SOUTH EAST ARROW  (\u27b7)
# U+27B8     ➸   HEAVY BLACK-FEATHERED RIGHTWARDS ARROW  (\u27b8)
# U+27B9     ➹   HEAVY BLACK-FEATHERED NORTH EAST ARROW  (\u27b9)
# U+27BA     ➺   TEARDROP-BARBED RIGHTWARDS ARROW  (\u27ba)
# U+27BB     ➻   HEAVY TEARDROP-SHANKED RIGHTWARDS ARROW  (\u27bb)
# U+27BC     ➼   WEDGE-TAILED RIGHTWARDS ARROW  (\u27bc)
# U+27BD     ➽   HEAVY WEDGE-TAILED RIGHTWARDS ARROW  (\u27bd)
# U+27BE     ➾   OPEN-OUTLINED RIGHTWARDS ARROW  (\u27be)
# U+27F0     ⟰   UPWARDS QUADRUPLE ARROW  (\u27f0)
# U+27F1     ⟱   DOWNWARDS QUADRUPLE ARROW  (\u27f1)
# U+27F2     ⟲   ANTICLOCKWISE GAPPED CIRCLE ARROW  (\u27f2)
# U+27F3     ⟳   CLOCKWISE GAPPED CIRCLE ARROW  (\u27f3)
# U+27F4     ⟴   RIGHT ARROW WITH CIRCLED PLUS  (\u27f4)
# U+27F5     ⟵   LONG LEFTWARDS ARROW  (\u27f5)
# U+27F6     ⟶   LONG RIGHTWARDS ARROW  (\u27f6)
# U+27F7     ⟷   LONG LEFT RIGHT ARROW  (\u27f7)
# U+27F8     ⟸   LONG LEFTWARDS DOUBLE ARROW  (\u27f8)
# U+27F9     ⟹   LONG RIGHTWARDS DOUBLE ARROW  (\u27f9)
# U+27FA     ⟺   LONG LEFT RIGHT DOUBLE ARROW  (\u27fa)
# U+27FB     ⟻   LONG LEFTWARDS ARROW FROM BAR  (\u27fb)
# U+27FC     ⟼   LONG RIGHTWARDS ARROW FROM BAR  (\u27fc)
# U+27FD     ⟽   LONG LEFTWARDS DOUBLE ARROW FROM BAR  (\u27fd)
# U+27FE     ⟾   LONG RIGHTWARDS DOUBLE ARROW FROM BAR  (\u27fe)
# U+27FF     ⟿   LONG RIGHTWARDS SQUIGGLE ARROW  (\u27ff)
# U+2900     ⤀   RIGHTWARDS TWO-HEADED ARROW WITH VERTICAL STROKE  (\u2900)
# U+2901     ⤁   RIGHTWARDS TWO-HEADED ARROW WITH DOUBLE VERTICAL STROKE  (\u2901)
# U+2902     ⤂   LEFTWARDS DOUBLE ARROW WITH VERTICAL STROKE  (\u2902)
# U+2903     ⤃   RIGHTWARDS DOUBLE ARROW WITH VERTICAL STROKE  (\u2903)
# U+2904     ⤄   LEFT RIGHT DOUBLE ARROW WITH VERTICAL STROKE  (\u2904)
# U+2905     ⤅   RIGHTWARDS TWO-HEADED ARROW FROM BAR  (\u2905)
# U+2906     ⤆   LEFTWARDS DOUBLE ARROW FROM BAR  (\u2906)
# U+2907     ⤇   RIGHTWARDS DOUBLE ARROW FROM BAR  (\u2907)
# U+2908     ⤈   DOWNWARDS ARROW WITH HORIZONTAL STROKE  (\u2908)
# U+2909     ⤉   UPWARDS ARROW WITH HORIZONTAL STROKE  (\u2909)
# U+290A     ⤊   UPWARDS TRIPLE ARROW  (\u290a)
# U+290B     ⤋   DOWNWARDS TRIPLE ARROW  (\u290b)
# U+290C     ⤌   LEFTWARDS DOUBLE DASH ARROW  (\u290c)
# U+290D     ⤍   RIGHTWARDS DOUBLE DASH ARROW  (\u290d)
# U+290E     ⤎   LEFTWARDS TRIPLE DASH ARROW  (\u290e)
# U+290F     ⤏   RIGHTWARDS TRIPLE DASH ARROW  (\u290f)
# U+2910     ⤐   RIGHTWARDS TWO-HEADED TRIPLE DASH ARROW  (\u2910)
# U+2911     ⤑   RIGHTWARDS ARROW WITH DOTTED STEM  (\u2911)
# U+2912     ⤒   UPWARDS ARROW TO BAR  (\u2912)
# U+2913     ⤓   DOWNWARDS ARROW TO BAR  (\u2913)
# U+2914     ⤔   RIGHTWARDS ARROW WITH TAIL WITH VERTICAL STROKE  (\u2914)
# U+2915     ⤕   RIGHTWARDS ARROW WITH TAIL WITH DOUBLE VERTICAL STROKE  (\u2915)
# U+2916     ⤖   RIGHTWARDS TWO-HEADED ARROW WITH TAIL  (\u2916)
# U+2917     ⤗   RIGHTWARDS TWO-HEADED ARROW WITH TAIL WITH VERTICAL STROKE  (\u2917)
# U+2918     ⤘   RIGHTWARDS TWO-HEADED ARROW WITH TAIL WITH DOUBLE VERTICAL STROKE  (\u2918)
# U+291D     ⤝   LEFTWARDS ARROW TO BLACK DIAMOND  (\u291d)
# U+291E     ⤞   RIGHTWARDS ARROW TO BLACK DIAMOND  (\u291e)
# U+291F     ⤟   LEFTWARDS ARROW FROM BAR TO BLACK DIAMOND  (\u291f)
# U+2920     ⤠   RIGHTWARDS ARROW FROM BAR TO BLACK DIAMOND  (\u2920)
# U+2921     ⤡   NORTH WEST AND SOUTH EAST ARROW  (\u2921)
# U+2922     ⤢   NORTH EAST AND SOUTH WEST ARROW  (\u2922)
# U+2923     ⤣   NORTH WEST ARROW WITH HOOK  (\u2923)
# U+2924     ⤤   NORTH EAST ARROW WITH HOOK  (\u2924)
# U+2925     ⤥   SOUTH EAST ARROW WITH HOOK  (\u2925)
# U+2926     ⤦   SOUTH WEST ARROW WITH HOOK  (\u2926)
# U+2927     ⤧   NORTH WEST ARROW AND NORTH EAST ARROW  (\u2927)
# U+2928     ⤨   NORTH EAST ARROW AND SOUTH EAST ARROW  (\u2928)
# U+2929     ⤩   SOUTH EAST ARROW AND SOUTH WEST ARROW  (\u2929)
# U+292A     ⤪   SOUTH WEST ARROW AND NORTH WEST ARROW  (\u292a)
# U+292D     ⤭   SOUTH EAST ARROW CROSSING NORTH EAST ARROW  (\u292d)
# U+292E     ⤮   NORTH EAST ARROW CROSSING SOUTH EAST ARROW  (\u292e)
# U+292F     ⤯   FALLING DIAGONAL CROSSING NORTH EAST ARROW  (\u292f)
# U+2930     ⤰   RISING DIAGONAL CROSSING SOUTH EAST ARROW  (\u2930)
# U+2931     ⤱   NORTH EAST ARROW CROSSING NORTH WEST ARROW  (\u2931)
# U+2932     ⤲   NORTH WEST ARROW CROSSING NORTH EAST ARROW  (\u2932)
# U+2933     ⤳   WAVE ARROW POINTING DIRECTLY RIGHT  (\u2933)
# U+2934     ⤴   ARROW POINTING RIGHTWARDS THEN CURVING UPWARDS  (\u2934)
# U+2935     ⤵   ARROW POINTING RIGHTWARDS THEN CURVING DOWNWARDS  (\u2935)
# U+2936     ⤶   ARROW POINTING DOWNWARDS THEN CURVING LEFTWARDS  (\u2936)
# U+2937     ⤷   ARROW POINTING DOWNWARDS THEN CURVING RIGHTWARDS  (\u2937)
# U+2938     ⤸   RIGHT-SIDE ARC CLOCKWISE ARROW  (\u2938)
# U+2939     ⤹   LEFT-SIDE ARC ANTICLOCKWISE ARROW  (\u2939)
# U+293A     ⤺   TOP ARC ANTICLOCKWISE ARROW  (\u293a)
# U+293B     ⤻   BOTTOM ARC ANTICLOCKWISE ARROW  (\u293b)
# U+293C     ⤼   TOP ARC CLOCKWISE ARROW WITH MINUS  (\u293c)
# U+293D     ⤽   TOP ARC ANTICLOCKWISE ARROW WITH PLUS  (\u293d)
# U+293E     ⤾   LOWER RIGHT SEMICIRCULAR CLOCKWISE ARROW  (\u293e)
# U+293F     ⤿   LOWER LEFT SEMICIRCULAR ANTICLOCKWISE ARROW  (\u293f)
# U+2940     ⥀   ANTICLOCKWISE CLOSED CIRCLE ARROW  (\u2940)
# U+2941     ⥁   CLOCKWISE CLOSED CIRCLE ARROW  (\u2941)
# U+2942     ⥂   RIGHTWARDS ARROW ABOVE SHORT LEFTWARDS ARROW  (\u2942)
# U+2943     ⥃   LEFTWARDS ARROW ABOVE SHORT RIGHTWARDS ARROW  (\u2943)
# U+2944     ⥄   SHORT RIGHTWARDS ARROW ABOVE LEFTWARDS ARROW  (\u2944)
# U+2945     ⥅   RIGHTWARDS ARROW WITH PLUS BELOW  (\u2945)
# U+2946     ⥆   LEFTWARDS ARROW WITH PLUS BELOW  (\u2946)
# U+2947     ⥇   RIGHTWARDS ARROW THROUGH X  (\u2947)
# U+2948     ⥈   LEFT RIGHT ARROW THROUGH SMALL CIRCLE  (\u2948)
# U+2949     ⥉   UPWARDS TWO-HEADED ARROW FROM SMALL CIRCLE  (\u2949)
# U+2970     ⥰   RIGHT DOUBLE ARROW WITH ROUNDED HEAD  (\u2970)
# U+2971     ⥱   EQUALS SIGN ABOVE RIGHTWARDS ARROW  (\u2971)
# U+2972     ⥲   TILDE OPERATOR ABOVE RIGHTWARDS ARROW  (\u2972)
# U+2973     ⥳   LEFTWARDS ARROW ABOVE TILDE OPERATOR  (\u2973)
# U+2974     ⥴   RIGHTWARDS ARROW ABOVE TILDE OPERATOR  (\u2974)
# U+2975     ⥵   RIGHTWARDS ARROW ABOVE ALMOST EQUAL TO  (\u2975)
# U+2976     ⥶   LESS-THAN ABOVE LEFTWARDS ARROW  (\u2976)
# U+2977     ⥷   LEFTWARDS ARROW THROUGH LESS-THAN  (\u2977)
# U+2978     ⥸   GREATER-THAN ABOVE RIGHTWARDS ARROW  (\u2978)
# U+2979     ⥹   SUBSET ABOVE RIGHTWARDS ARROW  (\u2979)
# U+297A     ⥺   LEFTWARDS ARROW THROUGH SUBSET  (\u297a)
# U+297B     ⥻   SUPERSET ABOVE LEFTWARDS ARROW  (\u297b)
# U+29A8     ⦨   MEASURED ANGLE WITH OPEN ARM ENDING IN ARROW POINTING UP AND RIGHT  (\u29a8)
# U+29A9     ⦩   MEASURED ANGLE WITH OPEN ARM ENDING IN ARROW POINTING UP AND LEFT  (\u29a9)
# U+29AA     ⦪   MEASURED ANGLE WITH OPEN ARM ENDING IN ARROW POINTING DOWN AND RIGHT  (\u29aa)
# U+29AB     ⦫   MEASURED ANGLE WITH OPEN ARM ENDING IN ARROW POINTING DOWN AND LEFT  (\u29ab)
# U+29AC     ⦬   MEASURED ANGLE WITH OPEN ARM ENDING IN ARROW POINTING RIGHT AND UP  (\u29ac)
# U+29AD     ⦭   MEASURED ANGLE WITH OPEN ARM ENDING IN ARROW POINTING LEFT AND UP  (\u29ad)
# U+29AE     ⦮   MEASURED ANGLE WITH OPEN ARM ENDING IN ARROW POINTING RIGHT AND DOWN  (\u29ae)
# U+29AF     ⦯   MEASURED ANGLE WITH OPEN ARM ENDING IN ARROW POINTING LEFT AND DOWN  (\u29af)
# U+29B3     ⦳   EMPTY SET WITH RIGHT ARROW ABOVE  (\u29b3)
# U+29B4     ⦴   EMPTY SET WITH LEFT ARROW ABOVE  (\u29b4)
# U+29BD     ⦽   UP ARROW THROUGH CIRCLE  (\u29bd)
# U+29EA     ⧪   BLACK DIAMOND WITH DOWN ARROW  (\u29ea)
# U+29EC     ⧬   WHITE CIRCLE WITH DOWN ARROW  (\u29ec)
# U+29ED     ⧭   BLACK CIRCLE WITH DOWN ARROW  (\u29ed)
# U+2A17     ⨗   INTEGRAL WITH LEFTWARDS ARROW WITH HOOK  (\u2a17)
# U+2B00     ⬀   NORTH EAST WHITE ARROW  (\u2b00)
# U+2B01     ⬁   NORTH WEST WHITE ARROW  (\u2b01)
# U+2B02     ⬂   SOUTH EAST WHITE ARROW  (\u2b02)
# U+2B03     ⬃   SOUTH WEST WHITE ARROW  (\u2b03)
# U+2B04     ⬄   LEFT RIGHT WHITE ARROW  (\u2b04)
# U+2B05     ⬅   LEFTWARDS BLACK ARROW  (\u2b05)
# U+2B06     ⬆   UPWARDS BLACK ARROW  (\u2b06)
# U+2B07     ⬇   DOWNWARDS BLACK ARROW  (\u2b07)
# U+2B08     ⬈   NORTH EAST BLACK ARROW  (\u2b08)
# U+2B09     ⬉   NORTH WEST BLACK ARROW  (\u2b09)
# U+2B0A     ⬊   SOUTH EAST BLACK ARROW  (\u2b0a)
# U+2B0B     ⬋   SOUTH WEST BLACK ARROW  (\u2b0b)
# U+2B0C     ⬌   LEFT RIGHT BLACK ARROW  (\u2b0c)
# U+2B0D     ⬍   UP DOWN BLACK ARROW  (\u2b0d)
# U+2B0E     ⬎   RIGHTWARDS ARROW WITH TIP DOWNWARDS  (\u2b0e)
# U+2B0F     ⬏   RIGHTWARDS ARROW WITH TIP UPWARDS  (\u2b0f)
# U+2B10     ⬐   LEFTWARDS ARROW WITH TIP DOWNWARDS  (\u2b10)
# U+2B11     ⬑   LEFTWARDS ARROW WITH TIP UPWARDS  (\u2b11)
# U+2B30     ⬰   LEFT ARROW WITH SMALL CIRCLE  (\u2b30)
# U+2B32     ⬲   LEFT ARROW WITH CIRCLED PLUS  (\u2b32)
# U+2B33     ⬳   LONG LEFTWARDS SQUIGGLE ARROW  (\u2b33)
# U+2B34     ⬴   LEFTWARDS TWO-HEADED ARROW WITH VERTICAL STROKE  (\u2b34)
# U+2B35     ⬵   LEFTWARDS TWO-HEADED ARROW WITH DOUBLE VERTICAL STROKE  (\u2b35)
# U+2B36     ⬶   LEFTWARDS TWO-HEADED ARROW FROM BAR  (\u2b36)
# U+2B37     ⬷   LEFTWARDS TWO-HEADED TRIPLE DASH ARROW  (\u2b37)
# U+2B38     ⬸   LEFTWARDS ARROW WITH DOTTED STEM  (\u2b38)
# U+2B39     ⬹   LEFTWARDS ARROW WITH TAIL WITH VERTICAL STROKE  (\u2b39)
# U+2B3A     ⬺   LEFTWARDS ARROW WITH TAIL WITH DOUBLE VERTICAL STROKE  (\u2b3a)
# U+2B3B     ⬻   LEFTWARDS TWO-HEADED ARROW WITH TAIL  (\u2b3b)
# U+2B3C     ⬼   LEFTWARDS TWO-HEADED ARROW WITH TAIL WITH VERTICAL STROKE  (\u2b3c)
# U+2B3D     ⬽   LEFTWARDS TWO-HEADED ARROW WITH TAIL WITH DOUBLE VERTICAL STROKE  (\u2b3d)
# U+2B3E     ⬾   LEFTWARDS ARROW THROUGH X  (\u2b3e)
# U+2B3F     ⬿   WAVE ARROW POINTING DIRECTLY LEFT  (\u2b3f)
# U+2B40     ⭀   EQUALS SIGN ABOVE LEFTWARDS ARROW  (\u2b40)
# U+2B41     ⭁   REVERSE TILDE OPERATOR ABOVE LEFTWARDS ARROW  (\u2b41)
# U+2B42     ⭂   LEFTWARDS ARROW ABOVE REVERSE ALMOST EQUAL TO  (\u2b42)
# U+2B43     ⭃   RIGHTWARDS ARROW THROUGH GREATER-THAN  (\u2b43)
# U+2B44     ⭄   RIGHTWARDS ARROW THROUGH SUPERSET  (\u2b44)
# U+2B45     ⭅   LEFTWARDS QUADRUPLE ARROW  (\u2b45)
# U+2B46     ⭆   RIGHTWARDS QUADRUPLE ARROW  (\u2b46)
# U+2B47     ⭇   REVERSE TILDE OPERATOR ABOVE RIGHTWARDS ARROW  (\u2b47)
# U+2B48     ⭈   RIGHTWARDS ARROW ABOVE REVERSE ALMOST EQUAL TO  (\u2b48)
# U+2B49     ⭉   TILDE OPERATOR ABOVE LEFTWARDS ARROW  (\u2b49)
# U+2B4A     ⭊   LEFTWARDS ARROW ABOVE ALMOST EQUAL TO  (\u2b4a)
# U+2B4B     ⭋   LEFTWARDS ARROW ABOVE REVERSE TILDE OPERATOR  (\u2b4b)
# U+2B4C     ⭌   RIGHTWARDS ARROW ABOVE REVERSE TILDE OPERATOR  (\u2b4c)
# U+2B4D     ⭍   DOWNWARDS TRIANGLE-HEADED ZIGZAG ARROW  (\u2b4d)
# U+2B4E     ⭎   SHORT SLANTED NORTH ARROW  (\u2b4e)
# U+2B4F     ⭏   SHORT BACKSLANTED SOUTH ARROW  (\u2b4f)
# U+2B5A     ⭚   SLANTED NORTH ARROW WITH HOOKED HEAD  (\u2b5a)
# U+2B5B     ⭛   BACKSLANTED SOUTH ARROW WITH HOOKED TAIL  (\u2b5b)
# U+2B5C     ⭜   SLANTED NORTH ARROW WITH HORIZONTAL TAIL  (\u2b5c)
# U+2B5D     ⭝   BACKSLANTED SOUTH ARROW WITH HORIZONTAL TAIL  (\u2b5d)
# U+2B5E     ⭞   BENT ARROW POINTING DOWNWARDS THEN NORTH EAST  (\u2b5e)
# U+2B5F     ⭟   SHORT BENT ARROW POINTING DOWNWARDS THEN NORTH EAST  (\u2b5f)
# U+2B60     ⭠   LEFTWARDS TRIANGLE-HEADED ARROW  (\u2b60)
# U+2B61     ⭡   UPWARDS TRIANGLE-HEADED ARROW  (\u2b61)
# U+2B62     ⭢   RIGHTWARDS TRIANGLE-HEADED ARROW  (\u2b62)
# U+2B63     ⭣   DOWNWARDS TRIANGLE-HEADED ARROW  (\u2b63)
# U+2B64     ⭤   LEFT RIGHT TRIANGLE-HEADED ARROW  (\u2b64)
# U+2B65     ⭥   UP DOWN TRIANGLE-HEADED ARROW  (\u2b65)
# U+2B66     ⭦   NORTH WEST TRIANGLE-HEADED ARROW  (\u2b66)
# U+2B67     ⭧   NORTH EAST TRIANGLE-HEADED ARROW  (\u2b67)
# U+2B68     ⭨   SOUTH EAST TRIANGLE-HEADED ARROW  (\u2b68)
# U+2B69     ⭩   SOUTH WEST TRIANGLE-HEADED ARROW  (\u2b69)
# U+2B6A     ⭪   LEFTWARDS TRIANGLE-HEADED DASHED ARROW  (\u2b6a)
# U+2B6B     ⭫   UPWARDS TRIANGLE-HEADED DASHED ARROW  (\u2b6b)
# U+2B6C     ⭬   RIGHTWARDS TRIANGLE-HEADED DASHED ARROW  (\u2b6c)
# U+2B6D     ⭭   DOWNWARDS TRIANGLE-HEADED DASHED ARROW  (\u2b6d)
# U+2B6E     ⭮   CLOCKWISE TRIANGLE-HEADED OPEN CIRCLE ARROW  (\u2b6e)
# U+2B6F     ⭯   ANTICLOCKWISE TRIANGLE-HEADED OPEN CIRCLE ARROW  (\u2b6f)
# U+2B70     ⭰   LEFTWARDS TRIANGLE-HEADED ARROW TO BAR  (\u2b70)
# U+2B71     ⭱   UPWARDS TRIANGLE-HEADED ARROW TO BAR  (\u2b71)
# U+2B72     ⭲   RIGHTWARDS TRIANGLE-HEADED ARROW TO BAR  (\u2b72)
# U+2B73     ⭳   DOWNWARDS TRIANGLE-HEADED ARROW TO BAR  (\u2b73)
# U+2B76     ⭶   NORTH WEST TRIANGLE-HEADED ARROW TO BAR  (\u2b76)
# U+2B77     ⭷   NORTH EAST TRIANGLE-HEADED ARROW TO BAR  (\u2b77)
# U+2B78     ⭸   SOUTH EAST TRIANGLE-HEADED ARROW TO BAR  (\u2b78)
# U+2B79     ⭹   SOUTH WEST TRIANGLE-HEADED ARROW TO BAR  (\u2b79)
# U+2B7A     ⭺   LEFTWARDS TRIANGLE-HEADED ARROW WITH DOUBLE HORIZONTAL STROKE  (\u2b7a)
# U+2B7B     ⭻   UPWARDS TRIANGLE-HEADED ARROW WITH DOUBLE HORIZONTAL STROKE  (\u2b7b)
# U+2B7C     ⭼   RIGHTWARDS TRIANGLE-HEADED ARROW WITH DOUBLE HORIZONTAL STROKE  (\u2b7c)
# U+2B7D     ⭽   DOWNWARDS TRIANGLE-HEADED ARROW WITH DOUBLE HORIZONTAL STROKE  (\u2b7d)
# U+2B80     ⮀   LEFTWARDS TRIANGLE-HEADED ARROW OVER RIGHTWARDS TRIANGLE-HEADED ARROW  (\u2b80)
# U+2B81     ⮁   UPWARDS TRIANGLE-HEADED ARROW LEFTWARDS OF DOWNWARDS TRIANGLE-HEADED ARROW  (\u2b81)
# U+2B82     ⮂   RIGHTWARDS TRIANGLE-HEADED ARROW OVER LEFTWARDS TRIANGLE-HEADED ARROW  (\u2b82)
# U+2B83     ⮃   DOWNWARDS TRIANGLE-HEADED ARROW LEFTWARDS OF UPWARDS TRIANGLE-HEADED ARROW  (\u2b83)
# U+2B88     ⮈   LEFTWARDS BLACK CIRCLED WHITE ARROW  (\u2b88)
# U+2B89     ⮉   UPWARDS BLACK CIRCLED WHITE ARROW  (\u2b89)
# U+2B8A     ⮊   RIGHTWARDS BLACK CIRCLED WHITE ARROW  (\u2b8a)
# U+2B8B     ⮋   DOWNWARDS BLACK CIRCLED WHITE ARROW  (\u2b8b)
# U+2B8C     ⮌   ANTICLOCKWISE TRIANGLE-HEADED RIGHT U-SHAPED ARROW  (\u2b8c)
# U+2B8D     ⮍   ANTICLOCKWISE TRIANGLE-HEADED BOTTOM U-SHAPED ARROW  (\u2b8d)
# U+2B8E     ⮎   ANTICLOCKWISE TRIANGLE-HEADED LEFT U-SHAPED ARROW  (\u2b8e)
# U+2B8F     ⮏   ANTICLOCKWISE TRIANGLE-HEADED TOP U-SHAPED ARROW  (\u2b8f)
# U+2B95     ⮕   RIGHTWARDS BLACK ARROW  (\u2b95)
# U+2BA0     ⮠   DOWNWARDS TRIANGLE-HEADED ARROW WITH LONG TIP LEFTWARDS  (\u2ba0)
# U+2BA1     ⮡   DOWNWARDS TRIANGLE-HEADED ARROW WITH LONG TIP RIGHTWARDS  (\u2ba1)
# U+2BA2     ⮢   UPWARDS TRIANGLE-HEADED ARROW WITH LONG TIP LEFTWARDS  (\u2ba2)
# U+2BA3     ⮣   UPWARDS TRIANGLE-HEADED ARROW WITH LONG TIP RIGHTWARDS  (\u2ba3)
# U+2BA4     ⮤   LEFTWARDS TRIANGLE-HEADED ARROW WITH LONG TIP UPWARDS  (\u2ba4)
# U+2BA5     ⮥   RIGHTWARDS TRIANGLE-HEADED ARROW WITH LONG TIP UPWARDS  (\u2ba5)
# U+2BA6     ⮦   LEFTWARDS TRIANGLE-HEADED ARROW WITH LONG TIP DOWNWARDS  (\u2ba6)
# U+2BA7     ⮧   RIGHTWARDS TRIANGLE-HEADED ARROW WITH LONG TIP DOWNWARDS  (\u2ba7)
# U+2BA8     ⮨   BLACK CURVED DOWNWARDS AND LEFTWARDS ARROW  (\u2ba8)
# U+2BA9     ⮩   BLACK CURVED DOWNWARDS AND RIGHTWARDS ARROW  (\u2ba9)
# U+2BAA     ⮪   BLACK CURVED UPWARDS AND LEFTWARDS ARROW  (\u2baa)
# U+2BAB     ⮫   BLACK CURVED UPWARDS AND RIGHTWARDS ARROW  (\u2bab)
# U+2BAC     ⮬   BLACK CURVED LEFTWARDS AND UPWARDS ARROW  (\u2bac)
# U+2BAD     ⮭   BLACK CURVED RIGHTWARDS AND UPWARDS ARROW  (\u2bad)
# U+2BAE     ⮮   BLACK CURVED LEFTWARDS AND DOWNWARDS ARROW  (\u2bae)
# U+2BAF     ⮯   BLACK CURVED RIGHTWARDS AND DOWNWARDS ARROW  (\u2baf)
# U+2BB0     ⮰   RIBBON ARROW DOWN LEFT  (\u2bb0)
# U+2BB1     ⮱   RIBBON ARROW DOWN RIGHT  (\u2bb1)
# U+2BB2     ⮲   RIBBON ARROW UP LEFT  (\u2bb2)
# U+2BB3     ⮳   RIBBON ARROW UP RIGHT  (\u2bb3)
# U+2BB4     ⮴   RIBBON ARROW LEFT UP  (\u2bb4)
# U+2BB5     ⮵   RIBBON ARROW RIGHT UP  (\u2bb5)
# U+2BB6     ⮶   RIBBON ARROW LEFT DOWN  (\u2bb6)
# U+2BB7     ⮷   RIBBON ARROW RIGHT DOWN  (\u2bb7)
# U+2BB8     ⮸   UPWARDS WHITE ARROW FROM BAR WITH HORIZONTAL BAR  (\u2bb8)
# U+2BEC     ⯬   LEFTWARDS TWO-HEADED ARROW WITH TRIANGLE ARROWHEADS  (\u2bec)
# U+2BED     ⯭   UPWARDS TWO-HEADED ARROW WITH TRIANGLE ARROWHEADS  (\u2bed)
# U+2BEE     ⯮   RIGHTWARDS TWO-HEADED ARROW WITH TRIANGLE ARROWHEADS  (\u2bee)
# U+2BEF     ⯯   DOWNWARDS TWO-HEADED ARROW WITH TRIANGLE ARROWHEADS  (\u2bef)
# U+2F6E     ⽮   KANGXI RADICAL ARROW  (\u2f6e)
# U+A71B     ꜛ   MODIFIER LETTER RAISED UP ARROW  (\ua71b)
# U+A71C     ꜜ   MODIFIER LETTER RAISED DOWN ARROW  (\ua71c)
# U+FFE9     ￩   HALFWIDTH LEFTWARDS ARROW  (\uffe9)
# U+FFEA     ￪   HALFWIDTH UPWARDS ARROW  (\uffea)
# U+FFEB     ￫   HALFWIDTH RIGHTWARDS ARROW  (\uffeb)
# U+FFEC     ￬   HALFWIDTH DOWNWARDS ARROW  (\uffec)
# U+100C7    𐃇   LINEAR B IDEOGRAM B231 ARROW  (\u100c7)
# U+101D9    𐇙   PHAISTOS DISC SIGN ARROW  (\u101d9)
# U+1BC99    𛲙   DUPLOYAN AFFIX LOW ARROW  (\u1bc99)
# U+1F10E    🄎   CIRCLED ANTICLOCKWISE ARROW  (\u1f10e)
# U+1F3F9    🏹   BOW AND ARROW  (\u1f3f9)
# U+1F498    💘   HEART WITH ARROW  (\u1f498)
# U+1F4E9    📩   ENVELOPE WITH DOWNWARDS ARROW ABOVE  (\u1f4e9)
# U+1F4F2    📲   MOBILE PHONE WITH RIGHTWARDS ARROW AT LEFT  (\u1f4f2)
# U+1F519    🔙   BACK WITH LEFTWARDS ARROW ABOVE  (\u1f519)
# U+1F51A    🔚   END WITH LEFTWARDS ARROW ABOVE  (\u1f51a)
# U+1F51B    🔛   ON WITH EXCLAMATION MARK WITH LEFT RIGHT ARROW ABOVE  (\u1f51b)
# U+1F51C    🔜   SOON WITH RIGHTWARDS ARROW ABOVE  (\u1f51c)
# U+1F51D    🔝   TOP WITH UPWARDS ARROW ABOVE  (\u1f51d)
# U+1F800    🠀   LEFTWARDS ARROW WITH SMALL TRIANGLE ARROWHEAD  (\u1f800)
# U+1F801    🠁   UPWARDS ARROW WITH SMALL TRIANGLE ARROWHEAD  (\u1f801)
# U+1F802    🠂   RIGHTWARDS ARROW WITH SMALL TRIANGLE ARROWHEAD  (\u1f802)
# U+1F803    🠃   DOWNWARDS ARROW WITH SMALL TRIANGLE ARROWHEAD  (\u1f803)
# U+1F804    🠄   LEFTWARDS ARROW WITH MEDIUM TRIANGLE ARROWHEAD  (\u1f804)
# U+1F805    🠅   UPWARDS ARROW WITH MEDIUM TRIANGLE ARROWHEAD  (\u1f805)
# U+1F806    🠆   RIGHTWARDS ARROW WITH MEDIUM TRIANGLE ARROWHEAD  (\u1f806)
# U+1F807    🠇   DOWNWARDS ARROW WITH MEDIUM TRIANGLE ARROWHEAD  (\u1f807)
# U+1F808    🠈   LEFTWARDS ARROW WITH LARGE TRIANGLE ARROWHEAD  (\u1f808)
# U+1F809    🠉   UPWARDS ARROW WITH LARGE TRIANGLE ARROWHEAD  (\u1f809)
# U+1F80A    🠊   RIGHTWARDS ARROW WITH LARGE TRIANGLE ARROWHEAD  (\u1f80a)
# U+1F80B    🠋   DOWNWARDS ARROW WITH LARGE TRIANGLE ARROWHEAD  (\u1f80b)
# U+1F810    🠐   LEFTWARDS ARROW WITH SMALL EQUILATERAL ARROWHEAD  (\u1f810)
# U+1F811    🠑   UPWARDS ARROW WITH SMALL EQUILATERAL ARROWHEAD  (\u1f811)
# U+1F812    🠒   RIGHTWARDS ARROW WITH SMALL EQUILATERAL ARROWHEAD  (\u1f812)
# U+1F813    🠓   DOWNWARDS ARROW WITH SMALL EQUILATERAL ARROWHEAD  (\u1f813)
# U+1F814    🠔   LEFTWARDS ARROW WITH EQUILATERAL ARROWHEAD  (\u1f814)
# U+1F815    🠕   UPWARDS ARROW WITH EQUILATERAL ARROWHEAD  (\u1f815)
# U+1F816    🠖   RIGHTWARDS ARROW WITH EQUILATERAL ARROWHEAD  (\u1f816)
# U+1F817    🠗   DOWNWARDS ARROW WITH EQUILATERAL ARROWHEAD  (\u1f817)
# U+1F818    🠘   HEAVY LEFTWARDS ARROW WITH EQUILATERAL ARROWHEAD  (\u1f818)
# U+1F819    🠙   HEAVY UPWARDS ARROW WITH EQUILATERAL ARROWHEAD  (\u1f819)
# U+1F81A    🠚   HEAVY RIGHTWARDS ARROW WITH EQUILATERAL ARROWHEAD  (\u1f81a)
# U+1F81B    🠛   HEAVY DOWNWARDS ARROW WITH EQUILATERAL ARROWHEAD  (\u1f81b)
# U+1F81C    🠜   HEAVY LEFTWARDS ARROW WITH LARGE EQUILATERAL ARROWHEAD  (\u1f81c)
# U+1F81D    🠝   HEAVY UPWARDS ARROW WITH LARGE EQUILATERAL ARROWHEAD  (\u1f81d)
# U+1F81E    🠞   HEAVY RIGHTWARDS ARROW WITH LARGE EQUILATERAL ARROWHEAD  (\u1f81e)
# U+1F81F    🠟   HEAVY DOWNWARDS ARROW WITH LARGE EQUILATERAL ARROWHEAD  (\u1f81f)
# U+1F820    🠠   LEFTWARDS TRIANGLE-HEADED ARROW WITH NARROW SHAFT  (\u1f820)
# U+1F821    🠡   UPWARDS TRIANGLE-HEADED ARROW WITH NARROW SHAFT  (\u1f821)
# U+1F822    🠢   RIGHTWARDS TRIANGLE-HEADED ARROW WITH NARROW SHAFT  (\u1f822)
# U+1F823    🠣   DOWNWARDS TRIANGLE-HEADED ARROW WITH NARROW SHAFT  (\u1f823)
# U+1F824    🠤   LEFTWARDS TRIANGLE-HEADED ARROW WITH MEDIUM SHAFT  (\u1f824)
# U+1F825    🠥   UPWARDS TRIANGLE-HEADED ARROW WITH MEDIUM SHAFT  (\u1f825)
# U+1F826    🠦   RIGHTWARDS TRIANGLE-HEADED ARROW WITH MEDIUM SHAFT  (\u1f826)
# U+1F827    🠧   DOWNWARDS TRIANGLE-HEADED ARROW WITH MEDIUM SHAFT  (\u1f827)
# U+1F828    🠨   LEFTWARDS TRIANGLE-HEADED ARROW WITH BOLD SHAFT  (\u1f828)
# U+1F829    🠩   UPWARDS TRIANGLE-HEADED ARROW WITH BOLD SHAFT  (\u1f829)
# U+1F82A    🠪   RIGHTWARDS TRIANGLE-HEADED ARROW WITH BOLD SHAFT  (\u1f82a)
# U+1F82B    🠫   DOWNWARDS TRIANGLE-HEADED ARROW WITH BOLD SHAFT  (\u1f82b)
# U+1F82C    🠬   LEFTWARDS TRIANGLE-HEADED ARROW WITH HEAVY SHAFT  (\u1f82c)
# U+1F82D    🠭   UPWARDS TRIANGLE-HEADED ARROW WITH HEAVY SHAFT  (\u1f82d)
# U+1F82E    🠮   RIGHTWARDS TRIANGLE-HEADED ARROW WITH HEAVY SHAFT  (\u1f82e)
# U+1F82F    🠯   DOWNWARDS TRIANGLE-HEADED ARROW WITH HEAVY SHAFT  (\u1f82f)
# U+1F830    🠰   LEFTWARDS TRIANGLE-HEADED ARROW WITH VERY HEAVY SHAFT  (\u1f830)
# U+1F831    🠱   UPWARDS TRIANGLE-HEADED ARROW WITH VERY HEAVY SHAFT  (\u1f831)
# U+1F832    🠲   RIGHTWARDS TRIANGLE-HEADED ARROW WITH VERY HEAVY SHAFT  (\u1f832)
# U+1F833    🠳   DOWNWARDS TRIANGLE-HEADED ARROW WITH VERY HEAVY SHAFT  (\u1f833)
# U+1F834    🠴   LEFTWARDS FINGER-POST ARROW  (\u1f834)
# U+1F835    🠵   UPWARDS FINGER-POST ARROW  (\u1f835)
# U+1F836    🠶   RIGHTWARDS FINGER-POST ARROW  (\u1f836)
# U+1F837    🠷   DOWNWARDS FINGER-POST ARROW  (\u1f837)
# U+1F838    🠸   LEFTWARDS SQUARED ARROW  (\u1f838)
# U+1F839    🠹   UPWARDS SQUARED ARROW  (\u1f839)
# U+1F83A    🠺   RIGHTWARDS SQUARED ARROW  (\u1f83a)
# U+1F83B    🠻   DOWNWARDS SQUARED ARROW  (\u1f83b)
# U+1F83C    🠼   LEFTWARDS COMPRESSED ARROW  (\u1f83c)
# U+1F83D    🠽   UPWARDS COMPRESSED ARROW  (\u1f83d)
# U+1F83E    🠾   RIGHTWARDS COMPRESSED ARROW  (\u1f83e)
# U+1F83F    🠿   DOWNWARDS COMPRESSED ARROW  (\u1f83f)
# U+1F840    🡀   LEFTWARDS HEAVY COMPRESSED ARROW  (\u1f840)
# U+1F841    🡁   UPWARDS HEAVY COMPRESSED ARROW  (\u1f841)
# U+1F842    🡂   RIGHTWARDS HEAVY COMPRESSED ARROW  (\u1f842)
# U+1F843    🡃   DOWNWARDS HEAVY COMPRESSED ARROW  (\u1f843)
# U+1F844    🡄   LEFTWARDS HEAVY ARROW  (\u1f844)
# U+1F845    🡅   UPWARDS HEAVY ARROW  (\u1f845)
# U+1F846    🡆   RIGHTWARDS HEAVY ARROW  (\u1f846)
# U+1F847    🡇   DOWNWARDS HEAVY ARROW  (\u1f847)
# U+1F850    🡐   LEFTWARDS SANS-SERIF ARROW  (\u1f850)
# U+1F851    🡑   UPWARDS SANS-SERIF ARROW  (\u1f851)
# U+1F852    🡒   RIGHTWARDS SANS-SERIF ARROW  (\u1f852)
# U+1F853    🡓   DOWNWARDS SANS-SERIF ARROW  (\u1f853)
# U+1F854    🡔   NORTH WEST SANS-SERIF ARROW  (\u1f854)
# U+1F855    🡕   NORTH EAST SANS-SERIF ARROW  (\u1f855)
# U+1F856    🡖   SOUTH EAST SANS-SERIF ARROW  (\u1f856)
# U+1F857    🡗   SOUTH WEST SANS-SERIF ARROW  (\u1f857)
# U+1F858    🡘   LEFT RIGHT SANS-SERIF ARROW  (\u1f858)
# U+1F859    🡙   UP DOWN SANS-SERIF ARROW  (\u1f859)
# U+1F860    🡠   WIDE-HEADED LEFTWARDS LIGHT BARB ARROW  (\u1f860)
# U+1F861    🡡   WIDE-HEADED UPWARDS LIGHT BARB ARROW  (\u1f861)
# U+1F862    🡢   WIDE-HEADED RIGHTWARDS LIGHT BARB ARROW  (\u1f862)
# U+1F863    🡣   WIDE-HEADED DOWNWARDS LIGHT BARB ARROW  (\u1f863)
# U+1F864    🡤   WIDE-HEADED NORTH WEST LIGHT BARB ARROW  (\u1f864)
# U+1F865    🡥   WIDE-HEADED NORTH EAST LIGHT BARB ARROW  (\u1f865)
# U+1F866    🡦   WIDE-HEADED SOUTH EAST LIGHT BARB ARROW  (\u1f866)
# U+1F867    🡧   WIDE-HEADED SOUTH WEST LIGHT BARB ARROW  (\u1f867)
# U+1F868    🡨   WIDE-HEADED LEFTWARDS BARB ARROW  (\u1f868)
# U+1F869    🡩   WIDE-HEADED UPWARDS BARB ARROW  (\u1f869)
# U+1F86A    🡪   WIDE-HEADED RIGHTWARDS BARB ARROW  (\u1f86a)
# U+1F86B    🡫   WIDE-HEADED DOWNWARDS BARB ARROW  (\u1f86b)
# U+1F86C    🡬   WIDE-HEADED NORTH WEST BARB ARROW  (\u1f86c)
# U+1F86D    🡭   WIDE-HEADED NORTH EAST BARB ARROW  (\u1f86d)
# U+1F86E    🡮   WIDE-HEADED SOUTH EAST BARB ARROW  (\u1f86e)
# U+1F86F    🡯   WIDE-HEADED SOUTH WEST BARB ARROW  (\u1f86f)
# U+1F870    🡰   WIDE-HEADED LEFTWARDS MEDIUM BARB ARROW  (\u1f870)
# U+1F871    🡱   WIDE-HEADED UPWARDS MEDIUM BARB ARROW  (\u1f871)
# U+1F872    🡲   WIDE-HEADED RIGHTWARDS MEDIUM BARB ARROW  (\u1f872)
# U+1F873    🡳   WIDE-HEADED DOWNWARDS MEDIUM BARB ARROW  (\u1f873)
# U+1F874    🡴   WIDE-HEADED NORTH WEST MEDIUM BARB ARROW  (\u1f874)
# U+1F875    🡵   WIDE-HEADED NORTH EAST MEDIUM BARB ARROW  (\u1f875)
# U+1F876    🡶   WIDE-HEADED SOUTH EAST MEDIUM BARB ARROW  (\u1f876)
# U+1F877    🡷   WIDE-HEADED SOUTH WEST MEDIUM BARB ARROW  (\u1f877)
# U+1F878    🡸   WIDE-HEADED LEFTWARDS HEAVY BARB ARROW  (\u1f878)
# U+1F879    🡹   WIDE-HEADED UPWARDS HEAVY BARB ARROW  (\u1f879)
# U+1F87A    🡺   WIDE-HEADED RIGHTWARDS HEAVY BARB ARROW  (\u1f87a)
# U+1F87B    🡻   WIDE-HEADED DOWNWARDS HEAVY BARB ARROW  (\u1f87b)
# U+1F87C    🡼   WIDE-HEADED NORTH WEST HEAVY BARB ARROW  (\u1f87c)
# U+1F87D    🡽   WIDE-HEADED NORTH EAST HEAVY BARB ARROW  (\u1f87d)
# U+1F87E    🡾   WIDE-HEADED SOUTH EAST HEAVY BARB ARROW  (\u1f87e)
# U+1F87F    🡿   WIDE-HEADED SOUTH WEST HEAVY BARB ARROW  (\u1f87f)
# U+1F880    🢀   WIDE-HEADED LEFTWARDS VERY HEAVY BARB ARROW  (\u1f880)
# U+1F881    🢁   WIDE-HEADED UPWARDS VERY HEAVY BARB ARROW  (\u1f881)
# U+1F882    🢂   WIDE-HEADED RIGHTWARDS VERY HEAVY BARB ARROW  (\u1f882)
# U+1F883    🢃   WIDE-HEADED DOWNWARDS VERY HEAVY BARB ARROW  (\u1f883)
# U+1F884    🢄   WIDE-HEADED NORTH WEST VERY HEAVY BARB ARROW  (\u1f884)
# U+1F885    🢅   WIDE-HEADED NORTH EAST VERY HEAVY BARB ARROW  (\u1f885)
# U+1F886    🢆   WIDE-HEADED SOUTH EAST VERY HEAVY BARB ARROW  (\u1f886)
# U+1F887    🢇   WIDE-HEADED SOUTH WEST VERY HEAVY BARB ARROW  (\u1f887)
# U+1F894    🢔   LEFTWARDS WHITE ARROW WITHIN TRIANGLE ARROWHEAD  (\u1f894)
# U+1F895    🢕   UPWARDS WHITE ARROW WITHIN TRIANGLE ARROWHEAD  (\u1f895)
# U+1F896    🢖   RIGHTWARDS WHITE ARROW WITHIN TRIANGLE ARROWHEAD  (\u1f896)
# U+1F897    🢗   DOWNWARDS WHITE ARROW WITHIN TRIANGLE ARROWHEAD  (\u1f897)
# U+1F898    🢘   LEFTWARDS ARROW WITH NOTCHED TAIL  (\u1f898)
# U+1F899    🢙   UPWARDS ARROW WITH NOTCHED TAIL  (\u1f899)
# U+1F89A    🢚   RIGHTWARDS ARROW WITH NOTCHED TAIL  (\u1f89a)
# U+1F89B    🢛   DOWNWARDS ARROW WITH NOTCHED TAIL  (\u1f89b)
# U+1F89C    🢜   HEAVY ARROW SHAFT WIDTH ONE  (\u1f89c)
# U+1F89D    🢝   HEAVY ARROW SHAFT WIDTH TWO THIRDS  (\u1f89d)
# U+1F89E    🢞   HEAVY ARROW SHAFT WIDTH ONE HALF  (\u1f89e)
# U+1F89F    🢟   HEAVY ARROW SHAFT WIDTH ONE THIRD  (\u1f89f)
# U+1F8A0    🢠   LEFTWARDS BOTTOM-SHADED WHITE ARROW  (\u1f8a0)
# U+1F8A1    🢡   RIGHTWARDS BOTTOM SHADED WHITE ARROW  (\u1f8a1)
# U+1F8A2    🢢   LEFTWARDS TOP SHADED WHITE ARROW  (\u1f8a2)
# U+1F8A3    🢣   RIGHTWARDS TOP SHADED WHITE ARROW  (\u1f8a3)
# U+1F8A4    🢤   LEFTWARDS LEFT-SHADED WHITE ARROW  (\u1f8a4)
# U+1F8A5    🢥   RIGHTWARDS RIGHT-SHADED WHITE ARROW  (\u1f8a5)
# U+1F8A6    🢦   LEFTWARDS RIGHT-SHADED WHITE ARROW  (\u1f8a6)
# U+1F8A7    🢧   RIGHTWARDS LEFT-SHADED WHITE ARROW  (\u1f8a7)
# U+1F8A8    🢨   LEFTWARDS BACK-TILTED SHADOWED WHITE ARROW  (\u1f8a8)
# U+1F8A9    🢩   RIGHTWARDS BACK-TILTED SHADOWED WHITE ARROW  (\u1f8a9)
# U+1F8AA    🢪   LEFTWARDS FRONT-TILTED SHADOWED WHITE ARROW  (\u1f8aa)
# U+1F8AB    🢫   RIGHTWARDS FRONT-TILTED SHADOWED WHITE ARROW  (\u1f8ab)
# U+1F8AC    🢬   WHITE ARROW SHAFT WIDTH ONE  (\u1f8ac)
# U+1F8AD    🢭   WHITE ARROW SHAFT WIDTH TWO THIRDS  (\u1f8ad)
# U+1F8B0    🢰   ARROW POINTING UPWARDS THEN NORTH WEST  (\u1f8b0)
# U+1F8B1    🢱   ARROW POINTING RIGHTWARDS THEN CURVING SOUTH WEST  (\u1f8b1)
# U+1FBB4    🮴   INVERSE DOWNWARDS ARROW WITH TIP LEFTWARDS  (\u1fbb4)
# U+1FBB5    🮵   LEFTWARDS ARROW AND UPPER AND LOWER ONE EIGHTH BLOCK  (\u1fbb5)
# U+1FBB6    🮶   RIGHTWARDS ARROW AND UPPER AND LOWER ONE EIGHTH BLOCK  (\u1fbb6)
# U+1FBB7    🮷   DOWNWARDS ARROW AND RIGHT ONE EIGHTH BLOCK  (\u1fbb7)
# U+1FBB8    🮸   UPWARDS ARROW AND RIGHT ONE EIGHTH BLOCK  (\u1fbb8)

# %% [markdown]
# #### Fuzzy Match, Low Threshold

# %%
query = "arw"
results = list(find_chars(query, fuzzy=True, threshold=0.3))

print("\n".join(results))
# Out:
# [INFO] Loaded Unicode name cache from: "C:\Users\HamedVAHEB\Documents\Projects\Python\charfinder\data\cache\unicode_name_cache.json"
# [INFO] No exact match found for 'arw', trying fuzzy...
# [INFO] Fuzzy settings: threshold=0.3, agg_fn=mean
# [DEBUG] Skipped char '+' (U+002B) — no valid score computed.
# [DEBUG] Skipped char '-' (U+002D) — no valid score computed.
# [DEBUG] Skipped char '1' (U+0031) — no valid score computed.
# [DEBUG] Skipped char '5' (U+0035) — no valid score computed.
# [DEBUG] Skipped char '6' (U+0036) — no valid score computed.
# [DEBUG] Skipped char '7' (U+0037) — no valid score computed.
# [DEBUG] Skipped char '8' (U+0038) — no valid score computed.
# [DEBUG] Skipped char '9' (U+0039) — no valid score computed.
# [DEBUG] Skipped char ':' (U+003A) — no valid score computed.
# [DEBUG] Skipped char ';' (U+003B) — no valid score computed.
# [DEBUG] Skipped char '~' (U+007E) — no valid score computed.
# [DEBUG] Skipped char '¢' (U+00A2) — no valid score computed.
# [DEBUG] Skipped char '£' (U+00A3) — no valid score computed.
# [DEBUG] Skipped char '¥' (U+00A5) — no valid score computed.
# [DEBUG] Skipped char '§' (U+00A7) — no valid score computed.
# [DEBUG] Skipped char '¬' (U+00AC) — no valid score computed.
# [DEBUG] Skipped char '­' (U+00AD) — no valid score computed.
# [DEBUG] Skipped char '·' (U+00B7) — no valid score computed.
# [DEBUG] Skipped char '÷' (U+00F7) — no valid score computed.
# [DEBUG] Skipped char '͠' (U+0360) — no valid score computed.
# [DEBUG] Skipped char '߁' (U+07C1) — no valid score computed.
# [DEBUG] Skipped char '߅' (U+07C5) — no valid score computed.
# [DEBUG] Skipped char '߆' (U+07C6) — no valid score computed.
# [DEBUG] Skipped char '߇' (U+07C7) — no valid score computed.
# [DEBUG] Skipped char '߈' (U+07C8) — no valid score computed.
# [DEBUG] Skipped char '߉' (U+07C9) — no valid score computed.
# [DEBUG] Skipped char '߮' (U+07EE) — no valid score computed.
# [DEBUG] Skipped char '߯' (U+07EF) — no valid score computed.
# [DEBUG] Skipped char '߶' (U+07F6) — no valid score computed.
# [DEBUG] Skipped char '౧' (U+0C67) — no valid score computed.
# [DEBUG] Skipped char '౫' (U+0C6B) — no valid score computed.
# [DEBUG] Skipped char '౬' (U+0C6C) — no valid score computed.
# [DEBUG] Skipped char '౭' (U+0C6D) — no valid score computed.
# [DEBUG] Skipped char '౮' (U+0C6E) — no valid score computed.
# [DEBUG] Skipped char '౯' (U+0C6F) — no valid score computed.
# [DEBUG] Skipped char '౿' (U+0C7F) — no valid score computed.
# [DEBUG] Skipped char '።' (U+1362) — no valid score computed.
# [DEBUG] Skipped char '፤' (U+1364) — no valid score computed.
# [DEBUG] Skipped char '፥' (U+1365) — no valid score computed.
# [DEBUG] Skipped char '፩' (U+1369) — no valid score computed.
# [DEBUG] Skipped char '፭' (U+136D) — no valid score computed.
# [DEBUG] Skipped char '፮' (U+136E) — no valid score computed.
# [DEBUG] Skipped char '፯' (U+136F) — no valid score computed.
# [DEBUG] Skipped char '፰' (U+1370) — no valid score computed.
# [DEBUG] Skipped char '፱' (U+1371) — no valid score computed.
# [DEBUG] Skipped char '᥀' (U+1940) — no valid score computed.
# [DEBUG] Skipped char '᥇' (U+1947) — no valid score computed.
# [DEBUG] Skipped char '᥋' (U+194B) — no valid score computed.
# [DEBUG] Skipped char '᥌' (U+194C) — no valid score computed.
# [DEBUG] Skipped char '᥍' (U+194D) — no valid score computed.
# [DEBUG] Skipped char '᥎' (U+194E) — no valid score computed.
# [DEBUG] Skipped char '᥏' (U+194F) — no valid score computed.
# [DEBUG] Skipped char '᨟' (U+1A1F) — no valid score computed.
# [DEBUG] Skipped char '᪲' (U+1AB2) — no valid score computed.
# [DEBUG] Skipped char '᱑' (U+1C51) — no valid score computed.
# [DEBUG] Skipped char '᱕' (U+1C55) — no valid score computed.
# [DEBUG] Skipped char '᱖' (U+1C56) — no valid score computed.
# [DEBUG] Skipped char '᱗' (U+1C57) — no valid score computed.
# [DEBUG] Skipped char '᱘' (U+1C58) — no valid score computed.
# [DEBUG] Skipped char '᱙' (U+1C59) — no valid score computed.
# [DEBUG] Skipped char '‐' (U+2010) — no valid score computed.
# [DEBUG] Skipped char '•' (U+2022) — no valid score computed.
# [DEBUG] Skipped char '⁃' (U+2043) — no valid score computed.
# [DEBUG] Skipped char '⁐' (U+2050) — no valid score computed.
# [DEBUG] Skipped char '⁢' (U+2062) — no valid score computed.
# [DEBUG] Skipped char '⁤' (U+2064) — no valid score computed.
# [DEBUG] Skipped char '₡' (U+20A1) — no valid score computed.
# [DEBUG] Skipped char '₥' (U+20A5) — no valid score computed.
# [DEBUG] Skipped char '₫' (U+20AB) — no valid score computed.
# [DEBUG] Skipped char '₭' (U+20AD) — no valid score computed.
# [DEBUG] Skipped char '₱' (U+20B1) — no valid score computed.
# [DEBUG] Skipped char '₵' (U+20B5) — no valid score computed.
# [DEBUG] Skipped char '₷' (U+20B7) — no valid score computed.
# [DEBUG] Skipped char '₸' (U+20B8) — no valid score computed.
# [DEBUG] Skipped char '₿' (U+20BF) — no valid score computed.
# [DEBUG] Skipped char '⃀' (U+20C0) — no valid score computed.
# [DEBUG] Skipped char '℡' (U+2121) — no valid score computed.
# [DEBUG] Skipped char '℥' (U+2125) — no valid score computed.
# [DEBUG] Skipped char 'Ω' (U+2126) — no valid score computed.
# [DEBUG] Skipped char '∁' (U+2201) — no valid score computed.
# [DEBUG] Skipped char '∅' (U+2205) — no valid score computed.
# [DEBUG] Skipped char '∈' (U+2208) — no valid score computed.
# [DEBUG] Skipped char '−' (U+2212) — no valid score computed.
# [DEBUG] Skipped char '∔' (U+2214) — no valid score computed.
# [DEBUG] Skipped char '∖' (U+2216) — no valid score computed.
# [DEBUG] Skipped char '∞' (U+221E) — no valid score computed.
# [DEBUG] Skipped char '∣' (U+2223) — no valid score computed.
# [DEBUG] Skipped char '∤' (U+2224) — no valid score computed.
# [DEBUG] Skipped char '∪' (U+222A) — no valid score computed.
# [DEBUG] Skipped char '∸' (U+2238) — no valid score computed.
# [DEBUG] Skipped char '∹' (U+2239) — no valid score computed.
# [DEBUG] Skipped char '∻' (U+223B) — no valid score computed.
# [DEBUG] Skipped char '≁' (U+2241) — no valid score computed.
# [DEBUG] Skipped char '≂' (U+2242) — no valid score computed.
# [DEBUG] Skipped char '≻' (U+227B) — no valid score computed.
# [DEBUG] Skipped char '⊁' (U+2281) — no valid score computed.
# [DEBUG] Skipped char '⊂' (U+2282) — no valid score computed.
# [DEBUG] Skipped char '⊌' (U+228C) — no valid score computed.
# [DEBUG] Skipped char '⊎' (U+228E) — no valid score computed.
# [DEBUG] Skipped char '⊧' (U+22A7) — no valid score computed.
# [DEBUG] Skipped char '⋇' (U+22C7) — no valid score computed.
# [DEBUG] Skipped char '⋐' (U+22D0) — no valid score computed.
# [DEBUG] Skipped char '⋓' (U+22D3) — no valid score computed.
# [DEBUG] Skipped char '⌂' (U+2302) — no valid score computed.
# [DEBUG] Skipped char '⌈' (U+2308) — no valid score computed.
# [DEBUG] Skipped char '⌓' (U+2313) — no valid score computed.
# [DEBUG] Skipped char '⌣' (U+2323) — no valid score computed.
# [DEBUG] Skipped char '⌥' (U+2325) — no valid score computed.
# [DEBUG] Skipped char '⌳' (U+2333) — no valid score computed.
# [DEBUG] Skipped char '⍾' (U+237E) — no valid score computed.
# [DEBUG] Skipped char '⎄' (U+2384) — no valid score computed.
# [DEBUG] Skipped char '⎈' (U+2388) — no valid score computed.
# [DEBUG] Skipped char '⎌' (U+238C) — no valid score computed.
# [DEBUG] Skipped char '⏏' (U+23CF) — no valid score computed.
# [DEBUG] Skipped char '⏛' (U+23DB) — no valid score computed.
# [DEBUG] Skipped char '␣' (U+2423) — no valid score computed.
# [DEBUG] Skipped char '█' (U+2588) — no valid score computed.
# [DEBUG] Skipped char '▉' (U+2589) — no valid score computed.
# [DEBUG] Skipped char '▋' (U+258B) — no valid score computed.
# [DEBUG] Skipped char '▏' (U+258F) — no valid score computed.
# [DEBUG] Skipped char '◉' (U+25C9) — no valid score computed.
# [DEBUG] Skipped char '◊' (U+25CA) — no valid score computed.
# [DEBUG] Skipped char '◎' (U+25CE) — no valid score computed.
# [DEBUG] Skipped char '☁' (U+2601) — no valid score computed.
# [DEBUG] Skipped char '☄' (U+2604) — no valid score computed.
# [DEBUG] Skipped char '☇' (U+2607) — no valid score computed.
# [DEBUG] Skipped char '☉' (U+2609) — no valid score computed.
# [DEBUG] Skipped char '☋' (U+260B) — no valid score computed.
# [DEBUG] Skipped char '☌' (U+260C) — no valid score computed.
# [DEBUG] Skipped char '☍' (U+260D) — no valid score computed.
# [DEBUG] Skipped char '♆' (U+2646) — no valid score computed.
# [DEBUG] Skipped char '♇' (U+2647) — no valid score computed.
# [DEBUG] Skipped char '♊' (U+264A) — no valid score computed.
# [DEBUG] Skipped char '♌' (U+264C) — no valid score computed.
# [DEBUG] Skipped char '♓' (U+2653) — no valid score computed.
# [DEBUG] Skipped char '♪' (U+266A) — no valid score computed.
# [DEBUG] Skipped char '⚰' (U+26B0) — no valid score computed.
# [DEBUG] Skipped char '⚵' (U+26B5) — no valid score computed.
# [DEBUG] Skipped char '⚹' (U+26B9) — no valid score computed.
# [DEBUG] Skipped char '⚺' (U+26BA) — no valid score computed.
# [DEBUG] Skipped char '⚻' (U+26BB) — no valid score computed.
# [DEBUG] Skipped char '⛅' (U+26C5) — no valid score computed.
# [DEBUG] Skipped char '⛎' (U+26CE) — no valid score computed.
# [DEBUG] Skipped char '⛏' (U+26CF) — no valid score computed.
# [DEBUG] Skipped char '⛺' (U+26FA) — no valid score computed.
# [DEBUG] Skipped char '⛽' (U+26FD) — no valid score computed.
# [DEBUG] Skipped char '✉' (U+2709) — no valid score computed.
# [DEBUG] Skipped char '✏' (U+270F) — no valid score computed.
# [DEBUG] Skipped char '⟃' (U+27C3) — no valid score computed.
# [DEBUG] Skipped char '⟌' (U+27CC) — no valid score computed.
# [DEBUG] Skipped char '⦙' (U+2999) — no valid score computed.
# [DEBUG] Skipped char '⧜' (U+29DC) — no valid score computed.
# [DEBUG] Skipped char '⧸' (U+29F8) — no valid score computed.
# [DEBUG] Skipped char '⧺' (U+29FA) — no valid score computed.
# [DEBUG] Skipped char '⧾' (U+29FE) — no valid score computed.
# [DEBUG] Skipped char '⧿' (U+29FF) — no valid score computed.
# [DEBUG] Skipped char '⨝' (U+2A1D) — no valid score computed.
# [DEBUG] Skipped char '⪼' (U+2ABC) — no valid score computed.
# [DEBUG] Skipped char '⫏' (U+2ACF) — no valid score computed.
# [DEBUG] Skipped char '⯛' (U+2BDB) — no valid score computed.
# [DEBUG] Skipped char '⯜' (U+2BDC) — no valid score computed.
# [DEBUG] Skipped char '⯠' (U+2BE0) — no valid score computed.
# [DEBUG] Skipped char '⯢' (U+2BE2) — no valid score computed.
# [DEBUG] Skipped char '⯧' (U+2BE7) — no valid score computed.
# [DEBUG] Skipped char '⯺' (U+2BFA) — no valid score computed.
# [DEBUG] Skipped char '⯼' (U+2BFC) — no valid score computed.
# [DEBUG] Skipped char '⳾' (U+2CFE) — no valid score computed.
# [DEBUG] Skipped char '⸓' (U+2E13) — no valid score computed.
# [DEBUG] Skipped char '⸗' (U+2E17) — no valid score computed.
# [DEBUG] Skipped char '⹀' (U+2E40) — no valid score computed.
# [DEBUG] Skipped char '⹊' (U+2E4A) — no valid score computed.
# [DEBUG] Skipped char '⹝' (U+2E5D) — no valid score computed.
# [DEBUG] Skipped char '𑈾' (U+1123E) — no valid score computed.
# [DEBUG] Skipped char '𑙑' (U+11651) — no valid score computed.
# [DEBUG] Skipped char '𑙕' (U+11655) — no valid score computed.
# [DEBUG] Skipped char '𑙖' (U+11656) — no valid score computed.
# [DEBUG] Skipped char '𑙗' (U+11657) — no valid score computed.
# [DEBUG] Skipped char '𑙘' (U+11658) — no valid score computed.
# [DEBUG] Skipped char '𑙙' (U+11659) — no valid score computed.
# [DEBUG] Skipped char '🄯' (U+1F12F) — no valid score computed.
# [DEBUG] Skipped char '🌀' (U+1F300) — no valid score computed.
# [DEBUG] Skipped char '🌁' (U+1F301) — no valid score computed.
# [DEBUG] Skipped char '🌕' (U+1F315) — no valid score computed.
# [DEBUG] Skipped char '🌫' (U+1F32B) — no valid score computed.
# [DEBUG] Skipped char '🌭' (U+1F32D) — no valid score computed.
# [DEBUG] Skipped char '🌰' (U+1F330) — no valid score computed.
# [DEBUG] Skipped char '🌱' (U+1F331) — no valid score computed.
# [DEBUG] Skipped char '🌷' (U+1F337) — no valid score computed.
# [DEBUG] Skipped char '🌺' (U+1F33A) — no valid score computed.
# [DEBUG] Skipped char '🌼' (U+1F33C) — no valid score computed.
# [DEBUG] Skipped char '🍈' (U+1F348) — no valid score computed.
# [DEBUG] Skipped char '🍋' (U+1F34B) — no valid score computed.
# [DEBUG] Skipped char '🍢' (U+1F362) — no valid score computed.
# [DEBUG] Skipped char '🍣' (U+1F363) — no valid score computed.
# [DEBUG] Skipped char '🍩' (U+1F369) — no valid score computed.
# [DEBUG] Skipped char '🍪' (U+1F36A) — no valid score computed.
# [DEBUG] Skipped char '🍭' (U+1F36D) — no valid score computed.
# [DEBUG] Skipped char '🍯' (U+1F36F) — no valid score computed.
# [DEBUG] Skipped char '🍱' (U+1F371) — no valid score computed.
# [DEBUG] Skipped char '🍲' (U+1F372) — no valid score computed.
# [DEBUG] Skipped char '🍳' (U+1F373) — no valid score computed.
# [DEBUG] Skipped char '🎫' (U+1F3AB) — no valid score computed.
# [DEBUG] Skipped char '🎻' (U+1F3BB) — no valid score computed.
# [DEBUG] Skipped char '🏘' (U+1F3D8) — no valid score computed.
# [DEBUG] Skipped char '🏠' (U+1F3E0) — no valid score computed.
# [DEBUG] Skipped char '🏢' (U+1F3E2) — no valid score computed.
# [DEBUG] Skipped char '🏨' (U+1F3E8) — no valid score computed.
# [DEBUG] Skipped char '🏩' (U+1F3E9) — no valid score computed.
# [DEBUG] Skipped char '🏫' (U+1F3EB) — no valid score computed.
# [DEBUG] Skipped char '🐁' (U+1F401) — no valid score computed.
# [DEBUG] Skipped char '🐂' (U+1F402) — no valid score computed.
# [DEBUG] Skipped char '🐑' (U+1F411) — no valid score computed.
# [DEBUG] Skipped char '🐒' (U+1F412) — no valid score computed.
# [DEBUG] Skipped char '🐔' (U+1F414) — no valid score computed.
# [DEBUG] Skipped char '🐕' (U+1F415) — no valid score computed.
# [DEBUG] Skipped char '🐖' (U+1F416) — no valid score computed.
# [DEBUG] Skipped char '🐙' (U+1F419) — no valid score computed.
# [DEBUG] Skipped char '🐛' (U+1F41B) — no valid score computed.
# [DEBUG] Skipped char '🐝' (U+1F41D) — no valid score computed.
# [DEBUG] Skipped char '🐟' (U+1F41F) — no valid score computed.
# [DEBUG] Skipped char '🐧' (U+1F427) — no valid score computed.
# [DEBUG] Skipped char '🐩' (U+1F429) — no valid score computed.
# [DEBUG] Skipped char '🐬' (U+1F42C) — no valid score computed.
# [DEBUG] Skipped char '🐽' (U+1F43D) — no valid score computed.
# [DEBUG] Skipped char '🐿' (U+1F43F) — no valid score computed.
# [DEBUG] Skipped char '👀' (U+1F440) — no valid score computed.
# [DEBUG] Skipped char '👁' (U+1F441) — no valid score computed.
# [DEBUG] Skipped char '👃' (U+1F443) — no valid score computed.
# [DEBUG] Skipped char '👄' (U+1F444) — no valid score computed.
# [DEBUG] Skipped char '👅' (U+1F445) — no valid score computed.
# [DEBUG] Skipped char '👍' (U+1F44D) — no valid score computed.
# [DEBUG] Skipped char '👔' (U+1F454) — no valid score computed.
# [DEBUG] Skipped char '👘' (U+1F458) — no valid score computed.
# [DEBUG] Skipped char '👙' (U+1F459) — no valid score computed.
# [DEBUG] Skipped char '👝' (U+1F45D) — no valid score computed.
# [DEBUG] Skipped char '👠' (U+1F460) — no valid score computed.
# [DEBUG] Skipped char '👤' (U+1F464) — no valid score computed.
# [DEBUG] Skipped char '👥' (U+1F465) — no valid score computed.
# [DEBUG] Skipped char '👦' (U+1F466) — no valid score computed.
# [DEBUG] Skipped char '👻' (U+1F47B) — no valid score computed.
# [DEBUG] Skipped char '👿' (U+1F47F) — no valid score computed.
# [DEBUG] Skipped char '💀' (U+1F480) — no valid score computed.
# [DEBUG] Skipped char '💄' (U+1F484) — no valid score computed.
# [DEBUG] Skipped char '💊' (U+1F48A) — no valid score computed.
# [DEBUG] Skipped char '💎' (U+1F48E) — no valid score computed.
# [DEBUG] Skipped char '💏' (U+1F48F) — no valid score computed.
# [DEBUG] Skipped char '💐' (U+1F490) — no valid score computed.
# [DEBUG] Skipped char '💣' (U+1F4A3) — no valid score computed.
# [DEBUG] Skipped char '💤' (U+1F4A4) — no valid score computed.
# [DEBUG] Skipped char '💥' (U+1F4A5) — no valid score computed.
# [DEBUG] Skipped char '💩' (U+1F4A9) — no valid score computed.
# [DEBUG] Skipped char '💪' (U+1F4AA) — no valid score computed.
# [DEBUG] Skipped char '💫' (U+1F4AB) — no valid score computed.
# [DEBUG] Skipped char '💽' (U+1F4BD) — no valid score computed.
# [DEBUG] Skipped char '💾' (U+1F4BE) — no valid score computed.
# [DEBUG] Skipped char '📀' (U+1F4C0) — no valid score computed.
# [DEBUG] Skipped char '📌' (U+1F4CC) — no valid score computed.
# [DEBUG] Skipped char '📓' (U+1F4D3) — no valid score computed.
# [DEBUG] Skipped char '📕' (U+1F4D5) — no valid score computed.
# [DEBUG] Skipped char '📖' (U+1F4D6) — no valid score computed.
# [DEBUG] Skipped char '📘' (U+1F4D8) — no valid score computed.
# [DEBUG] Skipped char '📚' (U+1F4DA) — no valid score computed.
# [DEBUG] Skipped char '📝' (U+1F4DD) — no valid score computed.
# [DEBUG] Skipped char '📨' (U+1F4E8) — no valid score computed.
# [DEBUG] Skipped char '📮' (U+1F4EE) — no valid score computed.
# [DEBUG] Skipped char '📱' (U+1F4F1) — no valid score computed.
# [DEBUG] Skipped char '📴' (U+1F4F4) — no valid score computed.
# [DEBUG] Skipped char '📵' (U+1F4F5) — no valid score computed.
# [DEBUG] Skipped char '📺' (U+1F4FA) — no valid score computed.
# [DEBUG] Skipped char '🔑' (U+1F511) — no valid score computed.
# [DEBUG] Skipped char '🔒' (U+1F512) — no valid score computed.
# [DEBUG] Skipped char '🔓' (U+1F513) — no valid score computed.
# [DEBUG] Skipped char '🔔' (U+1F514) — no valid score computed.
# [DEBUG] Skipped char '🔗' (U+1F517) — no valid score computed.
# [DEBUG] Skipped char '🔪' (U+1F52A) — no valid score computed.
# [DEBUG] Skipped char '🔫' (U+1F52B) — no valid score computed.
# [DEBUG] Skipped char '🔭' (U+1F52D) — no valid score computed.
# [DEBUG] Skipped char '🕉' (U+1F549) — no valid score computed.
# [DEBUG] Skipped char '🕌' (U+1F54C) — no valid score computed.
# [DEBUG] Skipped char '🕮' (U+1F56E) — no valid score computed.
# [DEBUG] Skipped char '🕳' (U+1F573) — no valid score computed.
# [DEBUG] Skipped char '🕹' (U+1F579) — no valid score computed.
# [DEBUG] Skipped char '🖀' (U+1F580) — no valid score computed.
# [DEBUG] Skipped char '🖅' (U+1F585) — no valid score computed.
# [DEBUG] Skipped char '🖬' (U+1F5AC) — no valid score computed.
# [DEBUG] Skipped char '🖯' (U+1F5AF) — no valid score computed.
# [DEBUG] Skipped char '🗅' (U+1F5C5) — no valid score computed.
# [DEBUG] Skipped char '🗈' (U+1F5C8) — no valid score computed.
# [DEBUG] Skipped char '🗋' (U+1F5CB) — no valid score computed.
# [DEBUG] Skipped char '🗎' (U+1F5CE) — no valid score computed.
# [DEBUG] Skipped char '🗕' (U+1F5D5) — no valid score computed.
# [DEBUG] Skipped char '🗝' (U+1F5DD) — no valid score computed.
# [DEBUG] Skipped char '🗢' (U+1F5E2) — no valid score computed.
# [DEBUG] Skipped char '🗨' (U+1F5E8) — no valid score computed.
# [DEBUG] Skipped char '🗬' (U+1F5EC) — no valid score computed.
# [DEBUG] Skipped char '🗰' (U+1F5F0) — no valid score computed.
# [DEBUG] Skipped char '🗱' (U+1F5F1) — no valid score computed.
# [DEBUG] Skipped char '🗲' (U+1F5F2) — no valid score computed.
# [DEBUG] Skipped char '🗻' (U+1F5FB) — no valid score computed.
# [DEBUG] Skipped char '🙈' (U+1F648) — no valid score computed.
# [DEBUG] Skipped char '🚌' (U+1F68C) — no valid score computed.
# [DEBUG] Skipped char '🚍' (U+1F68D) — no valid score computed.
# [DEBUG] Skipped char '🚏' (U+1F68F) — no valid score computed.
# [DEBUG] Skipped char '🚐' (U+1F690) — no valid score computed.
# [DEBUG] Skipped char '🚢' (U+1F6A2) — no valid score computed.
# [DEBUG] Skipped char '🚬' (U+1F6AC) — no valid score computed.
# [DEBUG] Skipped char '🚭' (U+1F6AD) — no valid score computed.
# [DEBUG] Skipped char '🚲' (U+1F6B2) — no valid score computed.
# [DEBUG] Skipped char '🚳' (U+1F6B3) — no valid score computed.
# [DEBUG] Skipped char '🚴' (U+1F6B4) — no valid score computed.
# [DEBUG] Skipped char '🚹' (U+1F6B9) — no valid score computed.
# [DEBUG] Skipped char '🚽' (U+1F6BD) — no valid score computed.
# [DEBUG] Skipped char '🛃' (U+1F6C3) — no valid score computed.
# [DEBUG] Skipped char '🛉' (U+1F6C9) — no valid score computed.
# [DEBUG] Skipped char '🛎' (U+1F6CE) — no valid score computed.
# [DEBUG] Skipped char '🛏' (U+1F6CF) — no valid score computed.
# [DEBUG] Skipped char '🛕' (U+1F6D5) — no valid score computed.
# [DEBUG] Skipped char '🛖' (U+1F6D6) — no valid score computed.
# [DEBUG] Skipped char '🛡' (U+1F6E1) — no valid score computed.
# [DEBUG] Skipped char '🛲' (U+1F6F2) — no valid score computed.
# [DEBUG] Skipped char '🛷' (U+1F6F7) — no valid score computed.
# [DEBUG] Skipped char '🝽' (U+1F77D) — no valid score computed.
# [DEBUG] Skipped char '🤳' (U+1F933) — no valid score computed.
# [DEBUG] Skipped char '🤹' (U+1F939) — no valid score computed.
# [DEBUG] Skipped char '🥄' (U+1F944) — no valid score computed.
# [DEBUG] Skipped char '🥊' (U+1F94A) — no valid score computed.
# [DEBUG] Skipped char '🥏' (U+1F94F) — no valid score computed.
# [DEBUG] Skipped char '🥚' (U+1F95A) — no valid score computed.
# [DEBUG] Skipped char '🥟' (U+1F95F) — no valid score computed.
# [DEBUG] Skipped char '🥢' (U+1F962) — no valid score computed.
# [DEBUG] Skipped char '🥥' (U+1F965) — no valid score computed.
# [DEBUG] Skipped char '🥧' (U+1F967) — no valid score computed.
# [DEBUG] Skipped char '🥽' (U+1F97D) — no valid score computed.
# [DEBUG] Skipped char '🥾' (U+1F97E) — no valid score computed.
# [DEBUG] Skipped char '🦆' (U+1F986) — no valid score computed.
# [DEBUG] Skipped char '🦑' (U+1F991) — no valid score computed.
# [DEBUG] Skipped char '🦔' (U+1F994) — no valid score computed.
# [DEBUG] Skipped char '🦟' (U+1F99F) — no valid score computed.
# [DEBUG] Skipped char '🦤' (U+1F9A4) — no valid score computed.
# [DEBUG] Skipped char '🦥' (U+1F9A5) — no valid score computed.
# [DEBUG] Skipped char '🦨' (U+1F9A8) — no valid score computed.
# [DEBUG] Skipped char '🦬' (U+1F9AC) — no valid score computed.
# [DEBUG] Skipped char '🦮' (U+1F9AE) — no valid score computed.
# [DEBUG] Skipped char '🦴' (U+1F9B4) — no valid score computed.
# [DEBUG] Skipped char '🦵' (U+1F9B5) — no valid score computed.
# [DEBUG] Skipped char '🦶' (U+1F9B6) — no valid score computed.
# [DEBUG] Skipped char '🦷' (U+1F9B7) — no valid score computed.
# [DEBUG] Skipped char '🧅' (U+1F9C5) — no valid score computed.
# [DEBUG] Skipped char '🧊' (U+1F9CA) — no valid score computed.
# [DEBUG] Skipped char '🧒' (U+1F9D2) — no valid score computed.
# [DEBUG] Skipped char '🧝' (U+1F9DD) — no valid score computed.
# [DEBUG] Skipped char '🧞' (U+1F9DE) — no valid score computed.
# [DEBUG] Skipped char '🧟' (U+1F9DF) — no valid score computed.
# [DEBUG] Skipped char '🧤' (U+1F9E4) — no valid score computed.
# [DEBUG] Skipped char '🧦' (U+1F9E6) — no valid score computed.
# [DEBUG] Skipped char '🧪' (U+1F9EA) — no valid score computed.
# [DEBUG] Skipped char '🧰' (U+1F9F0) — no valid score computed.
# [DEBUG] Skipped char '🧴' (U+1F9F4) — no valid score computed.
# [DEBUG] Skipped char '🧽' (U+1F9FD) — no valid score computed.
# [DEBUG] Skipped char '🩺' (U+1FA7A) — no valid score computed.
# [DEBUG] Skipped char '🪀' (U+1FA80) — no valid score computed.
# [DEBUG] Skipped char '🪁' (U+1FA81) — no valid score computed.
# [DEBUG] Skipped char '🪆' (U+1FA86) — no valid score computed.
# [DEBUG] Skipped char '🪈' (U+1FA88) — no valid score computed.
# [DEBUG] Skipped char '🪙' (U+1FA99) — no valid score computed.
# [DEBUG] Skipped char '🪝' (U+1FA9D) — no valid score computed.
# [DEBUG] Skipped char '🪢' (U+1FAA2) — no valid score computed.
# [DEBUG] Skipped char '🪣' (U+1FAA3) — no valid score computed.
# [DEBUG] Skipped char '🪰' (U+1FAB0) — no valid score computed.
# [DEBUG] Skipped char '🪲' (U+1FAB2) — no valid score computed.
# [DEBUG] Skipped char '🪷' (U+1FAB7) — no valid score computed.
# [DEBUG] Skipped char '🪹' (U+1FAB9) — no valid score computed.
# [DEBUG] Skipped char '🪼' (U+1FABC) — no valid score computed.
# [DEBUG] Skipped char '🪿' (U+1FABF) — no valid score computed.
# [DEBUG] Skipped char '🫁' (U+1FAC1) — no valid score computed.
# [DEBUG] Skipped char '🫂' (U+1FAC2) — no valid score computed.
# [DEBUG] Skipped char '🫎' (U+1FACE) — no valid score computed.
# [DEBUG] Skipped char '🫏' (U+1FACF) — no valid score computed.
# [DEBUG] Skipped char '🫒' (U+1FAD2) — no valid score computed.
# [DEBUG] Skipped char '🫕' (U+1FAD5) — no valid score computed.
# [DEBUG] Skipped char '🫦' (U+1FAE6) — no valid score computed.
# [DEBUG] Skipped char '🫧' (U+1FAE7) — no valid score computed.
# [DEBUG] Skipped char '🯱' (U+1FBF1) — no valid score computed.
# [DEBUG] Skipped char '🯵' (U+1FBF5) — no valid score computed.
# [DEBUG] Skipped char '🯶' (U+1FBF6) — no valid score computed.
# [DEBUG] Skipped char '🯷' (U+1FBF7) — no valid score computed.
# [DEBUG] Skipped char '🯸' (U+1FBF8) — no valid score computed.
# [DEBUG] Skipped char '🯹' (U+1FBF9) — no valid score computed.
# [INFO] Found 408 match(es) for query: 'arw'
# CODE       CHAR NAME                                          SCORE
# -------------------------------------------------------------------
# U+0026     &   AMPERSAND  (\u0026)                            0.333
# U+0027     '   APOSTROPHE  (\u0027)                           0.308
# U+002A     *   ASTERISK  (\u002a)                             0.364
# U+00A6     ¦   BROKEN BAR  (\u00a6)                           0.308
# U+00A8     ¨   DIAERESIS  (\u00a8)                            0.333
# U+00AF     ¯   MACRON  (\u00af)                               0.444
# U+01BF     ƿ   LATIN LETTER WYNN  (\u01bf)                    0.300
# U+02C7     ˇ   CARON  (\u02c7)                                0.500
# U+02DA     ˚   RING ABOVE  (\u02da)                           0.308
# U+05AB     ֫   HEBREW ACCENT OLE  (\u05ab)                    0.300
# U+0608     ؈   ARABIC RAY  (\u0608)                           0.308
# U+0640     ـ   ARABIC TATWEEL  (\u0640)                       0.353
# U+0648     و   ARABIC LETTER WAW  (\u0648)                    0.300
# U+0659     ٙ   ARABIC ZWARAKAY  (\u0659)                      0.333
# U+06E5     ۥ   ARABIC SMALL WAW  (\u06e5)                     0.316
# U+0EA7     ວ   LAO LETTER WO  (\u0ea7)                        0.375
# U+101D     ဝ   MYANMAR LETTER WA  (\u101d)                    0.300
# U+1042     ၂   MYANMAR DIGIT TWO  (\u1042)                    0.300
# U+172F     ᜯ   HANUNOO LETTER WA  (\u172f)                    0.300
# U+1760     ᝠ   TAGBANWA LETTER A  (\u1760)                    0.300
# U+1BCB     ᯋ   BATAK LETTER WA  (\u1bcb)                      0.333
# U+1C22     ᰢ   LEPCHA LETTER WA  (\u1c22)                     0.316
# U+200A         HAIR SPACE  (\u200a)                           0.308
# U+2020     †   DAGGER  (\u2020)                               0.444
# U+2025     ‥   TWO DOT LEADER  (\u2025)                       0.353
# U+2038     ‸   CARET  (\u2038)                                0.500
# U+2042     ⁂   ASTERISM  (\u2042)                             0.364
# U+204E     ⁎   LOW ASTERISK  (\u204e)                         0.400
# U+2053     ⁓   SWUNG DASH  (\u2053)                           0.308
# U+20A6     ₦   NAIRA SIGN  (\u20a6)                           0.308
# U+20BE     ₾   LARI SIGN  (\u20be)                            0.333
# U+2105     ℅   CARE OF  (\u2105)                              0.400
# U+2122     ™   TRADE MARK SIGN  (\u2122)                      0.333
# U+2161     Ⅱ   ROMAN NUMERAL TWO  (\u2161)                    0.300
# U+2190     ←   LEFTWARDS ARROW  (\u2190)                      0.462
# U+2191     ↑   UPWARDS ARROW  (\u2191)                        0.545
# U+2192     →   RIGHTWARDS ARROW  (\u2192)                     0.429
# U+2193     ↓   DOWNWARDS ARROW  (\u2193)                      0.462
# U+2194     ↔   LEFT RIGHT ARROW  (\u2194)                     0.316
# U+2195     ↕   UP DOWN ARROW  (\u2195)                        0.375
# U+2196     ↖   NORTH WEST ARROW  (\u2196)                     0.316
# U+2197     ↗   NORTH EAST ARROW  (\u2197)                     0.316
# U+2198     ↘   SOUTH EAST ARROW  (\u2198)                     0.316
# U+2199     ↙   SOUTH WEST ARROW  (\u2199)                     0.316
# U+219C     ↜   LEFTWARDS WAVE ARROW  (\u219c)                 0.333
# U+219D     ↝   RIGHTWARDS WAVE ARROW  (\u219d)                0.316
# U+21A5     ↥   UPWARDS ARROW FROM BAR  (\u21a5)               0.300
# U+21AF     ↯   DOWNWARDS ZIGZAG ARROW  (\u21af)               0.300
# U+21C8     ⇈   UPWARDS PAIRED ARROWS  (\u21c8)                0.316
# U+21D0     ⇐   LEFTWARDS DOUBLE ARROW  (\u21d0)               0.300
# U+21D1     ⇑   UPWARDS DOUBLE ARROW  (\u21d1)                 0.333
# U+21D3     ⇓   DOWNWARDS DOUBLE ARROW  (\u21d3)               0.300
# U+21DA     ⇚   LEFTWARDS TRIPLE ARROW  (\u21da)               0.300
# U+21E0     ⇠   LEFTWARDS DASHED ARROW  (\u21e0)               0.300
# U+21E1     ⇡   UPWARDS DASHED ARROW  (\u21e1)                 0.333
# U+21E3     ⇣   DOWNWARDS DASHED ARROW  (\u21e3)               0.300
# U+21E4     ⇤   LEFTWARDS ARROW TO BAR  (\u21e4)               0.300
# U+21E6     ⇦   LEFTWARDS WHITE ARROW  (\u21e6)                0.316
# U+21E7     ⇧   UPWARDS WHITE ARROW  (\u21e7)                  0.353
# U+21E8     ⇨   RIGHTWARDS WHITE ARROW  (\u21e8)               0.300
# U+21E9     ⇩   DOWNWARDS WHITE ARROW  (\u21e9)                0.316
# U+2200     ∀   FOR ALL  (\u2200)                              0.400
# U+2228     ∨   LOGICAL OR  (\u2228)                           0.308
# U+2293     ⊓   SQUARE CAP  (\u2293)                           0.308
# U+2294     ⊔   SQUARE CUP  (\u2294)                           0.308
# U+22A6     ⊦   ASSERTION  (\u22a6)                            0.333
# U+22BB     ⊻   XOR  (\u22bb)                                  0.333
# U+22BD     ⊽   NOR  (\u22bd)                                  0.333
# U+2301     ⌁   ELECTRIC ARROW  (\u2301)                       0.353
# U+2303     ⌃   UP ARROWHEAD  (\u2303)                         0.400
# U+2304     ⌄   DOWN ARROWHEAD  (\u2304)                       0.353
# U+2312     ⌒   ARC  (\u2312)                                  0.667
# U+2317     ⌗   VIEWDATA SQUARE  (\u2317)                      0.333
# U+2322     ⌢   FROWN  (\u2322)                                0.500
# U+2327     ⌧   X IN A RECTANGLE BOX  (\u2327)                 0.333
# U+2328     ⌨   KEYBOARD  (\u2328)                             0.364
# U+2329     〈   LEFT-POINTING ANGLE BRACKET  (\u2329)          0.333
# U+23E6     ⏦   AC CURRENT  (\u23e6)                           0.308
# U+2441     ⑁   OCR CHAIR  (\u2441)                            0.333
# U+2448     ⑈   OCR DASH  (\u2448)                             0.364
# U+2593     ▓   DARK SHADE  (\u2593)                           0.308
# U+25A1     □   WHITE SQUARE  (\u25a1)                         0.400
# U+2605     ★   BLACK STAR  (\u2605)                           0.308
# U+2606     ☆   WHITE STAR  (\u2606)                           0.462
# U+2613     ☓   SALTIRE  (\u2613)                              0.400
# U+2618     ☘   SHAMROCK  (\u2618)                             0.364
# U+2638     ☸   WHEEL OF DHARMA  (\u2638)                      0.333
# U+2641     ♁   EARTH  (\u2641)                                0.500
# U+2644     ♄   SATURN  (\u2644)                               0.444
# U+2648     ♈   ARIES  (\u2648)                                0.500
# U+2649     ♉   TAURUS  (\u2649)                               0.444
# U+264B     ♋   CANCER  (\u264b)                               0.444
# U+2651     ♑   CAPRICORN  (\u2651)                            0.333
# U+2652     ♒   AQUARIUS  (\u2652)                             0.364
# U+2661     ♡   WHITE HEART SUIT  (\u2661)                     0.316
# U+266E     ♮   MUSIC NATURAL SIGN  (\u266e)                   0.400
# U+266F     ♯   MUSIC SHARP SIGN  (\u266f)                     0.500
# U+2690     ⚐   WHITE FLAG  (\u2690)                           0.308
# U+2693     ⚓   ANCHOR  (\u2693)                               0.444
# U+2699     ⚙   GEAR  (\u2699)                                 0.571
# U+26E4     ⛤   PENTAGRAM  (\u26e4)                            0.333
# U+26ED     ⛭   GEAR WITHOUT HUB  (\u26ed)                     0.316
# U+26EE     ⛮   GEAR WITH HANDLES  (\u26ee)                    0.300
# U+26F9     ⛹   PERSON WITH BALL  (\u26f9)                     0.316
# U+2708     ✈   AIRPLANE  (\u2708)                             0.364
# U+2713     ✓   CHECK MARK  (\u2713)                           0.308
# U+2728     ✨   SPARKLES  (\u2728)                             0.364
# U+2747     ❇   SPARKLE  (\u2747)                              0.400
# U+274C     ❌   CROSS MARK  (\u274c)                           0.308
# U+2799     ➙   HEAVY RIGHTWARDS ARROW  (\u2799)               0.300
# U+27A1     ➡   BLACK RIGHTWARDS ARROW  (\u27a1)               0.300
# U+2B50     ⭐   WHITE MEDIUM STAR  (\u2b50)                    0.300
# U+2B52     ⭒   WHITE SMALL STAR  (\u2b52)                     0.316
# U+2BD2     ⯒   GROUP MARK  (\u2bd2)                           0.308
# U+2BD9     ⯙   ASTRAEA  (\u2bd9)                              0.400
# U+2E14     ⸔   DOWNWARDS ANCORA  (\u2e14)                     0.316
# U+2E15     ⸕   UPWARDS ANCORA  (\u2e15)                       0.353
# U+2E47     ⹇   LOW KAVYKA  (\u2e47)                           0.308
# U+3003     〃   DITTO MARK  (\u3003)                           0.308
# U+3013     〓   GETA MARK  (\u3013)                            0.333
# U+301C     〜   WAVE DASH  (\u301c)                            0.333
# U+3030     〰   WAVY DASH  (\u3030)                            0.333
# U+303C     〼   MASU MARK  (\u303c)                            0.333
# U+3158     ㅘ   HANGUL LETTER WA  (\u3158)                     0.316
# U+3159     ㅙ   HANGUL LETTER WAE  (\u3159)                    0.300
# U+315D     ㅝ   HANGUL LETTER WEO  (\u315d)                    0.300
# U+315E     ㅞ   HANGUL LETTER WE  (\u315e)                     0.316
# U+315F     ㅟ   HANGUL LETTER WI  (\u315f)                     0.316
# U+32CC     ㋌   SQUARE HG  (\u32cc)                            0.333
# U+32CD     ㋍   SQUARE ERG  (\u32cd)                           0.308
# U+32CE     ㋎   SQUARE EV  (\u32ce)                            0.333
# U+3306     ㌆   SQUARE UON  (\u3306)                           0.308
# U+3327     ㌧   SQUARE TON  (\u3327)                           0.308
# U+333F     ㌿   SQUARE HON  (\u333f)                           0.308
# U+3357     ㍗   SQUARE WATTO  (\u3357)                         0.400
# U+3371     ㍱   SQUARE HPA  (\u3371)                           0.308
# U+3372     ㍲   SQUARE DA  (\u3372)                            0.333
# U+3373     ㍳   SQUARE AU  (\u3373)                            0.333
# U+3374     ㍴   SQUARE BAR  (\u3374)                           0.308
# U+3375     ㍵   SQUARE OV  (\u3375)                            0.333
# U+3376     ㍶   SQUARE PC  (\u3376)                            0.333
# U+3377     ㍷   SQUARE DM  (\u3377)                            0.333
# U+337A     ㍺   SQUARE IU  (\u337a)                            0.333
# U+3381     ㎁   SQUARE NA  (\u3381)                            0.333
# U+3383     ㎃   SQUARE MA  (\u3383)                            0.333
# U+3384     ㎄   SQUARE KA  (\u3384)                            0.333
# U+3385     ㎅   SQUARE KB  (\u3385)                            0.333
# U+3386     ㎆   SQUARE MB  (\u3386)                            0.333
# U+3387     ㎇   SQUARE GB  (\u3387)                            0.333
# U+3388     ㎈   SQUARE CAL  (\u3388)                           0.308
# U+338A     ㎊   SQUARE PF  (\u338a)                            0.333
# U+338B     ㎋   SQUARE NF  (\u338b)                            0.333
# U+338E     ㎎   SQUARE MG  (\u338e)                            0.333
# U+338F     ㎏   SQUARE KG  (\u338f)                            0.333
# U+3390     ㎐   SQUARE HZ  (\u3390)                            0.333
# U+3391     ㎑   SQUARE KHZ  (\u3391)                           0.308
# U+3392     ㎒   SQUARE MHZ  (\u3392)                           0.308
# U+3393     ㎓   SQUARE GHZ  (\u3393)                           0.308
# U+3394     ㎔   SQUARE THZ  (\u3394)                           0.308
# U+3396     ㎖   SQUARE ML  (\u3396)                            0.333
# U+3397     ㎗   SQUARE DL  (\u3397)                            0.333
# U+3398     ㎘   SQUARE KL  (\u3398)                            0.333
# U+3399     ㎙   SQUARE FM  (\u3399)                            0.333
# U+339A     ㎚   SQUARE NM  (\u339a)                            0.333
# U+339C     ㎜   SQUARE MM  (\u339c)                            0.333
# U+339D     ㎝   SQUARE CM  (\u339d)                            0.333
# U+339E     ㎞   SQUARE KM  (\u339e)                            0.333
# U+33A9     ㎩   SQUARE PA  (\u33a9)                            0.333
# U+33AA     ㎪   SQUARE KPA  (\u33aa)                           0.308
# U+33AB     ㎫   SQUARE MPA  (\u33ab)                           0.308
# U+33AC     ㎬   SQUARE GPA  (\u33ac)                           0.308
# U+33AD     ㎭   SQUARE RAD  (\u33ad)                           0.308
# U+33B0     ㎰   SQUARE PS  (\u33b0)                            0.333
# U+33B1     ㎱   SQUARE NS  (\u33b1)                            0.333
# U+33B3     ㎳   SQUARE MS  (\u33b3)                            0.333
# U+33B4     ㎴   SQUARE PV  (\u33b4)                            0.333
# U+33B5     ㎵   SQUARE NV  (\u33b5)                            0.333
# U+33B7     ㎷   SQUARE MV  (\u33b7)                            0.333
# U+33B8     ㎸   SQUARE KV  (\u33b8)                            0.333
# U+33BA     ㎺   SQUARE PW  (\u33ba)                            0.333
# U+33BB     ㎻   SQUARE NW  (\u33bb)                            0.333
# U+33BC     ㎼   SQUARE MU W  (\u33bc)                          0.429
# U+33BD     ㎽   SQUARE MW  (\u33bd)                            0.333
# U+33BE     ㎾   SQUARE KW  (\u33be)                            0.333
# U+33C2     ㏂   SQUARE AM  (\u33c2)                            0.333
# U+33C3     ㏃   SQUARE BQ  (\u33c3)                            0.333
# U+33C4     ㏄   SQUARE CC  (\u33c4)                            0.333
# U+33C5     ㏅   SQUARE CD  (\u33c5)                            0.333
# U+33C7     ㏇   SQUARE CO  (\u33c7)                            0.333
# U+33C8     ㏈   SQUARE DB  (\u33c8)                            0.333
# U+33C9     ㏉   SQUARE GY  (\u33c9)                            0.333
# U+33CA     ㏊   SQUARE HA  (\u33ca)                            0.333
# U+33CB     ㏋   SQUARE HP  (\u33cb)                            0.333
# U+33CC     ㏌   SQUARE IN  (\u33cc)                            0.333
# U+33CD     ㏍   SQUARE KK  (\u33cd)                            0.333
# U+33CF     ㏏   SQUARE KT  (\u33cf)                            0.333
# U+33D0     ㏐   SQUARE LM  (\u33d0)                            0.333
# U+33D1     ㏑   SQUARE LN  (\u33d1)                            0.333
# U+33D2     ㏒   SQUARE LOG  (\u33d2)                           0.308
# U+33D3     ㏓   SQUARE LX  (\u33d3)                            0.333
# U+33D5     ㏕   SQUARE MIL  (\u33d5)                           0.308
# U+33D6     ㏖   SQUARE MOL  (\u33d6)                           0.308
# U+33D7     ㏗   SQUARE PH  (\u33d7)                            0.333
# U+33D8     ㏘   SQUARE PM  (\u33d8)                            0.333
# U+33D9     ㏙   SQUARE PPM  (\u33d9)                           0.308
# U+33DA     ㏚   SQUARE PR  (\u33da)                            0.333
# U+33DB     ㏛   SQUARE SR  (\u33db)                            0.333
# U+33DC     ㏜   SQUARE SV  (\u33dc)                            0.333
# U+33DD     ㏝   SQUARE WB  (\u33dd)                            0.500
# U+33FF     ㏿   SQUARE GAL  (\u33ff)                           0.308
# U+A6C9     ꛉ   BAMUM LETTER WUE  (\ua6c9)                     0.316
# U+A6DA     ꛚ   BAMUM LETTER WA  (\ua6da)                      0.333
# U+10108    𐄈   AEGEAN NUMBER TWO  (\u10108)                   0.300
# U+108E5    𐣥   HATRAN LETTER WAW  (\u108e5)                   0.300
# U+108F5    𐣵   HATRAN LETTER TAW  (\u108f5)                   0.300
# U+11053    𑁓   BRAHMI NUMBER TWO  (\u11053)                   0.300
# U+11124    𑄤   CHAKMA LETTER WAA  (\u11124)                   0.300
# U+111C4    𑇄   SHARADA OM  (\u111c4)                          0.308
# U+111D2    𑇒   SHARADA DIGIT TWO  (\u111d2)                   0.300
# U+11400    𑐀   NEWA LETTER A  (\u11400)                       0.375
# U+11401    𑐁   NEWA LETTER AA  (\u11401)                      0.353
# U+1140B    𑐋   NEWA LETTER AI  (\u1140b)                      0.353
# U+1140D    𑐍   NEWA LETTER AU  (\u1140d)                      0.353
# U+1140E    𑐎   NEWA LETTER KA  (\u1140e)                      0.353
# U+1140F    𑐏   NEWA LETTER KHA  (\u1140f)                     0.333
# U+11410    𑐐   NEWA LETTER GA  (\u11410)                      0.353
# U+11411    𑐑   NEWA LETTER GHA  (\u11411)                     0.333
# U+11414    𑐔   NEWA LETTER CA  (\u11414)                      0.353
# U+11415    𑐕   NEWA LETTER CHA  (\u11415)                     0.333
# U+11416    𑐖   NEWA LETTER JA  (\u11416)                      0.353
# U+11417    𑐗   NEWA LETTER JHA  (\u11417)                     0.333
# U+1141C    𑐜   NEWA LETTER DDA  (\u1141c)                     0.333
# U+1141D    𑐝   NEWA LETTER DDHA  (\u1141d)                    0.316
# U+11421    𑐡   NEWA LETTER DA  (\u11421)                      0.353
# U+11422    𑐢   NEWA LETTER DHA  (\u11422)                     0.333
# U+11427    𑐧   NEWA LETTER BA  (\u11427)                      0.353
# U+11428    𑐨   NEWA LETTER BHA  (\u11428)                     0.333
# U+1142E    𑐮   NEWA LETTER LA  (\u1142e)                      0.353
# U+11434    𑐴   NEWA LETTER HA  (\u11434)                      0.353
# U+1144B    𑑋   NEWA DANDA  (\u1144b)                          0.308
# U+1144D    𑑍   NEWA COMMA  (\u1144d)                          0.308
# U+1145E    𑑞   NEWA SANDHI MARK  (\u1145e)                    0.316
# U+116C2    𑛂   TAKRI DIGIT TWO  (\u116c2)                     0.333
# U+11C85    𑲅   MARCHEN LETTER WA  (\u11c85)                   0.300
# U+11F2E    𑼮   KAWI LETTER WA  (\u11f2e)                      0.353
# U+11F43    𑽃   KAWI DANDA  (\u11f43)                          0.308
# U+16A6E    𖩮   MRO DANDA  (\u16a6e)                           0.333
# U+1BC38    𛰸   DUPLOYAN LETTER W  (\u1bc38)                   0.300
# U+1D2E2    𝋢   MAYAN NUMERAL TWO  (\u1d2e2)                   0.300
# U+1DA30    𝨰   SIGNWRITING EARS  (\u1da30)                    0.316
# U+1DA6B    𝩫   SIGNWRITING HAIR  (\u1da6b)                    0.316
# U+1E2C0    𞋀   WANCHO LETTER AA  (\u1e2c0)                    0.316
# U+1E2C1    𞋁   WANCHO LETTER A  (\u1e2c1)                     0.333
# U+1E2C2    𞋂   WANCHO LETTER BA  (\u1e2c2)                    0.316
# U+1E2C3    𞋃   WANCHO LETTER CA  (\u1e2c3)                    0.316
# U+1E2C4    𞋄   WANCHO LETTER DA  (\u1e2c4)                    0.316
# U+1E2C5    𞋅   WANCHO LETTER GA  (\u1e2c5)                    0.316
# U+1E2C8    𞋈   WANCHO LETTER LA  (\u1e2c8)                    0.316
# U+1E2CD    𞋍   WANCHO LETTER FA  (\u1e2cd)                    0.316
# U+1E2D0    𞋐   WANCHO LETTER JA  (\u1e2d0)                    0.316
# U+1E2D4    𞋔   WANCHO LETTER KA  (\u1e2d4)                    0.316
# U+1E2D6    𞋖   WANCHO LETTER AU  (\u1e2d6)                    0.316
# U+1E2D9    𞋙   WANCHO LETTER KHA  (\u1e2d9)                   0.300
# U+1E2DA    𞋚   WANCHO LETTER HA  (\u1e2da)                    0.316
# U+1E2E4    𞋤   WANCHO LETTER ANG  (\u1e2e4)                   0.300
# U+1E2E8    𞋨   WANCHO LETTER AAN  (\u1e2e8)                   0.300
# U+1F12E    🄮   CIRCLED WZ  (\u1f12e)                          0.308
# U+1F14A    🅊   SQUARED HV  (\u1f14a)                          0.308
# U+1F14B    🅋   SQUARED MV  (\u1f14b)                          0.308
# U+1F14C    🅌   SQUARED SD  (\u1f14c)                          0.308
# U+1F14D    🅍   SQUARED SS  (\u1f14d)                          0.308
# U+1F14F    🅏   SQUARED WC  (\u1f14f)                          0.462
# U+1F190    🆐   SQUARE DJ  (\u1f190)                           0.333
# U+1F191    🆑   SQUARED CL  (\u1f191)                          0.308
# U+1F194    🆔   SQUARED ID  (\u1f194)                          0.308
# U+1F196    🆖   SQUARED NG  (\u1f196)                          0.308
# U+1F197    🆗   SQUARED OK  (\u1f197)                          0.308
# U+1F19A    🆚   SQUARED VS  (\u1f19a)                          0.308
# U+1F19D    🆝   SQUARED TWO K  (\u1f19d)                       0.375
# U+1F1A6    🆦   SQUARED HC  (\u1f1a6)                          0.308
# U+1F303    🌃   NIGHT WITH STARS  (\u1f303)                    0.316
# U+1F308    🌈   RAINBOW  (\u1f308)                             0.400
# U+1F30A    🌊   WATER WAVE  (\u1f30a)                          0.462
# U+1F334    🌴   PALM TREE  (\u1f334)                           0.333
# U+1F346    🍆   AUBERGINE  (\u1f346)                           0.333
# U+1F349    🍉   WATERMELON  (\u1f349)                          0.308
# U+1F34A    🍊   TANGERINE  (\u1f34a)                           0.333
# U+1F34E    🍎   RED APPLE  (\u1f34e)                           0.333
# U+1F350    🍐   PEAR  (\u1f350)                                0.571
# U+1F353    🍓   STRAWBERRY  (\u1f353)                          0.308
# U+1F354    🍔   HAMBURGER  (\u1f354)                           0.333
# U+1F359    🍙   RICE BALL  (\u1f359)                           0.333
# U+1F36E    🍮   CUSTARD  (\u1f36e)                             0.400
# U+1F377    🍷   WINE GLASS  (\u1f377)                          0.308
# U+1F386    🎆   FIREWORKS  (\u1f386)                           0.333
# U+1F3B1    🎱   BILLIARDS  (\u1f3b1)                           0.333
# U+1F3B8    🎸   GUITAR  (\u1f3b8)                              0.444
# U+1F3CE    🏎   RACING CAR  (\u1f3ce)                          0.308
# U+1F3E1    🏡   HOUSE WITH GARDEN  (\u1f3e1)                   0.300
# U+1F3ED    🏭   FACTORY  (\u1f3ed)                             0.400
# U+1F3F9    🏹   BOW AND ARROW  (\u1f3f9)                       0.375
# U+1F3FA    🏺   AMPHORA  (\u1f3fa)                             0.400
# U+1F400    🐀   RAT  (\u1f400)                                 0.333
# U+1F404    🐄   COW  (\u1f404)                                 0.333
# U+1F406    🐆   LEOPARD  (\u1f406)                             0.400
# U+1F408    🐈   CAT  (\u1f408)                                 0.333
# U+1F40F    🐏   RAM  (\u1f40f)                                 0.333
# U+1F417    🐗   BOAR  (\u1f417)                                0.571
# U+1F41C    🐜   ANT  (\u1f41c)                                 0.333
# U+1F42F    🐯   TIGER FACE  (\u1f42f)                          0.308
# U+1F434    🐴   HORSE FACE  (\u1f434)                          0.308
# U+1F438    🐸   FROG FACE  (\u1f438)                           0.333
# U+1F43A    🐺   WOLF FACE  (\u1f43a)                           0.333
# U+1F43B    🐻   BEAR FACE  (\u1f43b)                           0.333
# U+1F43E    🐾   PAW PRINTS  (\u1f43e)                          0.308
# U+1F442    👂   EAR  (\u1f442)                                 0.667
# U+1F451    👑   CROWN  (\u1f451)                               0.500
# U+1F452    👒   WOMANS HAT  (\u1f452)                          0.308
# U+1F468    👨   MAN  (\u1f468)                                 0.333
# U+1F473    👳   MAN WITH TURBAN  (\u1f473)                     0.333
# U+1F474    👴   OLDER MAN  (\u1f474)                           0.333
# U+1F482    💂   GUARDSMAN  (\u1f482)                           0.333
# U+1F483    💃   DANCER  (\u1f483)                              0.444
# U+1F487    💇   HAIRCUT  (\u1f487)                             0.400
# U+1F48B    💋   KISS MARK  (\u1f48b)                           0.333
# U+1F491    💑   COUPLE WITH HEART  (\u1f491)                   0.300
# U+1F495    💕   TWO HEARTS  (\u1f495)                          0.462
# U+1F498    💘   HEART WITH ARROW  (\u1f498)                    0.316
# U+1F499    💙   BLUE HEART  (\u1f499)                          0.308
# U+1F49B    💛   YELLOW HEART  (\u1f49b)                        0.400
# U+1F49D    💝   HEART WITH RIBBON  (\u1f49d)                   0.300
# U+1F4C5    📅   CALENDAR  (\u1f4c5)                            0.364
# U+1F4C7    📇   CARD INDEX  (\u1f4c7)                          0.308
# U+1F4CA    📊   BAR CHART  (\u1f4ca)                           0.333
# U+1F4CB    📋   CLIPBOARD  (\u1f4cb)                           0.333
# U+1F4CE    📎   PAPERCLIP  (\u1f4ce)                           0.333
# U+1F4DF    📟   PAGER  (\u1f4df)                               0.500
# U+1F4F0    📰   NEWSPAPER  (\u1f4f0)                           0.333
# U+1F4F6    📶   ANTENNA WITH BARS  (\u1f4f6)                   0.300
# U+1F4F7    📷   CAMERA  (\u1f4f7)                              0.444
# U+1F4F8    📸   CAMERA WITH FLASH  (\u1f4f8)                   0.300
# U+1F508    🔈   SPEAKER  (\u1f508)                             0.400
# U+1F50B    🔋   BATTERY  (\u1f50b)                             0.400
# U+1F516    🔖   BOOKMARK  (\u1f516)                            0.364
# U+1F528    🔨   HAMMER  (\u1f528)                              0.444
# U+1F578    🕸   SPIDER WEB  (\u1f578)                          0.308
# U+1F5AE    🖮   WIRED KEYBOARD  (\u1f5ae)                      0.353
# U+1F5B4    🖴   HARD DISK  (\u1f5b4)                           0.333
# U+1F5BE    🖾   FRAME WITH AN X  (\u1f5be)                     0.333
# U+1F5FA    🗺   WORLD MAP  (\u1f5fa)                           0.333
# U+1F620    😠   ANGRY FACE  (\u1f620)                          0.308
# U+1F629    😩   WEARY FACE  (\u1f629)                          0.308
# U+1F62B    😫   TIRED FACE  (\u1f62b)                          0.308
# U+1F683    🚃   RAILWAY CAR  (\u1f683)                         0.429
# U+1F68B    🚋   TRAM CAR  (\u1f68b)                            0.364
# U+1F693    🚓   POLICE CAR  (\u1f693)                          0.308
# U+1F69C    🚜   TRACTOR  (\u1f69c)                             0.400
# U+1F69E    🚞   MOUNTAIN RAILWAY  (\u1f69e)                    0.316
# U+1F6A1    🚡   AERIAL TRAMWAY  (\u1f6a1)                      0.353
# U+1F6A3    🚣   ROWBOAT  (\u1f6a3)                             0.400
# U+1F6D7    🛗   ELEVATOR  (\u1f6d7)                            0.364
# U+1F6E0    🛠   HAMMER AND WRENCH  (\u1f6e0)                   0.300
# U+1F6E3    🛣   MOTORWAY  (\u1f6e3)                            0.364
# U+1F6E5    🛥   MOTOR BOAT  (\u1f6e5)                          0.308
# U+1F6F9    🛹   SKATEBOARD  (\u1f6f9)                          0.308
# U+1F6FA    🛺   AUTO RICKSHAW  (\u1f6fa)                       0.375
# U+1F77E    🝾   QUAOAR  (\u1f77e)                              0.444
# U+1F790    🞐   BOLD WHITE SQUARE  (\u1f790)                   0.300
# U+1F90D    🤍   WHITE HEART  (\u1f90d)                         0.429
# U+1F913    🤓   NERD FACE  (\u1f913)                           0.333
# U+1F916    🤖   ROBOT FACE  (\u1f916)                          0.308
# U+1F93D    🤽   WATER POLO  (\u1f93d)                          0.308
# U+1F955    🥕   CARROT  (\u1f955)                              0.444
# U+1F96A    🥪   SANDWICH  (\u1f96a)                            0.364
# U+1F97B    🥻   SARI  (\u1f97b)                                0.571
# U+1F987    🦇   BAT  (\u1f987)                                 0.333
# U+1F988    🦈   SHARK  (\u1f988)                               0.500
# U+1F989    🦉   OWL  (\u1f989)                                 0.333
# U+1F98E    🦎   LIZARD  (\u1f98e)                              0.444
# U+1F993    🦓   ZEBRA FACE  (\u1f993)                          0.308
# U+1F995    🦕   SAUROPOD  (\u1f995)                            0.364
# U+1F998    🦘   KANGAROO  (\u1f998)                            0.364
# U+1F99C    🦜   PARROT  (\u1f99c)                              0.444
# U+1F9A1    🦡   BADGER  (\u1f9a1)                              0.444
# U+1F9AB    🦫   BEAVER  (\u1f9ab)                              0.444
# U+1F9C4    🧄   GARLIC  (\u1f9c4)                              0.444
# U+1F9DA    🧚   FAIRY  (\u1f9da)                               0.500
# U+1F9DB    🧛   VAMPIRE  (\u1f9db)                             0.400
# U+1F9E3    🧣   SCARF  (\u1f9e3)                               0.500
# U+1F9F8    🧸   TEDDY BEAR  (\u1f9f8)                          0.308
# U+1FA76    🩶   GREY HEART  (\u1fa76)                          0.308
# U+1FA77    🩷   PINK HEART  (\u1fa77)                          0.308
# U+1FA82    🪂   PARACHUTE  (\u1fa82)                           0.333
# U+1FA84    🪄   MAGIC WAND  (\u1fa84)                          0.308
# U+1FA87    🪇   MARACAS  (\u1fa87)                             0.400
# U+1FA91    🪑   CHAIR  (\u1fa91)                               0.500
# U+1FA92    🪒   RAZOR  (\u1fa92)                               0.500
# U+1FA93    🪓   AXE  (\u1fa93)                                 0.333
# U+1FA97    🪗   ACCORDION  (\u1fa97)                           0.333
# U+1FA9A    🪚   CARPENTRY SAW  (\u1fa9a)                       0.375
# U+1FA9C    🪜   LADDER  (\u1fa9c)                              0.444
# U+1FAA7    🪧   PLACARD  (\u1faa7)                             0.400
# U+1FAAB    🪫   LOW BATTERY  (\u1faab)                         0.429
# U+1FAAE    🪮   HAIR PICK  (\u1faae)                           0.333
# U+1FAB6    🪶   FEATHER  (\u1fab6)                             0.400
# U+1FAD3    🫓   FLATBREAD  (\u1fad3)                           0.333
# U+1FAD9    🫙   JAR  (\u1fad9)                                 0.667
# U+1FAF1    🫱   RIGHTWARDS HAND  (\u1faf1)                     0.333

# %% [markdown]
# #### Fuzzy Match, High Threshold

# %%
query = "arw"
results = list(find_chars(query, fuzzy=True, threshold=0.85))

print("\n".join(results))
# Out:
# [INFO] Loaded Unicode name cache from: "C:\Users\HamedVAHEB\Documents\Projects\Python\charfinder\data\cache\unicode_name_cache.json"
# [INFO] No exact match found for 'arw', trying fuzzy...
# [INFO] Fuzzy settings: threshold=0.85, agg_fn=mean
# [DEBUG] Skipped char '+' (U+002B) — no valid score computed.
# [DEBUG] Skipped char '-' (U+002D) — no valid score computed.
# [DEBUG] Skipped char '1' (U+0031) — no valid score computed.
# [DEBUG] Skipped char '5' (U+0035) — no valid score computed.
# [DEBUG] Skipped char '6' (U+0036) — no valid score computed.
# [DEBUG] Skipped char '7' (U+0037) — no valid score computed.
# [DEBUG] Skipped char '8' (U+0038) — no valid score computed.
# [DEBUG] Skipped char '9' (U+0039) — no valid score computed.
# [DEBUG] Skipped char ':' (U+003A) — no valid score computed.
# [DEBUG] Skipped char ';' (U+003B) — no valid score computed.
# [DEBUG] Skipped char '~' (U+007E) — no valid score computed.
# [DEBUG] Skipped char '¢' (U+00A2) — no valid score computed.
# [DEBUG] Skipped char '£' (U+00A3) — no valid score computed.
# [DEBUG] Skipped char '¥' (U+00A5) — no valid score computed.
# [DEBUG] Skipped char '§' (U+00A7) — no valid score computed.
# [DEBUG] Skipped char '¬' (U+00AC) — no valid score computed.
# [DEBUG] Skipped char '­' (U+00AD) — no valid score computed.
# [DEBUG] Skipped char '·' (U+00B7) — no valid score computed.
# [DEBUG] Skipped char '÷' (U+00F7) — no valid score computed.
# [DEBUG] Skipped char '͠' (U+0360) — no valid score computed.
# [DEBUG] Skipped char '߁' (U+07C1) — no valid score computed.
# [DEBUG] Skipped char '߅' (U+07C5) — no valid score computed.
# [DEBUG] Skipped char '߆' (U+07C6) — no valid score computed.
# [DEBUG] Skipped char '߇' (U+07C7) — no valid score computed.
# [DEBUG] Skipped char '߈' (U+07C8) — no valid score computed.
# [DEBUG] Skipped char '߉' (U+07C9) — no valid score computed.
# [DEBUG] Skipped char '߮' (U+07EE) — no valid score computed.
# [DEBUG] Skipped char '߯' (U+07EF) — no valid score computed.
# [DEBUG] Skipped char '߶' (U+07F6) — no valid score computed.
# [DEBUG] Skipped char '౧' (U+0C67) — no valid score computed.
# [DEBUG] Skipped char '౫' (U+0C6B) — no valid score computed.
# [DEBUG] Skipped char '౬' (U+0C6C) — no valid score computed.
# [DEBUG] Skipped char '౭' (U+0C6D) — no valid score computed.
# [DEBUG] Skipped char '౮' (U+0C6E) — no valid score computed.
# [DEBUG] Skipped char '౯' (U+0C6F) — no valid score computed.
# [DEBUG] Skipped char '౿' (U+0C7F) — no valid score computed.
# [DEBUG] Skipped char '።' (U+1362) — no valid score computed.
# [DEBUG] Skipped char '፤' (U+1364) — no valid score computed.
# [DEBUG] Skipped char '፥' (U+1365) — no valid score computed.
# [DEBUG] Skipped char '፩' (U+1369) — no valid score computed.
# [DEBUG] Skipped char '፭' (U+136D) — no valid score computed.
# [DEBUG] Skipped char '፮' (U+136E) — no valid score computed.
# [DEBUG] Skipped char '፯' (U+136F) — no valid score computed.
# [DEBUG] Skipped char '፰' (U+1370) — no valid score computed.
# [DEBUG] Skipped char '፱' (U+1371) — no valid score computed.
# [DEBUG] Skipped char '᥀' (U+1940) — no valid score computed.
# [DEBUG] Skipped char '᥇' (U+1947) — no valid score computed.
# [DEBUG] Skipped char '᥋' (U+194B) — no valid score computed.
# [DEBUG] Skipped char '᥌' (U+194C) — no valid score computed.
# [DEBUG] Skipped char '᥍' (U+194D) — no valid score computed.
# [DEBUG] Skipped char '᥎' (U+194E) — no valid score computed.
# [DEBUG] Skipped char '᥏' (U+194F) — no valid score computed.
# [DEBUG] Skipped char '᨟' (U+1A1F) — no valid score computed.
# [DEBUG] Skipped char '᪲' (U+1AB2) — no valid score computed.
# [DEBUG] Skipped char '᱑' (U+1C51) — no valid score computed.
# [DEBUG] Skipped char '᱕' (U+1C55) — no valid score computed.
# [DEBUG] Skipped char '᱖' (U+1C56) — no valid score computed.
# [DEBUG] Skipped char '᱗' (U+1C57) — no valid score computed.
# [DEBUG] Skipped char '᱘' (U+1C58) — no valid score computed.
# [DEBUG] Skipped char '᱙' (U+1C59) — no valid score computed.
# [DEBUG] Skipped char '‐' (U+2010) — no valid score computed.
# [DEBUG] Skipped char '•' (U+2022) — no valid score computed.
# [DEBUG] Skipped char '⁃' (U+2043) — no valid score computed.
# [DEBUG] Skipped char '⁐' (U+2050) — no valid score computed.
# [DEBUG] Skipped char '⁢' (U+2062) — no valid score computed.
# [DEBUG] Skipped char '⁤' (U+2064) — no valid score computed.
# [DEBUG] Skipped char '₡' (U+20A1) — no valid score computed.
# [DEBUG] Skipped char '₥' (U+20A5) — no valid score computed.
# [DEBUG] Skipped char '₫' (U+20AB) — no valid score computed.
# [DEBUG] Skipped char '₭' (U+20AD) — no valid score computed.
# [DEBUG] Skipped char '₱' (U+20B1) — no valid score computed.
# [DEBUG] Skipped char '₵' (U+20B5) — no valid score computed.
# [DEBUG] Skipped char '₷' (U+20B7) — no valid score computed.
# [DEBUG] Skipped char '₸' (U+20B8) — no valid score computed.
# [DEBUG] Skipped char '₿' (U+20BF) — no valid score computed.
# [DEBUG] Skipped char '⃀' (U+20C0) — no valid score computed.
# [DEBUG] Skipped char '℡' (U+2121) — no valid score computed.
# [DEBUG] Skipped char '℥' (U+2125) — no valid score computed.
# [DEBUG] Skipped char 'Ω' (U+2126) — no valid score computed.
# [DEBUG] Skipped char '∁' (U+2201) — no valid score computed.
# [DEBUG] Skipped char '∅' (U+2205) — no valid score computed.
# [DEBUG] Skipped char '∈' (U+2208) — no valid score computed.
# [DEBUG] Skipped char '−' (U+2212) — no valid score computed.
# [DEBUG] Skipped char '∔' (U+2214) — no valid score computed.
# [DEBUG] Skipped char '∖' (U+2216) — no valid score computed.
# [DEBUG] Skipped char '∞' (U+221E) — no valid score computed.
# [DEBUG] Skipped char '∣' (U+2223) — no valid score computed.
# [DEBUG] Skipped char '∤' (U+2224) — no valid score computed.
# [DEBUG] Skipped char '∪' (U+222A) — no valid score computed.
# [DEBUG] Skipped char '∸' (U+2238) — no valid score computed.
# [DEBUG] Skipped char '∹' (U+2239) — no valid score computed.
# [DEBUG] Skipped char '∻' (U+223B) — no valid score computed.
# [DEBUG] Skipped char '≁' (U+2241) — no valid score computed.
# [DEBUG] Skipped char '≂' (U+2242) — no valid score computed.
# [DEBUG] Skipped char '≻' (U+227B) — no valid score computed.
# [DEBUG] Skipped char '⊁' (U+2281) — no valid score computed.
# [DEBUG] Skipped char '⊂' (U+2282) — no valid score computed.
# [DEBUG] Skipped char '⊌' (U+228C) — no valid score computed.
# [DEBUG] Skipped char '⊎' (U+228E) — no valid score computed.
# [DEBUG] Skipped char '⊧' (U+22A7) — no valid score computed.
# [DEBUG] Skipped char '⋇' (U+22C7) — no valid score computed.
# [DEBUG] Skipped char '⋐' (U+22D0) — no valid score computed.
# [DEBUG] Skipped char '⋓' (U+22D3) — no valid score computed.
# [DEBUG] Skipped char '⌂' (U+2302) — no valid score computed.
# [DEBUG] Skipped char '⌈' (U+2308) — no valid score computed.
# [DEBUG] Skipped char '⌓' (U+2313) — no valid score computed.
# [DEBUG] Skipped char '⌣' (U+2323) — no valid score computed.
# [DEBUG] Skipped char '⌥' (U+2325) — no valid score computed.
# [DEBUG] Skipped char '⌳' (U+2333) — no valid score computed.
# [DEBUG] Skipped char '⍾' (U+237E) — no valid score computed.
# [DEBUG] Skipped char '⎄' (U+2384) — no valid score computed.
# [DEBUG] Skipped char '⎈' (U+2388) — no valid score computed.
# [DEBUG] Skipped char '⎌' (U+238C) — no valid score computed.
# [DEBUG] Skipped char '⏏' (U+23CF) — no valid score computed.
# [DEBUG] Skipped char '⏛' (U+23DB) — no valid score computed.
# [DEBUG] Skipped char '␣' (U+2423) — no valid score computed.
# [DEBUG] Skipped char '█' (U+2588) — no valid score computed.
# [DEBUG] Skipped char '▉' (U+2589) — no valid score computed.
# [DEBUG] Skipped char '▋' (U+258B) — no valid score computed.
# [DEBUG] Skipped char '▏' (U+258F) — no valid score computed.
# [DEBUG] Skipped char '◉' (U+25C9) — no valid score computed.
# [DEBUG] Skipped char '◊' (U+25CA) — no valid score computed.
# [DEBUG] Skipped char '◎' (U+25CE) — no valid score computed.
# [DEBUG] Skipped char '☁' (U+2601) — no valid score computed.
# [DEBUG] Skipped char '☄' (U+2604) — no valid score computed.
# [DEBUG] Skipped char '☇' (U+2607) — no valid score computed.
# [DEBUG] Skipped char '☉' (U+2609) — no valid score computed.
# [DEBUG] Skipped char '☋' (U+260B) — no valid score computed.
# [DEBUG] Skipped char '☌' (U+260C) — no valid score computed.
# [DEBUG] Skipped char '☍' (U+260D) — no valid score computed.
# [DEBUG] Skipped char '♆' (U+2646) — no valid score computed.
# [DEBUG] Skipped char '♇' (U+2647) — no valid score computed.
# [DEBUG] Skipped char '♊' (U+264A) — no valid score computed.
# [DEBUG] Skipped char '♌' (U+264C) — no valid score computed.
# [DEBUG] Skipped char '♓' (U+2653) — no valid score computed.
# [DEBUG] Skipped char '♪' (U+266A) — no valid score computed.
# [DEBUG] Skipped char '⚰' (U+26B0) — no valid score computed.
# [DEBUG] Skipped char '⚵' (U+26B5) — no valid score computed.
# [DEBUG] Skipped char '⚹' (U+26B9) — no valid score computed.
# [DEBUG] Skipped char '⚺' (U+26BA) — no valid score computed.
# [DEBUG] Skipped char '⚻' (U+26BB) — no valid score computed.
# [DEBUG] Skipped char '⛅' (U+26C5) — no valid score computed.
# [DEBUG] Skipped char '⛎' (U+26CE) — no valid score computed.
# [DEBUG] Skipped char '⛏' (U+26CF) — no valid score computed.
# [DEBUG] Skipped char '⛺' (U+26FA) — no valid score computed.
# [DEBUG] Skipped char '⛽' (U+26FD) — no valid score computed.
# [DEBUG] Skipped char '✉' (U+2709) — no valid score computed.
# [DEBUG] Skipped char '✏' (U+270F) — no valid score computed.
# [DEBUG] Skipped char '⟃' (U+27C3) — no valid score computed.
# [DEBUG] Skipped char '⟌' (U+27CC) — no valid score computed.
# [DEBUG] Skipped char '⦙' (U+2999) — no valid score computed.
# [DEBUG] Skipped char '⧜' (U+29DC) — no valid score computed.
# [DEBUG] Skipped char '⧸' (U+29F8) — no valid score computed.
# [DEBUG] Skipped char '⧺' (U+29FA) — no valid score computed.
# [DEBUG] Skipped char '⧾' (U+29FE) — no valid score computed.
# [DEBUG] Skipped char '⧿' (U+29FF) — no valid score computed.
# [DEBUG] Skipped char '⨝' (U+2A1D) — no valid score computed.
# [DEBUG] Skipped char '⪼' (U+2ABC) — no valid score computed.
# [DEBUG] Skipped char '⫏' (U+2ACF) — no valid score computed.
# [DEBUG] Skipped char '⯛' (U+2BDB) — no valid score computed.
# [DEBUG] Skipped char '⯜' (U+2BDC) — no valid score computed.
# [DEBUG] Skipped char '⯠' (U+2BE0) — no valid score computed.
# [DEBUG] Skipped char '⯢' (U+2BE2) — no valid score computed.
# [DEBUG] Skipped char '⯧' (U+2BE7) — no valid score computed.
# [DEBUG] Skipped char '⯺' (U+2BFA) — no valid score computed.
# [DEBUG] Skipped char '⯼' (U+2BFC) — no valid score computed.
# [DEBUG] Skipped char '⳾' (U+2CFE) — no valid score computed.
# [DEBUG] Skipped char '⸓' (U+2E13) — no valid score computed.
# [DEBUG] Skipped char '⸗' (U+2E17) — no valid score computed.
# [DEBUG] Skipped char '⹀' (U+2E40) — no valid score computed.
# [DEBUG] Skipped char '⹊' (U+2E4A) — no valid score computed.
# [DEBUG] Skipped char '⹝' (U+2E5D) — no valid score computed.
# [DEBUG] Skipped char '𑈾' (U+1123E) — no valid score computed.
# [DEBUG] Skipped char '𑙑' (U+11651) — no valid score computed.
# [DEBUG] Skipped char '𑙕' (U+11655) — no valid score computed.
# [DEBUG] Skipped char '𑙖' (U+11656) — no valid score computed.
# [DEBUG] Skipped char '𑙗' (U+11657) — no valid score computed.
# [DEBUG] Skipped char '𑙘' (U+11658) — no valid score computed.
# [DEBUG] Skipped char '𑙙' (U+11659) — no valid score computed.
# [DEBUG] Skipped char '🄯' (U+1F12F) — no valid score computed.
# [DEBUG] Skipped char '🌀' (U+1F300) — no valid score computed.
# [DEBUG] Skipped char '🌁' (U+1F301) — no valid score computed.
# [DEBUG] Skipped char '🌕' (U+1F315) — no valid score computed.
# [DEBUG] Skipped char '🌫' (U+1F32B) — no valid score computed.
# [DEBUG] Skipped char '🌭' (U+1F32D) — no valid score computed.
# [DEBUG] Skipped char '🌰' (U+1F330) — no valid score computed.
# [DEBUG] Skipped char '🌱' (U+1F331) — no valid score computed.
# [DEBUG] Skipped char '🌷' (U+1F337) — no valid score computed.
# [DEBUG] Skipped char '🌺' (U+1F33A) — no valid score computed.
# [DEBUG] Skipped char '🌼' (U+1F33C) — no valid score computed.
# [DEBUG] Skipped char '🍈' (U+1F348) — no valid score computed.
# [DEBUG] Skipped char '🍋' (U+1F34B) — no valid score computed.
# [DEBUG] Skipped char '🍢' (U+1F362) — no valid score computed.
# [DEBUG] Skipped char '🍣' (U+1F363) — no valid score computed.
# [DEBUG] Skipped char '🍩' (U+1F369) — no valid score computed.
# [DEBUG] Skipped char '🍪' (U+1F36A) — no valid score computed.
# [DEBUG] Skipped char '🍭' (U+1F36D) — no valid score computed.
# [DEBUG] Skipped char '🍯' (U+1F36F) — no valid score computed.
# [DEBUG] Skipped char '🍱' (U+1F371) — no valid score computed.
# [DEBUG] Skipped char '🍲' (U+1F372) — no valid score computed.
# [DEBUG] Skipped char '🍳' (U+1F373) — no valid score computed.
# [DEBUG] Skipped char '🎫' (U+1F3AB) — no valid score computed.
# [DEBUG] Skipped char '🎻' (U+1F3BB) — no valid score computed.
# [DEBUG] Skipped char '🏘' (U+1F3D8) — no valid score computed.
# [DEBUG] Skipped char '🏠' (U+1F3E0) — no valid score computed.
# [DEBUG] Skipped char '🏢' (U+1F3E2) — no valid score computed.
# [DEBUG] Skipped char '🏨' (U+1F3E8) — no valid score computed.
# [DEBUG] Skipped char '🏩' (U+1F3E9) — no valid score computed.
# [DEBUG] Skipped char '🏫' (U+1F3EB) — no valid score computed.
# [DEBUG] Skipped char '🐁' (U+1F401) — no valid score computed.
# [DEBUG] Skipped char '🐂' (U+1F402) — no valid score computed.
# [DEBUG] Skipped char '🐑' (U+1F411) — no valid score computed.
# [DEBUG] Skipped char '🐒' (U+1F412) — no valid score computed.
# [DEBUG] Skipped char '🐔' (U+1F414) — no valid score computed.
# [DEBUG] Skipped char '🐕' (U+1F415) — no valid score computed.
# [DEBUG] Skipped char '🐖' (U+1F416) — no valid score computed.
# [DEBUG] Skipped char '🐙' (U+1F419) — no valid score computed.
# [DEBUG] Skipped char '🐛' (U+1F41B) — no valid score computed.
# [DEBUG] Skipped char '🐝' (U+1F41D) — no valid score computed.
# [DEBUG] Skipped char '🐟' (U+1F41F) — no valid score computed.
# [DEBUG] Skipped char '🐧' (U+1F427) — no valid score computed.
# [DEBUG] Skipped char '🐩' (U+1F429) — no valid score computed.
# [DEBUG] Skipped char '🐬' (U+1F42C) — no valid score computed.
# [DEBUG] Skipped char '🐽' (U+1F43D) — no valid score computed.
# [DEBUG] Skipped char '🐿' (U+1F43F) — no valid score computed.
# [DEBUG] Skipped char '👀' (U+1F440) — no valid score computed.
# [DEBUG] Skipped char '👁' (U+1F441) — no valid score computed.
# [DEBUG] Skipped char '👃' (U+1F443) — no valid score computed.
# [DEBUG] Skipped char '👄' (U+1F444) — no valid score computed.
# [DEBUG] Skipped char '👅' (U+1F445) — no valid score computed.
# [DEBUG] Skipped char '👍' (U+1F44D) — no valid score computed.
# [DEBUG] Skipped char '👔' (U+1F454) — no valid score computed.
# [DEBUG] Skipped char '👘' (U+1F458) — no valid score computed.
# [DEBUG] Skipped char '👙' (U+1F459) — no valid score computed.
# [DEBUG] Skipped char '👝' (U+1F45D) — no valid score computed.
# [DEBUG] Skipped char '👠' (U+1F460) — no valid score computed.
# [DEBUG] Skipped char '👤' (U+1F464) — no valid score computed.
# [DEBUG] Skipped char '👥' (U+1F465) — no valid score computed.
# [DEBUG] Skipped char '👦' (U+1F466) — no valid score computed.
# [DEBUG] Skipped char '👻' (U+1F47B) — no valid score computed.
# [DEBUG] Skipped char '👿' (U+1F47F) — no valid score computed.
# [DEBUG] Skipped char '💀' (U+1F480) — no valid score computed.
# [DEBUG] Skipped char '💄' (U+1F484) — no valid score computed.
# [DEBUG] Skipped char '💊' (U+1F48A) — no valid score computed.
# [DEBUG] Skipped char '💎' (U+1F48E) — no valid score computed.
# [DEBUG] Skipped char '💏' (U+1F48F) — no valid score computed.
# [DEBUG] Skipped char '💐' (U+1F490) — no valid score computed.
# [DEBUG] Skipped char '💣' (U+1F4A3) — no valid score computed.
# [DEBUG] Skipped char '💤' (U+1F4A4) — no valid score computed.
# [DEBUG] Skipped char '💥' (U+1F4A5) — no valid score computed.
# [DEBUG] Skipped char '💩' (U+1F4A9) — no valid score computed.
# [DEBUG] Skipped char '💪' (U+1F4AA) — no valid score computed.
# [DEBUG] Skipped char '💫' (U+1F4AB) — no valid score computed.
# [DEBUG] Skipped char '💽' (U+1F4BD) — no valid score computed.
# [DEBUG] Skipped char '💾' (U+1F4BE) — no valid score computed.
# [DEBUG] Skipped char '📀' (U+1F4C0) — no valid score computed.
# [DEBUG] Skipped char '📌' (U+1F4CC) — no valid score computed.
# [DEBUG] Skipped char '📓' (U+1F4D3) — no valid score computed.
# [DEBUG] Skipped char '📕' (U+1F4D5) — no valid score computed.
# [DEBUG] Skipped char '📖' (U+1F4D6) — no valid score computed.
# [DEBUG] Skipped char '📘' (U+1F4D8) — no valid score computed.
# [DEBUG] Skipped char '📚' (U+1F4DA) — no valid score computed.
# [DEBUG] Skipped char '📝' (U+1F4DD) — no valid score computed.
# [DEBUG] Skipped char '📨' (U+1F4E8) — no valid score computed.
# [DEBUG] Skipped char '📮' (U+1F4EE) — no valid score computed.
# [DEBUG] Skipped char '📱' (U+1F4F1) — no valid score computed.
# [DEBUG] Skipped char '📴' (U+1F4F4) — no valid score computed.
# [DEBUG] Skipped char '📵' (U+1F4F5) — no valid score computed.
# [DEBUG] Skipped char '📺' (U+1F4FA) — no valid score computed.
# [DEBUG] Skipped char '🔑' (U+1F511) — no valid score computed.
# [DEBUG] Skipped char '🔒' (U+1F512) — no valid score computed.
# [DEBUG] Skipped char '🔓' (U+1F513) — no valid score computed.
# [DEBUG] Skipped char '🔔' (U+1F514) — no valid score computed.
# [DEBUG] Skipped char '🔗' (U+1F517) — no valid score computed.
# [DEBUG] Skipped char '🔪' (U+1F52A) — no valid score computed.
# [DEBUG] Skipped char '🔫' (U+1F52B) — no valid score computed.
# [DEBUG] Skipped char '🔭' (U+1F52D) — no valid score computed.
# [DEBUG] Skipped char '🕉' (U+1F549) — no valid score computed.
# [DEBUG] Skipped char '🕌' (U+1F54C) — no valid score computed.
# [DEBUG] Skipped char '🕮' (U+1F56E) — no valid score computed.
# [DEBUG] Skipped char '🕳' (U+1F573) — no valid score computed.
# [DEBUG] Skipped char '🕹' (U+1F579) — no valid score computed.
# [DEBUG] Skipped char '🖀' (U+1F580) — no valid score computed.
# [DEBUG] Skipped char '🖅' (U+1F585) — no valid score computed.
# [DEBUG] Skipped char '🖬' (U+1F5AC) — no valid score computed.
# [DEBUG] Skipped char '🖯' (U+1F5AF) — no valid score computed.
# [DEBUG] Skipped char '🗅' (U+1F5C5) — no valid score computed.
# [DEBUG] Skipped char '🗈' (U+1F5C8) — no valid score computed.
# [DEBUG] Skipped char '🗋' (U+1F5CB) — no valid score computed.
# [DEBUG] Skipped char '🗎' (U+1F5CE) — no valid score computed.
# [DEBUG] Skipped char '🗕' (U+1F5D5) — no valid score computed.
# [DEBUG] Skipped char '🗝' (U+1F5DD) — no valid score computed.
# [DEBUG] Skipped char '🗢' (U+1F5E2) — no valid score computed.
# [DEBUG] Skipped char '🗨' (U+1F5E8) — no valid score computed.
# [DEBUG] Skipped char '🗬' (U+1F5EC) — no valid score computed.
# [DEBUG] Skipped char '🗰' (U+1F5F0) — no valid score computed.
# [DEBUG] Skipped char '🗱' (U+1F5F1) — no valid score computed.
# [DEBUG] Skipped char '🗲' (U+1F5F2) — no valid score computed.
# [DEBUG] Skipped char '🗻' (U+1F5FB) — no valid score computed.
# [DEBUG] Skipped char '🙈' (U+1F648) — no valid score computed.
# [DEBUG] Skipped char '🚌' (U+1F68C) — no valid score computed.
# [DEBUG] Skipped char '🚍' (U+1F68D) — no valid score computed.
# [DEBUG] Skipped char '🚏' (U+1F68F) — no valid score computed.
# [DEBUG] Skipped char '🚐' (U+1F690) — no valid score computed.
# [DEBUG] Skipped char '🚢' (U+1F6A2) — no valid score computed.
# [DEBUG] Skipped char '🚬' (U+1F6AC) — no valid score computed.
# [DEBUG] Skipped char '🚭' (U+1F6AD) — no valid score computed.
# [DEBUG] Skipped char '🚲' (U+1F6B2) — no valid score computed.
# [DEBUG] Skipped char '🚳' (U+1F6B3) — no valid score computed.
# [DEBUG] Skipped char '🚴' (U+1F6B4) — no valid score computed.
# [DEBUG] Skipped char '🚹' (U+1F6B9) — no valid score computed.
# [DEBUG] Skipped char '🚽' (U+1F6BD) — no valid score computed.
# [DEBUG] Skipped char '🛃' (U+1F6C3) — no valid score computed.
# [DEBUG] Skipped char '🛉' (U+1F6C9) — no valid score computed.
# [DEBUG] Skipped char '🛎' (U+1F6CE) — no valid score computed.
# [DEBUG] Skipped char '🛏' (U+1F6CF) — no valid score computed.
# [DEBUG] Skipped char '🛕' (U+1F6D5) — no valid score computed.
# [DEBUG] Skipped char '🛖' (U+1F6D6) — no valid score computed.
# [DEBUG] Skipped char '🛡' (U+1F6E1) — no valid score computed.
# [DEBUG] Skipped char '🛲' (U+1F6F2) — no valid score computed.
# [DEBUG] Skipped char '🛷' (U+1F6F7) — no valid score computed.
# [DEBUG] Skipped char '🝽' (U+1F77D) — no valid score computed.
# [DEBUG] Skipped char '🤳' (U+1F933) — no valid score computed.
# [DEBUG] Skipped char '🤹' (U+1F939) — no valid score computed.
# [DEBUG] Skipped char '🥄' (U+1F944) — no valid score computed.
# [DEBUG] Skipped char '🥊' (U+1F94A) — no valid score computed.
# [DEBUG] Skipped char '🥏' (U+1F94F) — no valid score computed.
# [DEBUG] Skipped char '🥚' (U+1F95A) — no valid score computed.
# [DEBUG] Skipped char '🥟' (U+1F95F) — no valid score computed.
# [DEBUG] Skipped char '🥢' (U+1F962) — no valid score computed.
# [DEBUG] Skipped char '🥥' (U+1F965) — no valid score computed.
# [DEBUG] Skipped char '🥧' (U+1F967) — no valid score computed.
# [DEBUG] Skipped char '🥽' (U+1F97D) — no valid score computed.
# [DEBUG] Skipped char '🥾' (U+1F97E) — no valid score computed.
# [DEBUG] Skipped char '🦆' (U+1F986) — no valid score computed.
# [DEBUG] Skipped char '🦑' (U+1F991) — no valid score computed.
# [DEBUG] Skipped char '🦔' (U+1F994) — no valid score computed.
# [DEBUG] Skipped char '🦟' (U+1F99F) — no valid score computed.
# [DEBUG] Skipped char '🦤' (U+1F9A4) — no valid score computed.
# [DEBUG] Skipped char '🦥' (U+1F9A5) — no valid score computed.
# [DEBUG] Skipped char '🦨' (U+1F9A8) — no valid score computed.
# [DEBUG] Skipped char '🦬' (U+1F9AC) — no valid score computed.
# [DEBUG] Skipped char '🦮' (U+1F9AE) — no valid score computed.
# [DEBUG] Skipped char '🦴' (U+1F9B4) — no valid score computed.
# [DEBUG] Skipped char '🦵' (U+1F9B5) — no valid score computed.
# [DEBUG] Skipped char '🦶' (U+1F9B6) — no valid score computed.
# [DEBUG] Skipped char '🦷' (U+1F9B7) — no valid score computed.
# [DEBUG] Skipped char '🧅' (U+1F9C5) — no valid score computed.
# [DEBUG] Skipped char '🧊' (U+1F9CA) — no valid score computed.
# [DEBUG] Skipped char '🧒' (U+1F9D2) — no valid score computed.
# [DEBUG] Skipped char '🧝' (U+1F9DD) — no valid score computed.
# [DEBUG] Skipped char '🧞' (U+1F9DE) — no valid score computed.
# [DEBUG] Skipped char '🧟' (U+1F9DF) — no valid score computed.
# [DEBUG] Skipped char '🧤' (U+1F9E4) — no valid score computed.
# [DEBUG] Skipped char '🧦' (U+1F9E6) — no valid score computed.
# [DEBUG] Skipped char '🧪' (U+1F9EA) — no valid score computed.
# [DEBUG] Skipped char '🧰' (U+1F9F0) — no valid score computed.
# [DEBUG] Skipped char '🧴' (U+1F9F4) — no valid score computed.
# [DEBUG] Skipped char '🧽' (U+1F9FD) — no valid score computed.
# [DEBUG] Skipped char '🩺' (U+1FA7A) — no valid score computed.
# [DEBUG] Skipped char '🪀' (U+1FA80) — no valid score computed.
# [DEBUG] Skipped char '🪁' (U+1FA81) — no valid score computed.
# [DEBUG] Skipped char '🪆' (U+1FA86) — no valid score computed.
# [DEBUG] Skipped char '🪈' (U+1FA88) — no valid score computed.
# [DEBUG] Skipped char '🪙' (U+1FA99) — no valid score computed.
# [DEBUG] Skipped char '🪝' (U+1FA9D) — no valid score computed.
# [DEBUG] Skipped char '🪢' (U+1FAA2) — no valid score computed.
# [DEBUG] Skipped char '🪣' (U+1FAA3) — no valid score computed.
# [DEBUG] Skipped char '🪰' (U+1FAB0) — no valid score computed.
# [DEBUG] Skipped char '🪲' (U+1FAB2) — no valid score computed.
# [DEBUG] Skipped char '🪷' (U+1FAB7) — no valid score computed.
# [DEBUG] Skipped char '🪹' (U+1FAB9) — no valid score computed.
# [DEBUG] Skipped char '🪼' (U+1FABC) — no valid score computed.
# [DEBUG] Skipped char '🪿' (U+1FABF) — no valid score computed.
# [DEBUG] Skipped char '🫁' (U+1FAC1) — no valid score computed.
# [DEBUG] Skipped char '🫂' (U+1FAC2) — no valid score computed.
# [DEBUG] Skipped char '🫎' (U+1FACE) — no valid score computed.
# [DEBUG] Skipped char '🫏' (U+1FACF) — no valid score computed.
# [DEBUG] Skipped char '🫒' (U+1FAD2) — no valid score computed.
# [DEBUG] Skipped char '🫕' (U+1FAD5) — no valid score computed.
# [DEBUG] Skipped char '🫦' (U+1FAE6) — no valid score computed.
# [DEBUG] Skipped char '🫧' (U+1FAE7) — no valid score computed.
# [DEBUG] Skipped char '🯱' (U+1FBF1) — no valid score computed.
# [DEBUG] Skipped char '🯵' (U+1FBF5) — no valid score computed.
# [DEBUG] Skipped char '🯶' (U+1FBF6) — no valid score computed.
# [DEBUG] Skipped char '🯷' (U+1FBF7) — no valid score computed.
# [DEBUG] Skipped char '🯸' (U+1FBF8) — no valid score computed.
# [DEBUG] Skipped char '🯹' (U+1FBF9) — no valid score computed.
# [INFO] No matches found for query: 'arw'

# %% [markdown]
# #### Compare Fuzzy Algorithms

# %%
query = "arrw"
for algo in FuzzyAlgorithm.__args__:
    print(f"\n=== Fuzzy Algorithm: {algo} ===")
    results = list(find_chars(query, fuzzy=True, fuzzy_algo=algo, threshold=0.4))
    print("\n".join(results[:5]) or "No results")
# Out:
# === Fuzzy Algorithm: sequencematcher ===
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 4
#       2 for algo in FuzzyAlgorithm.__args__:
#       3     print(f"\n=== Fuzzy Algorithm: {algo} ===")
# ----> 4     results = list(find_chars(query, fuzzy=True, fuzzy_algo=algo, threshold=0.4))
#       5     print("\n".join(results[:5]) or "No results")
#
# File ~\Documents\Projects\Python\charfinder\src\charfinder\core\core_main.py:72, in find_chars(query, fuzzy, threshold, name_cache, verbose, use_color, fuzzy_algo, fuzzy_match_mode, exact_match_mode, agg_fn, prefer_fuzzy)
#      58 def find_chars(
#      59     query: str,
#      60     *,
#    (...)     70     prefer_fuzzy: bool = False,
#      71 ) -> Generator[str, None, None]:
# ---> 72     config: SearchConfig = build_search_config(
#      73         fuzzy=fuzzy,
#      74         threshold=threshold,
#      75         name_cache=name_cache,
#      76         verbose=verbose,
#      77         use_color=use_color,
#      78         fuzzy_algo=fuzzy_algo,
#      79         fuzzy_match_mode=fuzzy_match_mode,
#      80         exact_match_mode=exact_match_mode,
#      81         agg_fn=agg_fn,
#      82         prefer_fuzzy=prefer_fuzzy,
#      83     )
#      84     return _find_chars_impl(query, config)
#
# File ~\Documents\Projects\Python\charfinder\src\charfinder\core\handlers.py:206, in build_search_config(fuzzy, threshold, name_cache, verbose, use_color, fuzzy_algo, fuzzy_match_mode, exact_match_mode, agg_fn, prefer_fuzzy)
#     169 def build_search_config(
#     170     *,
#     171     fuzzy: bool,
#    (...)    180     prefer_fuzzy: bool,
#     181 ) -> SearchConfig:
#     182     """
#     183     Validate inputs and return a full SearchConfig object.
#     184
#    (...)    198         SearchConfig: Fully validated search configuration object.
#     199     """
#     200     return SearchConfig(
#     201         fuzzy=fuzzy,
#     202         threshold=validate_threshold(threshold),
#     203         name_cache=name_cache,
#     204         verbose=verbose,
#     205         use_color=use_color,
# --> 206         fuzzy_algo=validate_fuzzy_algo(fuzzy_algo),
#     207         fuzzy_match_mode=validate_fuzzy_match_mode(fuzzy_match_mode),
#     208         exact_match_mode=validate_exact_match_mode(exact_match_mode),
#     209         agg_fn=agg_fn,
#     210         prefer_fuzzy=bool(prefer_fuzzy),
#     211     )
#
# File ~\Documents\Projects\Python\charfinder\src\charfinder\validators.py:170, in validate_fuzzy_algo(fuzzy_algo, source)
#     168 if source == "cli":
#     169     return cast("FuzzyAlgorithm", fuzzy_algo)
# --> 170 return _normalize_and_validate_fuzzy_algo(fuzzy_algo)
#
# File ~\Documents\Projects\Python\charfinder\src\charfinder\validators.py:144, in _normalize_and_validate_fuzzy_algo(fuzzy_algo)
#     142 valid_inputs = sorted(set(FUZZY_ALGO_ALIASES) | set(FUZZY_ALGORITHM_REGISTRY))
#     143 message = f"{ERROR_UNKNOWN_ALGO} Supported values: {', '.join(valid_inputs)}"
# --> 144 raise ValueError(message)
#
# ValueError: Unknown or unsupported fuzzy algorithm. Supported values: hybrid, hybrid_score, lev, levenshtein, levenshtein_ratio, normalized, normalized_ratio, rapidfuzz, sequencematcher, simple, simple_ratio, token_sort, token_sort_ratio, tsr

# %%
from charfinder.core.core_main import (
    find_chars,
    find_chars_raw,
    find_chars_with_info,
)
from charfinder.constants import FuzzyAlgorithm, HybridAggFunc

# %% [markdown]
# # Unicode Normalization Test

# %%
import unicodedata

# Define some example strings
input_text = "é"  # Composed 'e' with acute accent
decomposed_e = "é"  # Decomposed 'e' + acute accent

# Apply different Unicode normalization forms
nfc = unicodedata.normalize("NFC", input_text)  # Composed form
nfd = unicodedata.normalize("NFD", input_text)  # Decomposed form
nfkc = unicodedata.normalize("NFKC", input_text)  # Compatibility composed form
nfkd = unicodedata.normalize("NFKD", input_text)  # Compatibility decomposed form

# Print the results
print(f"NFC: {nfc}")  # Composed 'É'
print(f"NFD: {nfd}")  # Decomposed 'E\u0301'
print(f"NFKC: {nfkc}")  # Compatibility composed 'É'
print(f"NFKD: {nfkd}")  # Compatibility decomposed 'E\u0301'

# Normalize manually using the decomposed string
print(f"NFC from decomposed: {unicodedata.normalize('NFC', decomposed_e)}")  # Should be 'É'
print(f"NFD from decomposed: {unicodedata.normalize('NFD', decomposed_e)}")  # Should be 'E\u0301'
# Out:
# NFC: é
# NFD: é
# NFKC: é
# NFKD: é
# NFC from decomposed: é
# NFD from decomposed: é

# %%
# Define the test characters
characters = ['é']

# Normalization results
results = {}

for char in characters:
    results[char] = {
        'NFC': unicodedata.normalize('NFC', char).upper(),
        'NFD': unicodedata.normalize('NFD', char).upper(),
        'NFKC': unicodedata.normalize('NFKC', char).upper(),
        'NFKD': unicodedata.normalize('NFKD', char).upper()
    }

results
# Out:
# {'é': {'NFC': 'É', 'NFD': 'É', 'NFKC': 'É', 'NFKD': 'É'}}

# %%
import unicodedata

# Test character
test_char = 'é'

# Normalization results
nfc_result = unicodedata.normalize('NFC', test_char)
nfd_result = unicodedata.normalize('NFD', test_char)
nfkc_result = unicodedata.normalize('NFKC', test_char)
nfkd_result = unicodedata.normalize('NFKD', test_char)

# Expected results for verification
expected_nfc = 'é'  # Composed
expected_nfd = 'é'  # Decomposed: 'e' + combining acute accent
expected_nfkc = 'é'  # Composed
expected_nfkd = 'é'  # Decomposed: 'e' + combining acute accent

# Assertions to verify the results
assert nfc_result == expected_nfc, f"Expected NFC: {expected_nfc}, but got {nfc_result}"
assert nfd_result == expected_nfd, f"Expected NFD: {expected_nfd}, but got {nfd_result}"
assert nfkc_result == expected_nfkc, f"Expected NFKC: {expected_nfkc}, but got {nfkc_result}"
assert nfkd_result == expected_nfkd, f"Expected NFKD: {expected_nfkd}, but got {nfkd_result}"

# Print the results if everything passes
print(f"NFC: {nfc_result}")
print(f"NFD: {nfd_result}")
print(f"NFKC: {nfkc_result}")
print(f"NFKD: {nfkd_result}")
# Out:
# NFC: é
# NFD: é
# NFKC: é
# NFKD: é

# %%
import unicodedata

# Example characters
characters = ['é', 'è', 'ü', 'ç']

# Normalize results and manually check their Unicode code points
results = {}

for char in characters:
    results[char] = {
        'NFC': unicodedata.normalize('NFC', char),
        'NFD': unicodedata.normalize('NFD', char),
        'NFKC': unicodedata.normalize('NFKC', char),
        'NFKD': unicodedata.normalize('NFKD', char),
        'code_points': [ord(c) for c in char]  # To see the exact code points of characters
}

# Print results to verify normalization and character code points
results
# Out:
# {'é': {'NFC': 'é',
#   'NFD': 'é',
#   'NFKC': 'é',
#   'NFKD': 'é',
#   'code_points': [233]},
#  'è': {'NFC': 'è',
#   'NFD': 'è',
#   'NFKC': 'è',
#   'NFKD': 'è',
#   'code_points': [232]},
#  'ü': {'NFC': 'ü',
#   'NFD': 'ü',
#   'NFKC': 'ü',
#   'NFKD': 'ü',
#   'code_points': [252]},
#  'ç': {'NFC': 'ç',
#   'NFD': 'ç',
#   'NFKC': 'ç',
#   'NFKD': 'ç',
#   'code_points': [231]}}

# %%
# Normalization results matrix for each normalization form
normalization_matrix = {
    "é": {
        "NFC": "É",
        "NFD": "É",
        "NFKC": "É",
        "NFKD": "É"
    },
    "è": {
        "NFC": "È",
        "NFD": "E\u0300",
        "NFKC": "È",
        "NFKD": "E\u0300"
    },
    "ü": {
        "NFC": "Ü",
        "NFD": "U\u0308",
        "NFKC": "Ü",
        "NFKD": "U\u0308"
    },
    "ç": {
        "NFC": "Ç",
        "NFD": "C\u0327",
        "NFKC": "Ç",
        "NFKD": "C\u0327"
    },
    "ö": {
        "NFC": "Ö",
        "NFD": "O\u0308",
        "NFKC": "Ö",
        "NFKD": "O\u0308"
    },
    "œ": {
        "NFC": "Œ",
        "NFD": "O\u0302E",
        "NFKC": "Œ",
        "NFKD": "O\u0302E"
    },
    "æ": {
        "NFC": "Æ",
        "NFD": "A\u030C",
        "NFKC": "Æ",
        "NFKD": "A\u030C"
    },
    "é": {
        "NFC": "É",
        "NFD": "E\u0301",
        "NFKC": "É",
        "NFKD": "E\u0301"
    },
    "á": {
        "NFC": "Á",
        "NFD": "A\u0301",
        "NFKC": "Á",
        "NFKD": "A\u0301"
    },
    "à": {
        "NFC": "À",
        "NFD": "A\u0300",
        "NFKC": "À",
        "NFKD": "A\u0300"
    },
    "ñ": {
        "NFC": "Ñ",
        "NFD": "N\u0303",
        "NFKC": "Ñ",
        "NFKD": "N\u0303"
    },
    "ø": {
        "NFC": "Ø",
        "NFD": "O\u0308",
        "NFKC": "Ø",
        "NFKD": "O\u0308"
    }
}

# Now you can print or verify this matrix directly in your notebook for manual checks:
print(normalization_matrix)
# Out:
# {'é': {'NFC': 'É', 'NFD': 'É', 'NFKC': 'É', 'NFKD': 'É'}, 'è': {'NFC': 'È', 'NFD': 'È', 'NFKC': 'È', 'NFKD': 'È'}, 'ü': {'NFC': 'Ü', 'NFD': 'Ü', 'NFKC': 'Ü', 'NFKD': 'Ü'}, 'ç': {'NFC': 'Ç', 'NFD': 'Ç', 'NFKC': 'Ç', 'NFKD': 'Ç'}, 'ö': {'NFC': 'Ö', 'NFD': 'Ö', 'NFKC': 'Ö', 'NFKD': 'Ö'}, 'œ': {'NFC': 'Œ', 'NFD': 'ÔE', 'NFKC': 'Œ', 'NFKD': 'ÔE'}, 'æ': {'NFC': 'Æ', 'NFD': 'Ǎ', 'NFKC': 'Æ', 'NFKD': 'Ǎ'}, 'é': {'NFC': 'É', 'NFD': 'É', 'NFKC': 'É', 'NFKD': 'É'}, 'á': {'NFC': 'Á', 'NFD': 'Á', 'NFKC': 'Á', 'NFKD': 'Á'}, 'à': {'NFC': 'À', 'NFD': 'À', 'NFKC': 'À', 'NFKD': 'À'}, 'ñ': {'NFC': 'Ñ', 'NFD': 'Ñ', 'NFKC': 'Ñ', 'NFKD': 'Ñ'}, 'ø': {'NFC': 'Ø', 'NFD': 'Ö', 'NFKC': 'Ø', 'NFKD': 'Ö'}}

# %%
{
    'é': {'NFC': 'É', 'NFD': 'É', 'NFKC': 'É', 'NFKD': 'É'},
    'è': {'NFC': 'È', 'NFD': 'È', 'NFKC': 'È', 'NFKD': 'È'},
    'ü': {'NFC': 'Ü', 'NFD': 'Ü', 'NFKC': 'Ü', 'NFKD': 'Ü'},
    'ç': {'NFC': 'Ç', 'NFD': 'Ç', 'NFKC': 'Ç', 'NFKD': 'Ç'},
    'ö': {'NFC': 'Ö', 'NFD': 'Ö', 'NFKC': 'Ö', 'NFKD': 'Ö'},
    'œ': {'NFC': 'Œ', 'NFD': 'ÔE', 'NFKC': 'Œ', 'NFKD': 'ÔE'},
    'æ': {'NFC': 'Æ', 'NFD': 'Ǎ', 'NFKC': 'Æ', 'NFKD': 'Ǎ'},
    'é': {'NFC': 'É', 'NFD': 'É', 'NFKC': 'É', 'NFKD': 'É'},
    'á': {'NFC': 'Á', 'NFD': 'Á', 'NFKC': 'Á', 'NFKD': 'Á'},
    'à': {'NFC': 'À', 'NFD': 'À', 'NFKC': 'À', 'NFKD': 'À'},
    'ñ': {'NFC': 'Ñ', 'NFD': 'Ñ', 'NFKC': 'Ñ', 'NFKD': 'Ñ'},
    'ø': {'NFC': 'Ø', 'NFD': 'Ö', 'NFKC': 'Ø', 'NFKD': 'Ö'}
}
# Out:
# {'é': {'NFC': 'É', 'NFD': 'É', 'NFKC': 'É', 'NFKD': 'É'},
#  'è': {'NFC': 'È', 'NFD': 'È', 'NFKC': 'È', 'NFKD': 'È'},
#  'ü': {'NFC': 'Ü', 'NFD': 'Ü', 'NFKC': 'Ü', 'NFKD': 'Ü'},
#  'ç': {'NFC': 'Ç', 'NFD': 'Ç', 'NFKC': 'Ç', 'NFKD': 'Ç'},
#  'ö': {'NFC': 'Ö', 'NFD': 'Ö', 'NFKC': 'Ö', 'NFKD': 'Ö'},
#  'œ': {'NFC': 'Œ', 'NFD': 'ÔE', 'NFKC': 'Œ', 'NFKD': 'ÔE'},
#  'æ': {'NFC': 'Æ', 'NFD': 'Ǎ', 'NFKC': 'Æ', 'NFKD': 'Ǎ'},
#  'é': {'NFC': 'É', 'NFD': 'É', 'NFKC': 'É', 'NFKD': 'É'},
#  'á': {'NFC': 'Á', 'NFD': 'Á', 'NFKC': 'Á', 'NFKD': 'Á'},
#  'à': {'NFC': 'À', 'NFD': 'À', 'NFKC': 'À', 'NFKD': 'À'},
#  'ñ': {'NFC': 'Ñ', 'NFD': 'Ñ', 'NFKC': 'Ñ', 'NFKD': 'Ñ'},
#  'ø': {'NFC': 'Ø', 'NFD': 'Ö', 'NFKC': 'Ø', 'NFKD': 'Ö'}}

# %%
import unicodedata

# Define the test characters and expected normalized values
test_characters = {
    'é': {'NFC': 'É', 'NFD': 'É', 'NFKC': 'É', 'NFKD': 'É'},
    'è': {'NFC': 'È', 'NFD': 'È', 'NFKC': 'È', 'NFKD': 'È'},
    'ü': {'NFC': 'Ü', 'NFD': 'Ü', 'NFKC': 'Ü', 'NFKD': 'Ü'},
    'ç': {'NFC': 'Ç', 'NFD': 'Ç', 'NFKC': 'Ç', 'NFKD': 'Ç'},
    'ö': {'NFC': 'Ö', 'NFD': 'Ö', 'NFKC': 'Ö', 'NFKD': 'Ö'},
    'œ': {'NFC': 'Œ', 'NFD': 'Œ', 'NFKC': 'Œ', 'NFKD': 'Œ'},
    'æ': {'NFC': 'Æ', 'NFD': 'Æ', 'NFKC': 'Æ', 'NFKD': 'Æ'},
    'é': {'NFC': 'É', 'NFD': 'É', 'NFKC': 'É', 'NFKD': 'É'},
    'á': {'NFC': 'Á', 'NFD': 'Á', 'NFKC': 'Á', 'NFKD': 'Á'},
    'à': {'NFC': 'À', 'NFD': 'À', 'NFKC': 'À', 'NFKD': 'À'},
    'ñ': {'NFC': 'Ñ', 'NFD': 'Ñ', 'NFKC': 'Ñ', 'NFKD': 'Ñ'},
    'ø': {'NFC': 'Ø', 'NFD': 'Ø', 'NFKC': 'Ø', 'NFKD': 'Ø'}
}

# Perform the normalization and verify it
for char, expected_norms in test_characters.items():
    for norm_form, expected_value in expected_norms.items():
        normalized = unicodedata.normalize(norm_form, char)
        # Convert the normalized value to uppercase
        normalized_upper = normalized.upper()
        
        # Print the results for verification
        print(f"Input: {char}, Norm Method: {norm_form}, Expected: {expected_value}, Normalized: {normalized_upper}")
        assert normalized_upper == expected_value, f"Test failed for {char} with {norm_form}. Expected {expected_value}, but got {normalized_upper}."
# Out:
# Input: é, Norm Method: NFC, Expected: É, Normalized: É
# Input: é, Norm Method: NFD, Expected: É, Normalized: É
# Input: é, Norm Method: NFKC, Expected: É, Normalized: É
# Input: é, Norm Method: NFKD, Expected: É, Normalized: É
# Input: è, Norm Method: NFC, Expected: È, Normalized: È
# Input: è, Norm Method: NFD, Expected: È, Normalized: È
# Input: è, Norm Method: NFKC, Expected: È, Normalized: È
# Input: è, Norm Method: NFKD, Expected: È, Normalized: È
# Input: ü, Norm Method: NFC, Expected: Ü, Normalized: Ü
# Input: ü, Norm Method: NFD, Expected: Ü, Normalized: Ü
# Input: ü, Norm Method: NFKC, Expected: Ü, Normalized: Ü
# Input: ü, Norm Method: NFKD, Expected: Ü, Normalized: Ü
# Input: ç, Norm Method: NFC, Expected: Ç, Normalized: Ç
# Input: ç, Norm Method: NFD, Expected: Ç, Normalized: Ç
# Input: ç, Norm Method: NFKC, Expected: Ç, Normalized: Ç
# Input: ç, Norm Method: NFKD, Expected: Ç, Normalized: Ç
# Input: ö, Norm Method: NFC, Expected: Ö, Normalized: Ö
# Input: ö, Norm Method: NFD, Expected: Ö, Normalized: Ö
# Input: ö, Norm Method: NFKC, Expected: Ö, Normalized: Ö
# Input: ö, Norm Method: NFKD, Expected: Ö, Normalized: Ö
# Input: œ, Norm Method: NFC, Expected: Œ, Normalized: Œ
# Input: œ, Norm Method: NFD, Expected: Œ, Normalized: Œ
# Input: œ, Norm Method: NFKC, Expected: Œ, Normalized: Œ
# Input: œ, Norm Method: NFKD, Expected: Œ, Normalized: Œ
# Input: æ, Norm Method: NFC, Expected: Æ, Normalized: Æ
# Input: æ, Norm Method: NFD, Expected: Æ, Normalized: Æ
# Input: æ, Norm Method: NFKC, Expected: Æ, Normalized: Æ
# Input: æ, Norm Method: NFKD, Expected: Æ, Normalized: Æ
# Input: é, Norm Method: NFC, Expected: É, Normalized: É
# Input: é, Norm Method: NFD, Expected: É, Normalized: É
# Input: é, Norm Method: NFKC, Expected: É, Normalized: É
# Input: é, Norm Method: NFKD, Expected: É, Normalized: É
# Input: á, Norm Method: NFC, Expected: Á, Normalized: Á
# Input: á, Norm Method: NFD, Expected: Á, Normalized: Á
# Input: á, Norm Method: NFKC, Expected: Á, Normalized: Á
# Input: á, Norm Method: NFKD, Expected: Á, Normalized: Á
# Input: à, Norm Method: NFC, Expected: À, Normalized: À
# Input: à, Norm Method: NFD, Expected: À, Normalized: À
# Input: à, Norm Method: NFKC, Expected: À, Normalized: À
# Input: à, Norm Method: NFKD, Expected: À, Normalized: À
# Input: ñ, Norm Method: NFC, Expected: Ñ, Normalized: Ñ
# Input: ñ, Norm Method: NFD, Expected: Ñ, Normalized: Ñ
# Input: ñ, Norm Method: NFKC, Expected: Ñ, Normalized: Ñ
# Input: ñ, Norm Method: NFKD, Expected: Ñ, Normalized: Ñ
# Input: ø, Norm Method: NFC, Expected: Ø, Normalized: Ø
# Input: ø, Norm Method: NFD, Expected: Ø, Normalized: Ø
# Input: ø, Norm Method: NFKC, Expected: Ø, Normalized: Ø
# Input: ø, Norm Method: NFKD, Expected: Ø, Normalized: Ø

# %%
import unicodedata

# Define the test characters and expected normalized values
test_characters = {
    'é': {'NFC': 'É', 'NFD': 'É', 'NFKC': 'É', 'NFKD': 'É'},
    'è': {'NFC': 'È', 'NFD': 'È', 'NFKC': 'È', 'NFKD': 'È'},
    'ü': {'NFC': 'Ü', 'NFD': 'Ü', 'NFKC': 'Ü', 'NFKD': 'Ü'},
    'ç': {'NFC': 'Ç', 'NFD': 'Ç', 'NFKC': 'Ç', 'NFKD': 'Ç'},
    'ö': {'NFC': 'Ö', 'NFD': 'Ö', 'NFKC': 'Ö', 'NFKD': 'Ö'},
    'œ': {'NFC': 'Œ', 'NFD': 'Œ', 'NFKC': 'Œ', 'NFKD': 'Œ'},
    'æ': {'NFC': 'Æ', 'NFD': 'Æ', 'NFKC': 'Æ', 'NFKD': 'Æ'},
    'é': {'NFC': 'É', 'NFD': 'É', 'NFKC': 'É', 'NFKD': 'É'},
    'á': {'NFC': 'Á', 'NFD': 'Á', 'NFKC': 'Á', 'NFKD': 'Á'},
    'à': {'NFC': 'À', 'NFD': 'À', 'NFKC': 'À', 'NFKD': 'À'},
    'ñ': {'NFC': 'Ñ', 'NFD': 'Ñ', 'NFKC': 'Ñ', 'NFKD': 'Ñ'},
    'ø': {'NFC': 'Ø', 'NFD': 'Ø', 'NFKC': 'Ø', 'NFKD': 'Ø'}
}

# Perform the normalization and verify it
for char, expected_norms in test_characters.items():
    for norm_form, expected_value in expected_norms.items():
        normalized = unicodedata.normalize(norm_form, char)
        # Convert the normalized value to uppercase
        normalized_upper = normalized.upper()

        # Print the results for verification
        #print(f"Input: {char}, Norm Method: {norm_form}, Expected: {expected_value}, Normalized: {normalized_upper}")
        assert normalized_upper == expected_value, f"Test failed for {char} with {norm_form}. Expected {expected_value}, but got {normalized_upper}."

# %%
# what works in pytest:
test_characters = {
    'é': {'NFC': 'É', 'NFD': 'É', 'NFKC': 'É', 'NFKD': 'É'},
    'è': {'NFC': 'È', 'NFD': 'È', 'NFKC': 'È', 'NFKD': 'È'},
    'ü': {'NFC': 'Ü', 'NFD': 'Ü', 'NFKC': 'Ü', 'NFKD': 'Ü'},
    'ç': {'NFC': 'Ç', 'NFD': 'Ç', 'NFKC': 'Ç', 'NFKD': 'Ç'},
    'ö': {'NFC': 'Ö', 'NFD': 'Ö', 'NFKC': 'Ö', 'NFKD': 'Ö'},
    'œ': {'NFC': 'Œ', 'NFD': 'Œ', 'NFKC': 'Œ', 'NFKD': 'Œ'},
    'æ': {'NFC': 'Æ', 'NFD': 'Æ', 'NFKC': 'Æ', 'NFKD': 'Æ'},
    'é': {'NFC': 'É', 'NFD': 'É', 'NFKC': 'É', 'NFKD': 'É'},
    'á': {'NFC': 'Á', 'NFD': 'Á', 'NFKC': 'Á', 'NFKD': 'Á'},
    'à': {'NFC': 'À', 'NFD': 'À', 'NFKC': 'À', 'NFKD': 'À'},
    'ñ': {'NFC': 'Ñ', 'NFD': 'Ñ', 'NFKC': 'Ñ', 'NFKD': 'Ñ'},
    'ø': {'NFC': 'Ø', 'NFD': 'Ø', 'NFKC': 'Ø', 'NFKD': 'Ø'}
}

# Perform the normalization and verify it
for char, expected_norms in test_characters.items():
    for norm_form, expected_value in expected_norms.items():
        normalized = unicodedata.normalize(norm_form, char)
        # Convert the normalized value to uppercase
        normalized_upper = normalized.upper()

        # Print the results for verification
        #print(f"Input: {char}, Norm Method: {norm_form}, Expected: {expected_value}, Normalized: {normalized_upper}")
        assert normalized_upper == expected_value, f"Test failed for {char} with {norm_form}. Expected {expected_value}, but got {normalized_upper}."
