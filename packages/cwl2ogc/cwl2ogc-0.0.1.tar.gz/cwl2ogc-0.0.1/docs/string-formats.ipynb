# %% [markdown]
# # String formats
#
# Follow below an example to demonstrate how the library handles and convert a an almost complete subset of all supported string formats by OpenAPI/JSON Schema, initial schema implementation in https://raw.githubusercontent.com/eoap/schemas/main/string_format.yaml
#
# What's out of the scope:
#
# * `binary`;
# * `byte`;
# * `regex` (`pattern` could be computed at runtime only, no way to specify it in the schema).

# %% [markdown]
# ## 1. Parsing
#
# Convert the CWL document, from its YAML representation, to the CWL DOM via [cwl-utils APIs](https://github.com/common-workflow-language/cwl-utils):

# %%
from cwl_utils.parser import load_document_by_yaml, save
import yaml

with open('./workflows/string-formats.cwl') as f:
    cwl_content = yaml.load(f, Loader=yaml.SafeLoader)

cwl = load_document_by_yaml(yaml=cwl_content, uri="io://", load_all=True)

print(
    yaml.dump(
        save(
            val=cwl,
            relative_uris=False
        )
    )
)
# Out:
# baseCommand: echo
# class: CommandLineTool
# cwlVersion: v1.2
# id: io:/#main
# inputs:
# - id: io:/#main/date_input
#   label: 'Expected schema serialization: { "type": "string", "format": ""date" }'
#   type: https://raw.githubusercontent.com/eoap/schemas/main/string_format.yaml#Date
# - id: io:/#main/date-time_input
#   label: 'Expected schema serialization: { "type": "string", "format": "date-time"
#     }'
#   type: https://raw.githubusercontent.com/eoap/schemas/main/string_format.yaml#DateTime
# - id: io:/#main/duration_input
#   label: 'Expected schema serialization: { "type": "string", "format": "duration"
#     }'
#   type: https://raw.githubusercontent.com/eoap/schemas/main/string_format.yaml#Duration
# - id: io:/#main/email_input
#   label: 'Expected schema serialization: { "type": "string", "format": "email" }'
#   type: https://raw.githubusercontent.com/eoap/schemas/main/string_format.yaml#Email
# - id: io:/#main/hostname_input
#   label: 'Expected schema serialization: { "type": "string", "format": "hostname"
#     }'
#   type: https://raw.githubusercontent.com/eoap/schemas/main/string_format.yaml#Hostname
# - id: io:/#main/idn-email_input
#   label: 'Expected schema serialization: { "type": "string", "format": "idn-email"
#     }'
#   type: https://raw.githubusercontent.com/eoap/schemas/main/string_format.yaml#IDNEmail
# - id: io:/#main/idn-hostname_input
#   label: 'Expected schema serialization: { "type": "string", "format": "idn-hostname"
#     }'
#   type: https://raw.githubusercontent.com/eoap/schemas/main/string_format.yaml#IDNHostname
# - id: io:/#main/ipv4_input
#   label: 'Expected schema serialization: { "type": "string", "format": "ipv4" }'
#   type: https://raw.githubusercontent.com/eoap/schemas/main/string_format.yaml#IPv4
# - id: io:/#main/ipv6_input
#   label: 'Expected schema serialization: { "type": "string", "format": "ipv6" }'
#   type: https://raw.githubusercontent.com/eoap/schemas/main/string_format.yaml#IPv6
# - id: io:/#main/iri_input
#   label: 'Expected schema serialization: { "type": "string", "format": "iri" }'
#   type: https://raw.githubusercontent.com/eoap/schemas/main/string_format.yaml#IRI
# - id: io:/#main/iri-reference_input
#   label: 'Expected schema serialization: { "type": "string", "format": "iri-reference"
#     }'
#   type: https://raw.githubusercontent.com/eoap/schemas/main/string_format.yaml#IRIReference
# - id: io:/#main/json-pointer_input
#   label: 'Expected schema serialization: { "type": "string", "format": "json-pointer"
#     }'
#   type: https://raw.githubusercontent.com/eoap/schemas/main/string_format.yaml#JsonPointer
# - id: io:/#main/password_input
#   label: 'Expected schema serialization: { "type": "string", "format": "password"
#     }'
#   type: https://raw.githubusercontent.com/eoap/schemas/main/string_format.yaml#Password
# - id: io:/#main/relative-json-pointer_input
#   label: 'Expected schema serialization: { "type": "string", "format": "relative-json-pointer"
#     }'
#   type: https://raw.githubusercontent.com/eoap/schemas/main/string_format.yaml#RelativeJsonPointer
# - id: io:/#main/uuid_input
#   label: 'Expected schema serialization: { "type": "string", "format": "uuid" }'
#   type: https://raw.githubusercontent.com/eoap/schemas/main/string_format.yaml#UUID
# - id: io:/#main/uri_input
#   label: 'Expected schema serialization: { "type": "string", "format": "uri" }'
#   type: https://raw.githubusercontent.com/eoap/schemas/main/string_format.yaml#URI
# - id: io:/#main/uri-reference_input
#   label: 'Expected schema serialization: { "type": "string", "format": "uri-reference"
#     }'
#   type: https://raw.githubusercontent.com/eoap/schemas/main/string_format.yaml#URIReference
# - id: io:/#main/uri-template_input
#   label: 'Expected schema serialization: { "type": "string", "format": "uri-template"
#     }'
#   type: https://raw.githubusercontent.com/eoap/schemas/main/string_format.yaml#URITemplate
# - id: io:/#main/time_input
#   label: 'Expected schema serialization: { "type": "string", "format": "time" }'
#   type: https://raw.githubusercontent.com/eoap/schemas/main/string_format.yaml#Time
# label: Echo OGC BBox
# outputs:
# - id: io:/#main/echo_output
#   type: stdout
# requirements:
# - class: InlineJavascriptRequirement
# - class: SchemaDefRequirement
#   types:
#   - fields:
#     - name: https://raw.githubusercontent.com/eoap/schemas/main/string_format.yaml#Date/value
#       type: string
#     name: https://raw.githubusercontent.com/eoap/schemas/main/string_format.yaml#Date
#     type: record
#   - fields:
#     - name: https://raw.githubusercontent.com/eoap/schemas/main/string_format.yaml#DateTime/value
#       type: string
#     name: https://raw.githubusercontent.com/eoap/schemas/main/string_format.yaml#DateTime
#     type: record
#   - fields:
#     - name: https://raw.githubusercontent.com/eoap/schemas/main/string_format.yaml#Duration/value
#       type: string
#     name: https://raw.githubusercontent.com/eoap/schemas/main/string_format.yaml#Duration
#     type: record
#   - fields:
#     - name: https://raw.githubusercontent.com/eoap/schemas/main/string_format.yaml#Email/value
#       type: string
#     name: https://raw.githubusercontent.com/eoap/schemas/main/string_format.yaml#Email
#     type: record
#   - fields:
#     - name: https://raw.githubusercontent.com/eoap/schemas/main/string_format.yaml#Hostname/value
#       type: string
#     name: https://raw.githubusercontent.com/eoap/schemas/main/string_format.yaml#Hostname
#     type: record
#   - fields:
#     - name: https://raw.githubusercontent.com/eoap/schemas/main/string_format.yaml#IDNEmail/value
#       type: string
#     name: https://raw.githubusercontent.com/eoap/schemas/main/string_format.yaml#IDNEmail
#     type: record
#   - fields:
#     - name: https://raw.githubusercontent.com/eoap/schemas/main/string_format.yaml#IDNHostname/value
#       type: string
#     name: https://raw.githubusercontent.com/eoap/schemas/main/string_format.yaml#IDNHostname
#     type: record
#   - fields:
#     - name: https://raw.githubusercontent.com/eoap/schemas/main/string_format.yaml#IPv4/value
#       type: string
#     name: https://raw.githubusercontent.com/eoap/schemas/main/string_format.yaml#IPv4
#     type: record
#   - fields:
#     - name: https://raw.githubusercontent.com/eoap/schemas/main/string_format.yaml#IPv6/value
#       type: string
#     name: https://raw.githubusercontent.com/eoap/schemas/main/string_format.yaml#IPv6
#     type: record
#   - fields:
#     - name: https://raw.githubusercontent.com/eoap/schemas/main/string_format.yaml#IRI/value
#       type: string
#     name: https://raw.githubusercontent.com/eoap/schemas/main/string_format.yaml#IRI
#     type: record
#   - fields:
#     - name: https://raw.githubusercontent.com/eoap/schemas/main/string_format.yaml#IRIReference/value
#       type: string
#     name: https://raw.githubusercontent.com/eoap/schemas/main/string_format.yaml#IRIReference
#     type: record
#   - fields:
#     - name: https://raw.githubusercontent.com/eoap/schemas/main/string_format.yaml#JsonPointer/value
#       type: string
#     name: https://raw.githubusercontent.com/eoap/schemas/main/string_format.yaml#JsonPointer
#     type: record
#   - fields:
#     - name: https://raw.githubusercontent.com/eoap/schemas/main/string_format.yaml#Password/value
#       type: string
#     name: https://raw.githubusercontent.com/eoap/schemas/main/string_format.yaml#Password
#     type: record
#   - fields:
#     - name: https://raw.githubusercontent.com/eoap/schemas/main/string_format.yaml#RelativeJsonPointer/value
#       type: string
#     name: https://raw.githubusercontent.com/eoap/schemas/main/string_format.yaml#RelativeJsonPointer
#     type: record
#   - fields:
#     - name: https://raw.githubusercontent.com/eoap/schemas/main/string_format.yaml#UUID/value
#       type: string
#     name: https://raw.githubusercontent.com/eoap/schemas/main/string_format.yaml#UUID
#     type: record
#   - fields:
#     - name: https://raw.githubusercontent.com/eoap/schemas/main/string_format.yaml#URI/value
#       type: string
#     name: https://raw.githubusercontent.com/eoap/schemas/main/string_format.yaml#URI
#     type: record
#   - fields:
#     - name: https://raw.githubusercontent.com/eoap/schemas/main/string_format.yaml#URIReference/value
#       type: string
#     name: https://raw.githubusercontent.com/eoap/schemas/main/string_format.yaml#URIReference
#     type: record
#   - fields:
#     - name: https://raw.githubusercontent.com/eoap/schemas/main/string_format.yaml#URITemplate/value
#       type: string
#     name: https://raw.githubusercontent.com/eoap/schemas/main/string_format.yaml#URITemplate
#     type: record
#   - fields:
#     - name: https://raw.githubusercontent.com/eoap/schemas/main/string_format.yaml#Time/value
#       type: string
#     name: https://raw.githubusercontent.com/eoap/schemas/main/string_format.yaml#Time
#     type: record
# stdout: echo_output.txt

# %% [markdown]
# # 2. Inputs conversion
#
# Once the document is parsed, invoke the `cwl2ogc` APIs to convert the CWL inputs to the OGC JSON format:

# %%
from cwl2ogc import BaseCWLtypes2OGCConverter
import json

converter = BaseCWLtypes2OGCConverter(cwl)

inputs = converter.to_ogc(cwl.inputs)

print(json.dumps(inputs, indent=2))
# Out:
# {
#   "date_input": {
#     "schema": {
#       "type": "string",
#       "format": "date"
#     },
#     "title": "Expected schema serialization: { \"type\": \"string\", \"format\": \"\"date\" }"
#   },
#   "date-time_input": {
#     "schema": {
#       "type": "string",
#       "format": "date-time"
#     },
#     "title": "Expected schema serialization: { \"type\": \"string\", \"format\": \"date-time\" }"
#   },
#   "duration_input": {
#     "schema": {
#       "type": "string",
#       "format": "duration"
#     },
#     "title": "Expected schema serialization: { \"type\": \"string\", \"format\": \"duration\" }"
#   },
#   "email_input": {
#     "schema": {
#       "type": "string",
#       "format": "email"
#     },
#     "title": "Expected schema serialization: { \"type\": \"string\", \"format\": \"email\" }"
#   },
#   "hostname_input": {
#     "schema": {
#       "type": "string",
#       "format": "hostname"
#     },
#     "title": "Expected schema serialization: { \"type\": \"string\", \"format\": \"hostname\" }"
#   },
#   "idn-email_input": {
#     "schema": {
#       "type": "string",
#       "format": "idn-email"
#     },
#     "title": "Expected schema serialization: { \"type\": \"string\", \"format\": \"idn-email\" }"
#   },
#   "idn-hostname_input": {
#     "schema": {
#       "type": "string",
#       "format": "idn-hostname"
#     },
#     "title": "Expected schema serialization: { \"type\": \"string\", \"format\": \"idn-hostname\" }"
#   },
#   "ipv4_input": {
#     "schema": {
#       "type": "string",
#       "format": "ipv4"
#     },
#     "title": "Expected schema serialization: { \"type\": \"string\", \"format\": \"ipv4\" }"
#   },
#   "ipv6_input": {
#     "schema": {
#       "type": "string",
#       "format": "ipv6"
#     },
#     "title": "Expected schema serialization: { \"type\": \"string\", \"format\": \"ipv6\" }"
#   },
#   "iri_input": {
#     "schema": {
#       "type": "string",
#       "format": "iri"
#     },
#     "title": "Expected schema serialization: { \"type\": \"string\", \"format\": \"iri\" }"
#   },
#   "iri-reference_input": {
#     "schema": {
#       "type": "string",
#       "format": "iri-reference"
#     },
#     "title": "Expected schema serialization: { \"type\": \"string\", \"format\": \"iri-reference\" }"
#   },
#   "json-pointer_input": {
#     "schema": {
#       "type": "string",
#       "format": "json-pointer"
#     },
#     "title": "Expected schema serialization: { \"type\": \"string\", \"format\": \"json-pointer\" }"
#   },
#   "password_input": {
#     "schema": {
#       "type": "string",
#       "format": "password"
#     },
#     "title": "Expected schema serialization: { \"type\": \"string\", \"format\": \"password\" }"
#   },
#   "relative-json-pointer_input": {
#     "schema": {
#       "type": "string",
#       "format": "relative-json-pointer"
#     },
#     "title": "Expected schema serialization: { \"type\": \"string\", \"format\": \"relative-json-pointer\" }"
#   },
#   "uuid_input": {
#     "schema": {
#       "type": "string",
#       "format": "uuid"
#     },
#     "title": "Expected schema serialization: { \"type\": \"string\", \"format\": \"uuid\" }"
#   },
#   "uri_input": {
#     "schema": {
#       "type": "string",
#       "format": "uri"
#     },
#     "title": "Expected schema serialization: { \"type\": \"string\", \"format\": \"uri\" }"
#   },
#   "uri-reference_input": {
#     "schema": {
#       "type": "string",
#       "format": "uri-reference"
#     },
#     "title": "Expected schema serialization: { \"type\": \"string\", \"format\": \"uri-reference\" }"
#   },
#   "uri-template_input": {
#     "schema": {
#       "type": "string",
#       "format": "uri-template"
#     },
#     "title": "Expected schema serialization: { \"type\": \"string\", \"format\": \"uri-template\" }"
#   },
#   "time_input": {
#     "schema": {
#       "type": "string",
#       "format": "time"
#     },
#     "title": "Expected schema serialization: { \"type\": \"string\", \"format\": \"time\" }"
#   }
# }

# %% [markdown]
# # 2. Outputs conversion
#
# Users can reuse the `BaseCWLtypes2OGCConverter` instance to convert the CWL outputs to the OGC JSON format:

# %%
outputs = converter.to_ogc(cwl.outputs)

print(json.dumps(outputs, indent=2))
# Out:
# {
#   "echo_output": {
#     "schema": {
#       "type": "string"
#     }
#   }
# }
