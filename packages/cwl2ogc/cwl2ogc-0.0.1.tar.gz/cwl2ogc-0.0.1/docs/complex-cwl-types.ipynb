# %% [markdown]
# # Complex CWL types
#
# Follow below an example to demonstrate how the library handles and convert a CWL where inputs are declared with hybrid types.

# %% [markdown]
# ## 1. Parsing
#
# Convert the CWL document, from its YAML representation, to the CWL DOM via [cwl-utils APIs](https://github.com/common-workflow-language/cwl-utils):

# %%
from cwl_utils.parser import load_document_by_yaml, save
import yaml

with open('./workflows/complex-cwl-types.cwl') as f:
    cwl_content = yaml.load(f, Loader=yaml.SafeLoader)

cwl = load_document_by_yaml(yaml=cwl_content, uri="io://", load_all=True)

print(
    yaml.dump(
        save(
            val=cwl,
            relative_uris=False
        )
    )
)
# Out:
# arguments: []
# baseCommand:
# - echo
# class: CommandLineTool
# cwlVersion: v1.2
# id: io:/#main
# inputs:
# - default: green
#   doc: color doc
#   id: io:/#main/color
#   label: color label
#   type:
#     name: _:b5e2c121-45b9-430f-bc55-bb57cb95316a
#     symbols:
#     - io:/#main/color/red
#     - io:/#main/color/green
#     - io:/#main/color/blue
#     type: enum
# - doc: color1 doc
#   id: io:/#main/color1
#   label: color1 label
#   type:
#   - 'null'
#   - items:
#       name: _:f8c8f12c-60d7-408e-8856-4853283e7d03
#       symbols:
#       - io:/#main/color1/red
#       - io:/#main/color1/green
#       - io:/#main/color1/blue
#       type: enum
#     name: _:89567c6f-ac35-41d6-b106-05a8b3ecf177
#     type: array
# - doc: bands doc
#   id: io:/#main/bands
#   label: bands label
#   type:
#   - 'null'
#   - items:
#       items:
#         name: _:67255de5-a4d8-4fb8-9b84-32033b9cfb69
#         symbols:
#         - io:/#main/bands/red
#         - io:/#main/bands/green
#         - io:/#main/bands/blue
#         type: enum
#       name: _:a6c596de-92b0-448f-bd3f-d6cc1bc7470d
#       type: array
#     name: _:7732b8f5-ec7b-4db2-ae71-b3eeb8df8317
#     type: array
# - doc: input0 doc
#   id: io:/#main/input0
#   inputBinding:
#     position: 1
#   label: input0 label
#   type: string
# - default: default
#   doc: optional_string doc
#   id: io:/#main/optional_string
#   label: optional_string label
#   type:
#   - 'null'
#   - string
# - doc: input1 doc
#   id: io:/#main/input1
#   inputBinding:
#     position: 2
#   label: input1 label
#   type:
#     items: string
#     name: _:0e4cc649-24c8-4920-82f7-cec6f1d3a2ea
#     type: array
# - doc: input2 doc
#   id: io:/#main/input2
#   inputBinding:
#     position: 2
#   label: input2 label
#   type:
#     items: int
#     name: _:e4585101-bfbd-4f19-b290-fc80772bca77
#     type: array
# - doc: input3 doc
#   id: io:/#main/input3
#   label: input3 label
#   type:
#   - items: string
#     name: _:06775fd0-3d41-40dd-95fc-dcea81ee0f3a
#     type: array
#   - 'null'
# - doc: input4 doc
#   id: io:/#main/input4
#   label: input4 label
#   type:
#   - 'null'
#   - name: _:f1e92686-d247-4378-9cee-2c004fe289f1
#     symbols:
#     - io:/#main/input4/bam
#     - io:/#main/input4/sam
#     - io:/#main/input4/bam_mapped
#     - io:/#main/input4/sam_mapped
#     - io:/#main/input4/fastq
#     type: enum
# - default: bam
#   doc: input5 doc
#   id: io:/#main/input5
#   label: input5 label
#   type:
#   - name: _:a412f4ea-37fb-4b17-b045-7530eab491cc
#     symbols:
#     - io:/#main/input5/bam
#     - io:/#main/input5/sam
#     - io:/#main/input5/bam_mapped
#     - io:/#main/input5/sam_mapped
#     - io:/#main/input5/fastq
#     type: enum
# - default: 1.0 mm/day
#   doc: thresh doc
#   id: io:/#main/thresh
#   label: thresh label
#   type:
#   - 'null'
#   - string
# - default: true
#   doc: option doc
#   id: io:/#main/option
#   label: option label
#   type: boolean
# - default: false
#   doc: option2 doc
#   id: io:/#main/option2
#   label: option2 label
#   type:
#   - 'null'
#   - boolean
# - doc: array_boolean doc
#   id: io:/#main/array_boolean
#   label: array_boolean label
#   type:
#   - items: boolean
#     name: _:c4868b45-895c-4daf-9b07-39ca095d23d2
#     type: array
#   - 'null'
# outputs: []

# %% [markdown]
# # 2. Inputs conversion
#
# Once the document is parsed, invoke the `cwl2ogc` APIs to convert the CWL inputs to the OGC JSON format:

# %%
from cwl2ogc import BaseCWLtypes2OGCConverter
import json

converter = BaseCWLtypes2OGCConverter(cwl)

inputs = converter.to_ogc(cwl.inputs)

print(json.dumps(inputs, indent=2))
# Out:
# {
#   "color": {
#     "schema": {
#       "type": "string",
#       "enum": [
#         "red",
#         "green",
#         "blue"
#       ],
#       "default": "green"
#     },
#     "title": "color label",
#     "description": "color doc"
#   },
#   "color1": {
#     "schema": {
#       "nullable": true,
#       "type": "array",
#       "items": {
#         "type": "string",
#         "enum": [
#           "red",
#           "green",
#           "blue"
#         ]
#       }
#     },
#     "title": "color1 label",
#     "description": "color1 doc"
#   },
#   "bands": {
#     "schema": {
#       "nullable": true,
#       "type": "array",
#       "items": {
#         "type": "array",
#         "items": {
#           "type": "string",
#           "enum": [
#             "red",
#             "green",
#             "blue"
#           ]
#         }
#       }
#     },
#     "title": "bands label",
#     "description": "bands doc"
#   },
#   "input0": {
#     "schema": {
#       "type": "string"
#     },
#     "title": "input0 label",
#     "description": "input0 doc"
#   },
#   "optional_string": {
#     "schema": {
#       "nullable": true,
#       "type": "string",
#       "default": "default"
#     },
#     "title": "optional_string label",
#     "description": "optional_string doc"
#   },
#   "input1": {
#     "schema": {
#       "type": "array",
#       "items": {
#         "type": "string"
#       }
#     },
#     "title": "input1 label",
#     "description": "input1 doc"
#   },
#   "input2": {
#     "schema": {
#       "type": "array",
#       "items": {
#         "type": "integer"
#       }
#     },
#     "title": "input2 label",
#     "description": "input2 doc"
#   },
#   "input3": {
#     "schema": {
#       "nullable": true,
#       "type": "array",
#       "items": {
#         "type": "string"
#       }
#     },
#     "title": "input3 label",
#     "description": "input3 doc"
#   },
#   "input4": {
#     "schema": {
#       "nullable": true,
#       "type": "string",
#       "enum": [
#         "bam",
#         "sam",
#         "bam_mapped",
#         "sam_mapped",
#         "fastq"
#       ]
#     },
#     "title": "input4 label",
#     "description": "input4 doc"
#   },
#   "input5": {
#     "schema": {
#       "nullable": false,
#       "anyOf": [
#         {
#           "type": "string",
#           "enum": [
#             "bam",
#             "sam",
#             "bam_mapped",
#             "sam_mapped",
#             "fastq"
#           ]
#         }
#       ],
#       "default": "bam"
#     },
#     "title": "input5 label",
#     "description": "input5 doc"
#   },
#   "thresh": {
#     "schema": {
#       "nullable": true,
#       "type": "string",
#       "default": "1.0 mm/day"
#     },
#     "title": "thresh label",
#     "description": "thresh doc"
#   },
#   "option": {
#     "schema": {
#       "type": "boolean",
#       "default": true
#     },
#     "title": "option label",
#     "description": "option doc"
#   },
#   "option2": {
#     "schema": {
#       "nullable": true,
#       "type": "boolean"
#     },
#     "title": "option2 label",
#     "description": "option2 doc"
#   },
#   "array_boolean": {
#     "schema": {
#       "nullable": true,
#       "type": "array",
#       "items": {
#         "type": "boolean"
#       }
#     },
#     "title": "array_boolean label",
#     "description": "array_boolean doc"
#   }
# }

# %% [markdown]
# # 2. Outputs conversion
#
# Users can reuse the `BaseCWLtypes2OGCConverter` instance to convert the CWL outputs to the OGC JSON format:

# %%
outputs = converter.to_ogc(cwl.outputs)

print(json.dumps(outputs, indent=2))
# Out:
# {}
